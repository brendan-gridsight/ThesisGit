# %% [markdown]
# # MPC Simulation DRH and IFH Real Data

# %% [markdown]
# This notebook contains simulations for the DRH MPC suystem that will be used throughout thesis

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.dae import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib
import numpy as np
import seaborn as sns
from sqlalchemy import create_engine
import pymysql
import datetime
#from datetime import datetime
import time
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing Data

# %% [markdown]
# **Specify start and end date of MPC simulations**

# %%
start = '2020-11-28'
end = '2020-12-2'
#end = '2020-12-4'
dt = 1/3
sim = 'IFH'

#sb_phase = 'P1'

# %%
sim_start = 0
sim_end = 2200

# %% [markdown]
# **Import fixed time series data**

# %%
ts_data = pd.read_csv('CSV/5min_tariffs_peak.csv', index_col=0)
ts_data.index = pd.to_datetime(ts_data.index, format='%H:%M:%S').time

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

weather = pd.read_sql(f'select * from thermal_comfort where date_ between "{start}" and "{end}"', con=db_connection)
weather.index = weather.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
weather = weather[['t_ext', 'ghi', 't_bed']]

# %%
weather['t_ext'].plot()
# Out:
# <AxesSubplot:>

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

power_balance = pd.read_sql(f'select * from power_balance where date_ between "{start}" and "{end}"', con=db_connection)
power_balance.index = power_balance.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
power_balance['pv'] = power_balance['pv_master'] + power_balance['pv_slave']

# %%
drh = pd.read_csv('CSV/DRH SWBD - Hioki PW3360 30sec 20202010 to 20201218.CSV', skiprows=16)
drh.index = pd.to_datetime((drh['Date']), format='%d/%m/%Y %H:%M')
drh = drh.resample('10min').mean()

# %%
ifh = pd.read_csv('CSV/IFH SWBD - Hioki PW3198 30sec 20201020 to 20201124.CSV')
ifh.index = pd.to_datetime((ifh['Date']+' '+ifh['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
#sbrc = pd.read_csv('CSV/SBRC Incomer - Hioki PW3198 30sec 20201020 to 20201124.CSV')
#sbrc.index = pd.to_datetime((sbrc['Date']+' '+sbrc['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
sbrc = pd.read_csv('CSV/Endeavour TX Monitor Data 23 Nov to 1 Dec 2020.csv')
sbrc.index = pd.to_datetime(sbrc['Time'], format='%m/%d/%Y %H:%M')
sbrc.index = sbrc.index.shift((-1-1/6), freq='H')

# %%
(sbrc.loc[start]['P1 [kW]']).plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
sbrc['AvgP1'] = (sbrc['P1 [kW]']*1000)-10000
sbrc['AvgP2'] = (sbrc['P2 [kW]']*1000)-10000
sbrc['AvgP3'] = (sbrc['P3 [kW]']*1000)-10000

# %%
pv = pd.read_csv('CSV/SBRC Office PV - Hioki PW3360 30sec 20201023 to 20201213.CSV', skiprows=16)
pv = pv.drop(pv.index[0])
pv['Date'] = [idx+':00' if i%2==0 else idx+':30' for i,idx in enumerate(pv['Date'])]
pv.index = pd.to_datetime((pv['Date']), format='%d/%m/%Y %H:%M:%S')

# %%
if(sim=='DRH'):
    power_balance['pv'] = (power_balance['pv_master'] + power_balance['pv_slave'])
elif(sim=='IFH'):
    power_balance['pv'] = (power_balance['pv_master'] + power_balance['pv_slave'])*0.95

# %%
(power_balance['pv_master'] + power_balance['pv_slave']).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Build dataframe with all relevant data source to use in simulations**

# %%
#Join weather and power data frames
sim_data = weather.join(power_balance['pv'], how='inner').resample('5min').mean()

# %%
sim_data
# Out:
#                      t_ext  ghi  t_bed   pv
# 2020-11-28 00:00:00   22.9  0.0  28.56  0.0
# 2020-11-28 00:05:00   23.4  0.0  28.58  0.0
# 2020-11-28 00:10:00   24.0  0.0  28.56  0.0
# 2020-11-28 00:15:00   24.2  0.0  28.54  0.0
# 2020-11-28 00:20:00   24.0  0.0  28.54  0.0
# ...                    ...  ...    ...  ...
# 2020-12-02 23:35:00   16.7  0.0  23.74  0.0
# 2020-12-02 23:40:00   16.5  0.0  23.72  0.0
# 2020-12-02 23:45:00   16.6  0.0  23.70  0.0
# 2020-12-02 23:50:00   16.6  0.0  23.70  0.0
# 2020-12-02 23:55:00   16.5  0.0  23.70  0.0
#
# [1440 rows x 4 columns]

# %%
#insert fixed time series data into df
for col in ts_data.columns:
    sim_data[col] = [ts_data[col].loc[idx]  for idx in sim_data.index.time]

# %%
sim_data['t_ext'] = sim_data['t_ext'].ewm(span = 24).mean()

# %%
m_cool, b_cool = np.polyfit(x=[20,25,30,35,40,45], y=[-10.24, -9.38, -8.41, -7.44, -5.16, -3.79], deg=1)

# %%
m_cop, b_cop = np.polyfit(x=[20,25,30,35,40,45], y=[3.59, 3.26, 2.85, 2.44, 2.15, 1.88], deg=1)

# %%
sim_data['cop'] = m_cop*(sim_data['t_ext']) + b_cop
sim_data['cool_cap'] = m_cool*sim_data['t_ext'] + b_cool

# %%
states = {'SoC_Av':20,
         'T_i': 25,
         'T_w': 24,
         'phi_h':0,
         'phi_c':0}

# %% [markdown]
# ## DRH MPC Formulation

# %%
class MPC_DRH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 13.8
        self.min_soc = 0
        self.max_ch = 3000
        self.max_dis = 3000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 2.786
        self.C_w = 14.78
        self.C_i = 1.887
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 0.637
        self.A_w = 2.103
        self.COP = 3.69
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        self.m.mode_2 = Param(self.m.t, initialize=self.forecasts['mode_2'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            self.m.mode_2[n] = self.forecasts['mode_2'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        return (self.m.cool_cap[t],0)
    
    
    def hp_min(self, m, t):
        return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
        #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
    def hp_max(self, m, t):
        return m.p_hvac[t] <= self.M*self.m.dhp[t]
        #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        return (21, 27)
        #return (23, 26)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.1*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_2[t]*(((self.m.p_im[t] + self.m.p_ex[t]) + 10000)*((self.m.p_im[t] + self.m.p_ex[t]) + 10000))
                   for t in self.m.t)
    

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# # IFH MPC Formulation

# %%
class MPC_IFH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 8.8
        self.min_soc = 0
        self.max_ch = 5000
        self.max_dis = 5000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        self.m.mode_2 = Param(self.m.t, initialize=self.forecasts['mode_2'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            self.m.mode_2[n] = self.forecasts['mode_2'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        #return (self.m.cool_cap[t],0)
        return (-7,0)
    
    
#     def hp_min(self, m, t):
#         return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
#         #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
#     def hp_max(self, m, t):
#         return m.p_hvac[t] <= self.M*self.m.dhp[t]
#         #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        #return (23, 26)
        return (21, 27)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt))
#                    for t in self.m.t)
    
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_2[t]*(((self.m.p_im[t] + self.m.p_ex[t]) + 10000)*((self.m.p_im[t] + self.m.p_ex[t]) + 10000))
                   for t in self.m.t)
    
    
    
    
    
    
    
    
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# ## SBRC MPC Formulation

# %%
class MPC_SBRC():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.95
        self.n_dis = 0.95
        self.max_soc = 13.3
        self.min_soc = 0
        self.max_ch = 7500
        self.max_dis = 7500
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        


    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['fixed'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        self.m.mode_2 = Param(self.m.t, initialize=self.forecasts['mode_2'].iloc[0], mutable=True)
        
        
        

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['fixed'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            self.m.mode_2[n] = self.forecasts['mode_2'].loc[time]
            #Thermal
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,100000), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(-100000,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)


    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  



    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        #return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]
    
    def dischargeBalance(self, m,t):
        return self.m.p_dis[t] == self.m.p_dis_l[t] + self.m.p_dis_g[t]

    def pvCharge(self, m,t):
        return -self.m.p_ch_p[t] <= self.m.p_pv[t]
    
    
    def gridDischarge(self, m,t):
        return self.m.p_dis_g[t] >= self.m.p_load[t]
    


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)


    def objFunc(self, m):  
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                       + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                       + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                       + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                       + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
                       + self.m.mode_2[t]*(((self.m.p_im[t] + self.m.p_ex[t]) + 10000)*((self.m.p_im[t] + self.m.p_ex[t]) + 10000))
                       for t in self.m.t)
    
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
#         discretizer = TransformationFactory('dae.finite_difference')
#         discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %%
def extract_pyomo_electrical_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    df['p_im'] = list(m.p_im.get_values().values())
    df['p_ex'] = list(m.p_ex.get_values().values())
    df['p_ch'] = list(m.p_ch.get_values().values())
    df['p_ch_p'] = list(m.p_ch_p.get_values().values())
    df['p_ch_g'] = list(m.p_ch_g.get_values().values())
    df['p_dis'] = list(m.p_dis.get_values().values())
    df['soc'] = list(m.soc.get_values().values())
    
    return df

# %%
def extract_pyomo_thermal_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    #df['phi_h_heat'] = list(m.phi_h_heat.get_values().values())
    df['phi_h_cool'] = list(m.phi_h_cool.get_values().values())
    df['p_hvac'] = list(m.p_hvac.get_values().values())
    df['T_i'] = list(m.T_i.get_values().values())
    df['T_w'] = list(m.T_w.get_values().values())
    
    return df

# %%
def plot_electrical3(df_results, sim):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    
    fig = plt.figure(figsize=(12,8))
    
    gs=GridSpec(3,1) # 2 rows, 3 columns

    ax1=fig.add_subplot(gs[0,0]) # First row, first column
    ax2=fig.add_subplot(gs[1:,0]) # First row, second column

    
    load =  ax2.plot(df_results.index, df_results['load'], label='$p_i^l$', lw=1, color='red', ls=(0, (3, 1, 1, 1)))
    pv =  ax2.plot(df_results.index, df_results['pv'], label='$p_i^p$', lw=1, color='blue', ls=(0, (5, 5)))
    im =  ax2.plot(df_results.index, df_results['p_im'], label='$p_i^i$', lw=1, color='grey', ls='-.')
    ex =  ax2.plot(df_results.index, df_results['p_ex'], label='$p_i^e$', lw=1, color='orange', ls=(0, (3, 1, 1, 1, 1, 1)))
    ch =  ax2.plot(df_results.index, df_results['p_ch'], label='$p_i^c$', lw=1.5,color='black', ls='dotted')
    dis =  ax2.plot(df_results.index, df_results['p_dis'], label='$p_i^d$', lw=1, color='green')
    hvac = ax2.plot(df_results.index, df_results['p_hvac'], label='$p_i^h$', lw=1, color='purple', ls=(0, (5, 1)))
    ax2.set_ylim(-30000,60000)
    #ax2.set_ylim(-7000,8000)
     
    soc = ax1.plot(df_results.index, df_results['soc'], label='$SoC$', lw=1, color='blue', ls='--')
    ax1.set_ylim(-10,120)
    
    ax3 = ax1.twinx()
    ax3.set_ylabel('Cost ($/kWh)')
    ax3.set_ylim(0,0.4)
    tou = ax3.plot(df_results.index, df_results['tou'], label='$ToU$', lw=1, color='red',)
    ax3.grid()
    
    ax2.set_xlabel('Date')
    ax1.set_ylabel('SoC (%)')
    ax1.get_shared_x_axes().join(ax1, ax2)
    ax1.set_xticklabels([])
    ax2.set_ylabel('Power (W)')
    
    ax2.legend(loc="upper left", ncol=7)
    ax1.legend(loc="upper left")
    ax3.legend(loc="upper right")
    ax1.autoscale(enable=True, axis='x', tight=True)

# %%
def plot_thermal_combined2(mpc_data):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    fig, ax = plt.subplots(2, sharex=True)
    ax[0].set_ylabel('Indoor Temperature ($^\circ$C)')
    ax[0].set_ylim(15,45)
    ax[0].plot(mpc_data.index, mpc_data['T_i'], color='red', lw=2, ls='--')
    #ax[0].plot(mpc_data.index, rbc_data['T_i'], color='black', lw=2, ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[0].plot(mpc_data.index, mpc_data['t_ext'], color='green', ls='-.')
    #ax[0].plot(mpc_data.index, mpc_data['t_bed'])
    ax[0].plot(mpc_data.index, mpc_data['set_point'], color='grey')
    ax[0].legend(['MPC $T_i^i$', 'RBC $T_i^i$', '$T_a$', 'Set Point'], loc="upper left", ncol=4)
    
    
    
    #Plot Results
    
    ax[1].set_xlabel('Date')
    ax[1].set_ylabel('Cooling (kW) \n Solar Irradiance (kW/m$^2$)')
    ax[1].set_ylim(0,15)
    #ax1.plot(df_results.index, df_results['phi_h_heat'], color='red')
    ax[1].plot(mpc_data.index, -mpc_data['phi_h_cool'], color='red', alpha=0.75, )
    #ax[1].plot(mpc_data.index, -rbc_data['phi_h_cool'], color= 'black', ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[1].plot(mpc_data.index, mpc_data['ghi']/1000, color='blue', ls='--')
    ax[1].legend(['MPC $\Phi_i^c$', 'RPC $\Phi_i^c$', 'GHI'], loc="upper left", ncol=3)



    fig.tight_layout()
    fig.set_figheight(7.5)
    fig.set_figwidth(12)# otherwise the right y-label is slightly clipped
    #ax.grid()
    
    #plt.savefig('thermal_mpc_rbc.pdf')
    ax[0].autoscale(enable=True, axis='x', tight=True)
    ax[1].autoscale(enable=True, axis='x', tight=True)
    plt.show()

# %% [markdown]
# ## Solve MPC

# %%
mpc_data = sim_data.loc[start:end].resample('20min').mean().dropna()

# %%
if(sim=='DRH'):
    mpc_data['pv'] = mpc_data['pv'].shift(-3, axis=0)
    mpc_data['pv'].fillna(0, inplace=True)

# %%
mpc_data.loc[end,'mode_0'] = 1
mpc_data.loc[end,'mode_2'] = 0

# mpc_data['mode_0'] = 1
# mpc_data['mode_1'] = 0

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
Np = 24

# %%
# for i, idx in enumerate(mpc_data.index):
#     print('\n' + str(i) + '\n' + str(idx) + '\n')
#     mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()

#     mpc = MPC_IFH(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
#     mpc.solve()

#     mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
#     mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)

#     mpc_results_first_step = mpc_sim.iloc[0].copy()
#     mpc_results.iloc[i] = mpc_results_first_step
    
#     #states = {'SoC_Av':mpc_sim['soc'].iloc[0]}
    
# #     states = {'SoC_Av':mpc_sim['soc'].iloc[0],
# #               'T_i':mpc_sim['T_i'].iloc[1],
# #               'T_w':mpc_sim['T_w'].iloc[1],
# #               'phi_h':mpc_sim['phi_h_heat'].iloc[1],
# #               'phi_c':mpc_sim['phi_h_cool'].iloc[1]}
    
#     states = {'SoC_Av':mpc_sim['soc'].iloc[0],
#               'T_i':mpc_sim['T_i'].iloc[1],
#               'T_w':mpc_sim['T_w'].iloc[1],
#               'phi_c':mpc_sim['phi_h_cool'].iloc[1]}

    
#     if(i==72):
#         break 
# #     if(i==500):
# #         break

# %%
plot_electrical3(mpc_results[start], sim='mbc')

# %%
#mpc_results.to_csv(f'Results/PSmode_20min_{sim}_{start}_3pm_5pm.csv')

# %%
pv = pv.resample('10min').mean()

# %% [markdown]
# # SBRC Simulations

# %%
def sbrc_mpc_df(sb_phase):
    sbrc_pv = pd.DataFrame()
    
    if(sb_phase == 'P1'):
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'] - drh.loc[start:end]['P1_Avg[W]'])
        #sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    elif(sb_phase == 'P3'):
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'] - drh.loc[start:end]['P1_Avg[W]'])            
    else:
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = -(pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = [0 if pv_val < 0 else pv_val for pv_val in sbrc_pv['pv']]

    sbrc_pv = sbrc_pv.resample('20min').mean()

    for col in ['fixed', 'tou', 'fit', 'ch_cost', 'dis_cost', 'mode_0', 'mode_1', 'mode_2']:
        sbrc_pv[col] = [ts_data[col].loc[idx]  for idx in sbrc_pv.index.time]
        
        
    return sbrc_pv

# %% [markdown]
# ## Simulate MPC Each Pahse SBRC

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
states = {'SoC_Av':20}

# %%
for ph in ['P1', 'P2', 'P3']:
#for ph in ['P3']:
    
    mpc_data = sbrc_mpc_df(ph)

    print(mpc_data)

    ##------PS MODE--------##
    mpc_data.loc[end,'mode_0'] = 1
    mpc_data.loc[end,'mode_2'] = 0

    ##------ECO MODE--------##
    # mpc_data['mode_0'] = 1
    # mpc_data['mode_2'] = 0

    for i, idx in enumerate(mpc_data.index):
        print('\n' + str(i) + '\n' + str(idx) + '\n')
        mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()

        mpc = MPC_SBRC(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
        mpc.solve()

        mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
    #         #mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)


        mpc_results_first_step = mpc_sim.iloc[0].copy()
        mpc_results.iloc[i] = mpc_results_first_step

        states = {'SoC_Av':mpc_sim['soc'].iloc[0]}


        if(i==72):
            break

    mpc_results.to_csv(f'Results/PSmode_20min_SBRC_{ph}_{start}_3pm_5pm.csv')
    states = {'SoC_Av':20}
# Out:
#                           load   pv  fixed   tou   fit  ch_cost  dis_cost  \
# 2020-11-28 00:00:00  27605.025  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:20:00  25947.225  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:40:00  25090.000  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:00:00  24998.200  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:20:00  24816.075  0.0   0.25  0.16  0.11     0.02      0.01
# ...                        ...  ...    ...   ...   ...      ...       ...
# 2020-12-02 22:20:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 22:40:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:00:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:20:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:40:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
#
#                      mode_0  mode_1  mode_2
# 2020-11-28 00:00:00       1       0       0
# 2020-11-28 00:20:00       1       0       0
# 2020-11-28 00:40:00       1       0       0
# 2020-11-28 01:00:00       1       0       0
# 2020-11-28 01:20:00       1       0       0
# ...                     ...     ...     ...
# 2020-12-02 22:20:00       1       0       0
# 2020-12-02 22:40:00       1       0       0
# 2020-12-02 23:00:00       1       0       0
# 2020-12-02 23:20:00       1       0       0
# 2020-12-02 23:40:00       1       0       0
#
# [360 rows x 10 columns]
#
# 0
# 2020-11-28 00:00:00
#
# Solver log file: '/tmp/tmp1afmg2gz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpifgx1cg9.pyomo.sol'
# Solver problem files: ('/tmp/tmpifgx1cg9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2020-11-28 00:20:00
#
# Solver log file: '/tmp/tmpg74l3cmi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3tw3na_a.pyomo.sol'
# Solver problem files: ('/tmp/tmp3tw3na_a.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2020-11-28 00:40:00
#
# Solver log file: '/tmp/tmpzdi5ncui_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprtcirjcz.pyomo.sol'
# Solver problem files: ('/tmp/tmprtcirjcz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2020-11-28 01:00:00
#
# Solver log file: '/tmp/tmp29mqdqxy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp47bjcmdn.pyomo.sol'
# Solver problem files: ('/tmp/tmp47bjcmdn.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2020-11-28 01:20:00
#
# Solver log file: '/tmp/tmpamikdpn2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgjqqmvku.pyomo.sol'
# Solver problem files: ('/tmp/tmpgjqqmvku.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2020-11-28 01:40:00
#
# Solver log file: '/tmp/tmppz4j4q36_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpibefbhia.pyomo.sol'
# Solver problem files: ('/tmp/tmpibefbhia.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2020-11-28 02:00:00
#
# Solver log file: '/tmp/tmprefs2qf0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgwpo8n6y.pyomo.sol'
# Solver problem files: ('/tmp/tmpgwpo8n6y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2020-11-28 02:20:00
#
# Solver log file: '/tmp/tmprjuesd3a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp0ttj6eq.pyomo.sol'
# Solver problem files: ('/tmp/tmpp0ttj6eq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2020-11-28 02:40:00
#
# Solver log file: '/tmp/tmpu5dzual9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphjsp8zd2.pyomo.sol'
# Solver problem files: ('/tmp/tmphjsp8zd2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2020-11-28 03:00:00
#
# Solver log file: '/tmp/tmp0i39ai4a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpffdpk8hb.pyomo.sol'
# Solver problem files: ('/tmp/tmpffdpk8hb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2020-11-28 03:20:00
#
# Solver log file: '/tmp/tmpqgcw2tst_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2215pu1q.pyomo.sol'
# Solver problem files: ('/tmp/tmp2215pu1q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2020-11-28 03:40:00
#
# Solver log file: '/tmp/tmp19a149ih_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6ffydn9u.pyomo.sol'
# Solver problem files: ('/tmp/tmp6ffydn9u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2020-11-28 04:00:00
#
# Solver log file: '/tmp/tmppund1pho_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_6nq4pxi.pyomo.sol'
# Solver problem files: ('/tmp/tmp_6nq4pxi.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2020-11-28 04:20:00
#
# Solver log file: '/tmp/tmpyakb0jje_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmczt_puo.pyomo.sol'
# Solver problem files: ('/tmp/tmpmczt_puo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2020-11-28 04:40:00
#
# Solver log file: '/tmp/tmphhs2s3f0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp120ifyx.pyomo.sol'
# Solver problem files: ('/tmp/tmpp120ifyx.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2020-11-28 05:00:00
#
# Solver log file: '/tmp/tmpok9g05xx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptt413dhf.pyomo.sol'
# Solver problem files: ('/tmp/tmptt413dhf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2020-11-28 05:20:00
#
# Solver log file: '/tmp/tmpyuwj94mu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpge8oc31_.pyomo.sol'
# Solver problem files: ('/tmp/tmpge8oc31_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2020-11-28 05:40:00
#
# Solver log file: '/tmp/tmpr2w8bmac_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpeyfm8q5c.pyomo.sol'
# Solver problem files: ('/tmp/tmpeyfm8q5c.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2020-11-28 06:00:00
#
# Solver log file: '/tmp/tmpc82m4dqv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppxwqfwxh.pyomo.sol'
# Solver problem files: ('/tmp/tmppxwqfwxh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2020-11-28 06:20:00
#
# Solver log file: '/tmp/tmp3vzi9mly_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpy0h85i3e.pyomo.sol'
# Solver problem files: ('/tmp/tmpy0h85i3e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2020-11-28 06:40:00
#
# Solver log file: '/tmp/tmpwksp4pf7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpflpmhp_p.pyomo.sol'
# Solver problem files: ('/tmp/tmpflpmhp_p.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2020-11-28 07:00:00
#
# Solver log file: '/tmp/tmpdtz0spg2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzutjgp62.pyomo.sol'
# Solver problem files: ('/tmp/tmpzutjgp62.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2020-11-28 07:20:00
#
# Solver log file: '/tmp/tmp0lw0mdou_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3wljojry.pyomo.sol'
# Solver problem files: ('/tmp/tmp3wljojry.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2020-11-28 07:40:00
#
# Solver log file: '/tmp/tmpts78gb61_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu7u4hqrk.pyomo.sol'
# Solver problem files: ('/tmp/tmpu7u4hqrk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2020-11-28 08:00:00
#
# Solver log file: '/tmp/tmp1cy9jipk_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4125j8xm.pyomo.sol'
# Solver problem files: ('/tmp/tmp4125j8xm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2020-11-28 08:20:00
#
# Solver log file: '/tmp/tmpkslm7j1y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8gwyomsa.pyomo.sol'
# Solver problem files: ('/tmp/tmp8gwyomsa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2020-11-28 08:40:00
#
# Solver log file: '/tmp/tmpgnbtdtsg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9n4jl9xy.pyomo.sol'
# Solver problem files: ('/tmp/tmp9n4jl9xy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2020-11-28 09:00:00
#
# Solver log file: '/tmp/tmp4qixtgqc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpboecospt.pyomo.sol'
# Solver problem files: ('/tmp/tmpboecospt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2020-11-28 09:20:00
#
# Solver log file: '/tmp/tmp56cbhugl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppl4bq59n.pyomo.sol'
# Solver problem files: ('/tmp/tmppl4bq59n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2020-11-28 09:40:00
#
# Solver log file: '/tmp/tmpkf1cbnpy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyvwwhu9t.pyomo.sol'
# Solver problem files: ('/tmp/tmpyvwwhu9t.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2020-11-28 10:00:00
#
# Solver log file: '/tmp/tmp73u_ud5p_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwg7_d2lu.pyomo.sol'
# Solver problem files: ('/tmp/tmpwg7_d2lu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2020-11-28 10:20:00
#
# Solver log file: '/tmp/tmpdpv8a6it_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpey218mxk.pyomo.sol'
# Solver problem files: ('/tmp/tmpey218mxk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2020-11-28 10:40:00
#
# Solver log file: '/tmp/tmpu9taxqne_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_n6x2wax.pyomo.sol'
# Solver problem files: ('/tmp/tmp_n6x2wax.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2020-11-28 11:00:00
#
# Solver log file: '/tmp/tmpgimrazrf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdriki83z.pyomo.sol'
# Solver problem files: ('/tmp/tmpdriki83z.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2020-11-28 11:20:00
#
# Solver log file: '/tmp/tmpvrd1bm68_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpg2wmwqro.pyomo.sol'
# Solver problem files: ('/tmp/tmpg2wmwqro.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2020-11-28 11:40:00
#
# Solver log file: '/tmp/tmps2zk6e18_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjd6u97_u.pyomo.sol'
# Solver problem files: ('/tmp/tmpjd6u97_u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2020-11-28 12:00:00
#
# Solver log file: '/tmp/tmp7kpwztv__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp91xs9ql3.pyomo.sol'
# Solver problem files: ('/tmp/tmp91xs9ql3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2020-11-28 12:20:00
#
# Solver log file: '/tmp/tmphmnjyu5f_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1i16u9ml.pyomo.sol'
# Solver problem files: ('/tmp/tmp1i16u9ml.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2020-11-28 12:40:00
#
# Solver log file: '/tmp/tmpgjp_g2dm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxifbin2n.pyomo.sol'
# Solver problem files: ('/tmp/tmpxifbin2n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2020-11-28 13:00:00
#
# Solver log file: '/tmp/tmpppx2txv__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2dg6zlui.pyomo.sol'
# Solver problem files: ('/tmp/tmp2dg6zlui.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2020-11-28 13:20:00
#
# Solver log file: '/tmp/tmpsex1yi8g_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3tg5ypwo.pyomo.sol'
# Solver problem files: ('/tmp/tmp3tg5ypwo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2020-11-28 13:40:00
#
# Solver log file: '/tmp/tmpfur140zh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpffnsqy88.pyomo.sol'
# Solver problem files: ('/tmp/tmpffnsqy88.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2020-11-28 14:00:00
#
# Solver log file: '/tmp/tmplmk16kxw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpj0qsvwm7.pyomo.sol'
# Solver problem files: ('/tmp/tmpj0qsvwm7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2020-11-28 14:20:00
#
# Solver log file: '/tmp/tmpi3fvrkde_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpo7w37_94.pyomo.sol'
# Solver problem files: ('/tmp/tmpo7w37_94.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2020-11-28 14:40:00
#
# Solver log file: '/tmp/tmpx0omhg81_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptow985yf.pyomo.sol'
# Solver problem files: ('/tmp/tmptow985yf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2020-11-28 15:00:00
#
# Solver log file: '/tmp/tmp6g7y_f6k_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd1276lt5.pyomo.sol'
# Solver problem files: ('/tmp/tmpd1276lt5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2020-11-28 15:20:00
#
# Solver log file: '/tmp/tmp6qipj3xh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5ouijuzl.pyomo.sol'
# Solver problem files: ('/tmp/tmp5ouijuzl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2020-11-28 15:40:00
#
# Solver log file: '/tmp/tmpgj91y5ui_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpw0kpruxy.pyomo.sol'
# Solver problem files: ('/tmp/tmpw0kpruxy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2020-11-28 16:00:00
#
# Solver log file: '/tmp/tmp06gla556_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1bqy28pl.pyomo.sol'
# Solver problem files: ('/tmp/tmp1bqy28pl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2020-11-28 16:20:00
#
# Solver log file: '/tmp/tmpv1jzc0mx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmnuam124.pyomo.sol'
# Solver problem files: ('/tmp/tmpmnuam124.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2020-11-28 16:40:00
#
# Solver log file: '/tmp/tmpx3gsskc1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3vu5y6lm.pyomo.sol'
# Solver problem files: ('/tmp/tmp3vu5y6lm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2020-11-28 17:00:00
#
# Solver log file: '/tmp/tmp1ijqpuvb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk8990xxb.pyomo.sol'
# Solver problem files: ('/tmp/tmpk8990xxb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2020-11-28 17:20:00
#
# Solver log file: '/tmp/tmp75z8z_pt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8mu77b3_.pyomo.sol'
# Solver problem files: ('/tmp/tmp8mu77b3_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2020-11-28 17:40:00
#
# Solver log file: '/tmp/tmp4j76_vc__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqi4hyx8y.pyomo.sol'
# Solver problem files: ('/tmp/tmpqi4hyx8y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2020-11-28 18:00:00
#
# Solver log file: '/tmp/tmps4kye_vc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd0iffguj.pyomo.sol'
# Solver problem files: ('/tmp/tmpd0iffguj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2020-11-28 18:20:00
#
# Solver log file: '/tmp/tmposa4c75i_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdv92x7qe.pyomo.sol'
# Solver problem files: ('/tmp/tmpdv92x7qe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2020-11-28 18:40:00
#
# Solver log file: '/tmp/tmp6qa50_tb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpo82xgmai.pyomo.sol'
# Solver problem files: ('/tmp/tmpo82xgmai.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2020-11-28 19:00:00
#
# Solver log file: '/tmp/tmpeow7c3a3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp28oqz3dq.pyomo.sol'
# Solver problem files: ('/tmp/tmp28oqz3dq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2020-11-28 19:20:00
#
# Solver log file: '/tmp/tmpiu5kgxlr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp90wodpxy.pyomo.sol'
# Solver problem files: ('/tmp/tmp90wodpxy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2020-11-28 19:40:00
#
# Solver log file: '/tmp/tmp2akar48y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjner_raz.pyomo.sol'
# Solver problem files: ('/tmp/tmpjner_raz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2020-11-28 20:00:00
#
# Solver log file: '/tmp/tmps7aubxuz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpombz8kop.pyomo.sol'
# Solver problem files: ('/tmp/tmpombz8kop.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2020-11-28 20:20:00
#
# Solver log file: '/tmp/tmpoxbump2n_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp98qmbvwu.pyomo.sol'
# Solver problem files: ('/tmp/tmp98qmbvwu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2020-11-28 20:40:00
#
# Solver log file: '/tmp/tmp2_dd2d0__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpsq6eyi4z.pyomo.sol'
# Solver problem files: ('/tmp/tmpsq6eyi4z.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2020-11-28 21:00:00
#
# Solver log file: '/tmp/tmpdyudot0f_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnjet_ux1.pyomo.sol'
# Solver problem files: ('/tmp/tmpnjet_ux1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2020-11-28 21:20:00
#
# Solver log file: '/tmp/tmpckjx2wp3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpiipa2jj0.pyomo.sol'
# Solver problem files: ('/tmp/tmpiipa2jj0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2020-11-28 21:40:00
#
# Solver log file: '/tmp/tmpugqaa6r9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4oepneht.pyomo.sol'
# Solver problem files: ('/tmp/tmp4oepneht.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2020-11-28 22:00:00
#
# Solver log file: '/tmp/tmp4vgh2p04_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnzmsi2y5.pyomo.sol'
# Solver problem files: ('/tmp/tmpnzmsi2y5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2020-11-28 22:20:00
#
# Solver log file: '/tmp/tmpp139agyp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgpnkj95q.pyomo.sol'
# Solver problem files: ('/tmp/tmpgpnkj95q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2020-11-28 22:40:00
#
# Solver log file: '/tmp/tmp7l8jkfoe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0q359qxl.pyomo.sol'
# Solver problem files: ('/tmp/tmp0q359qxl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2020-11-28 23:00:00
#
# Solver log file: '/tmp/tmpk7aoc9lq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvuy_b7im.pyomo.sol'
# Solver problem files: ('/tmp/tmpvuy_b7im.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2020-11-28 23:20:00
#
# Solver log file: '/tmp/tmpl6_4f4cf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_fnzacxu.pyomo.sol'
# Solver problem files: ('/tmp/tmp_fnzacxu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2020-11-28 23:40:00
#
# Solver log file: '/tmp/tmphcar4061_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpflkyhqr3.pyomo.sol'
# Solver problem files: ('/tmp/tmpflkyhqr3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2020-11-29 00:00:00
#
# Solver log file: '/tmp/tmpsggjzjeh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7zprp985.pyomo.sol'
# Solver problem files: ('/tmp/tmp7zprp985.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1                        load   pv  fixed   tou   fit  ch_cost  dis_cost  \
# 2020-11-28 00:00:00  14345.0  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:20:00  13545.0  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:40:00  12810.5  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:00:00  13842.0  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:20:00  13685.0  0.0   0.25  0.16  0.11     0.02      0.01
# ...                      ...  ...    ...   ...   ...      ...       ...
# 2020-12-02 22:20:00      NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 22:40:00      NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:00:00      NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:20:00      NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:40:00      NaN  0.0   0.25  0.16  0.11     0.02      0.01
#
#                      mode_0  mode_1  mode_2
# 2020-11-28 00:00:00       1       0       0
# 2020-11-28 00:20:00       1       0       0
# 2020-11-28 00:40:00       1       0       0
# 2020-11-28 01:00:00       1       0       0
# 2020-11-28 01:20:00       1       0       0
# ...                     ...     ...     ...
# 2020-12-02 22:20:00       1       0       0
# 2020-12-02 22:40:00       1       0       0
# 2020-12-02 23:00:00       1       0       0
# 2020-12-02 23:20:00       1       0       0
# 2020-12-02 23:40:00       1       0       0
#
# [360 rows x 10 columns]
#
# 0
# 2020-11-28 00:00:00
#
# Solver log file: '/tmp/tmpp05hmym3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2qke9p2i.pyomo.sol'
# Solver problem files: ('/tmp/tmp2qke9p2i.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2020-11-28 00:20:00
#
# Solver log file: '/tmp/tmpjhiqct77_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_l95ivzl.pyomo.sol'
# Solver problem files: ('/tmp/tmp_l95ivzl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2020-11-28 00:40:00
#
# Solver log file: '/tmp/tmpj9kwvefn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpaxpx6qez.pyomo.sol'
# Solver problem files: ('/tmp/tmpaxpx6qez.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2020-11-28 01:00:00
#
# Solver log file: '/tmp/tmpocsv6jwa_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpe1rg_kxe.pyomo.sol'
# Solver problem files: ('/tmp/tmpe1rg_kxe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2020-11-28 01:20:00
#
# Solver log file: '/tmp/tmp8hggat8q_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpg5j70efd.pyomo.sol'
# Solver problem files: ('/tmp/tmpg5j70efd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2020-11-28 01:40:00
#
# Solver log file: '/tmp/tmpuu7fbvby_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpapqnizrl.pyomo.sol'
# Solver problem files: ('/tmp/tmpapqnizrl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2020-11-28 02:00:00
#
# Solver log file: '/tmp/tmpw3ogg6qz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_r_uumux.pyomo.sol'
# Solver problem files: ('/tmp/tmp_r_uumux.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2020-11-28 02:20:00
#
# Solver log file: '/tmp/tmp0d88a0l8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdp4s2t4_.pyomo.sol'
# Solver problem files: ('/tmp/tmpdp4s2t4_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2020-11-28 02:40:00
#
# Solver log file: '/tmp/tmpl6mww_01_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpeplwgs41.pyomo.sol'
# Solver problem files: ('/tmp/tmpeplwgs41.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2020-11-28 03:00:00
#
# Solver log file: '/tmp/tmpxkybnedk_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk8i5ncm6.pyomo.sol'
# Solver problem files: ('/tmp/tmpk8i5ncm6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2020-11-28 03:20:00
#
# Solver log file: '/tmp/tmp01h6590m_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt89ky9l1.pyomo.sol'
# Solver problem files: ('/tmp/tmpt89ky9l1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2020-11-28 03:40:00
#
# Solver log file: '/tmp/tmprlu4ktlw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd_0_stki.pyomo.sol'
# Solver problem files: ('/tmp/tmpd_0_stki.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2020-11-28 04:00:00
#
# Solver log file: '/tmp/tmpdtujdb10_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpsenhfs2m.pyomo.sol'
# Solver problem files: ('/tmp/tmpsenhfs2m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2020-11-28 04:20:00
#
# Solver log file: '/tmp/tmps91gs6nn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp068m46n6.pyomo.sol'
# Solver problem files: ('/tmp/tmp068m46n6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2020-11-28 04:40:00
#
# Solver log file: '/tmp/tmpseykv_42_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9a_p32fo.pyomo.sol'
# Solver problem files: ('/tmp/tmp9a_p32fo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2020-11-28 05:00:00
#
# Solver log file: '/tmp/tmp1gd0279m_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplp0trd3o.pyomo.sol'
# Solver problem files: ('/tmp/tmplp0trd3o.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2020-11-28 05:20:00
#
# Solver log file: '/tmp/tmpfm7kb9po_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqhqpclw2.pyomo.sol'
# Solver problem files: ('/tmp/tmpqhqpclw2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2020-11-28 05:40:00
#
# Solver log file: '/tmp/tmp3qfxs8k__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmna98dk_.pyomo.sol'
# Solver problem files: ('/tmp/tmpmna98dk_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2020-11-28 06:00:00
#
# Solver log file: '/tmp/tmp7emoz2e5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpei7pf_qm.pyomo.sol'
# Solver problem files: ('/tmp/tmpei7pf_qm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2020-11-28 06:20:00
#
# Solver log file: '/tmp/tmp8tns_f_4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpste4a340.pyomo.sol'
# Solver problem files: ('/tmp/tmpste4a340.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2020-11-28 06:40:00
#
# Solver log file: '/tmp/tmpkdzgxmxx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr058x428.pyomo.sol'
# Solver problem files: ('/tmp/tmpr058x428.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2020-11-28 07:00:00
#
# Solver log file: '/tmp/tmp5uwfhvx__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8i_y2hr1.pyomo.sol'
# Solver problem files: ('/tmp/tmp8i_y2hr1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2020-11-28 07:20:00
#
# Solver log file: '/tmp/tmpclw5pk_x_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpao1xivpt.pyomo.sol'
# Solver problem files: ('/tmp/tmpao1xivpt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2020-11-28 07:40:00
#
# Solver log file: '/tmp/tmp019vjht__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt9m7o1y8.pyomo.sol'
# Solver problem files: ('/tmp/tmpt9m7o1y8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2020-11-28 08:00:00
#
# Solver log file: '/tmp/tmpq6726k8v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpcqsryfkt.pyomo.sol'
# Solver problem files: ('/tmp/tmpcqsryfkt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2020-11-28 08:20:00
#
# Solver log file: '/tmp/tmpnu5rsfv0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1h1uwgx4.pyomo.sol'
# Solver problem files: ('/tmp/tmp1h1uwgx4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2020-11-28 08:40:00
#
# Solver log file: '/tmp/tmpkibxvsf6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3798el0y.pyomo.sol'
# Solver problem files: ('/tmp/tmp3798el0y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2020-11-28 09:00:00
#
# Solver log file: '/tmp/tmpxqa0q8rq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd9gmxboh.pyomo.sol'
# Solver problem files: ('/tmp/tmpd9gmxboh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2020-11-28 09:20:00
#
# Solver log file: '/tmp/tmpvfdt9egv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvzvnooxs.pyomo.sol'
# Solver problem files: ('/tmp/tmpvzvnooxs.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2020-11-28 09:40:00
#
# Solver log file: '/tmp/tmpfa7d9jqe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1wp9xl_2.pyomo.sol'
# Solver problem files: ('/tmp/tmp1wp9xl_2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2020-11-28 10:00:00
#
# Solver log file: '/tmp/tmpg4zbl2nv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbddcxg6b.pyomo.sol'
# Solver problem files: ('/tmp/tmpbddcxg6b.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2020-11-28 10:20:00
#
# Solver log file: '/tmp/tmp4olqd7hh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1sph62l1.pyomo.sol'
# Solver problem files: ('/tmp/tmp1sph62l1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2020-11-28 10:40:00
#
# Solver log file: '/tmp/tmp60g3oxg0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7lqk_44l.pyomo.sol'
# Solver problem files: ('/tmp/tmp7lqk_44l.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2020-11-28 11:00:00
#
# Solver log file: '/tmp/tmp3jm7839g_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0c3a75xq.pyomo.sol'
# Solver problem files: ('/tmp/tmp0c3a75xq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2020-11-28 11:20:00
#
# Solver log file: '/tmp/tmpaepvy__8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu3k406uy.pyomo.sol'
# Solver problem files: ('/tmp/tmpu3k406uy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2020-11-28 11:40:00
#
# Solver log file: '/tmp/tmpjoz86v00_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgq21_fif.pyomo.sol'
# Solver problem files: ('/tmp/tmpgq21_fif.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2020-11-28 12:00:00
#
# Solver log file: '/tmp/tmpxxs2sj6r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjcht87ay.pyomo.sol'
# Solver problem files: ('/tmp/tmpjcht87ay.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2020-11-28 12:20:00
#
# Solver log file: '/tmp/tmp0qoxo5fe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjyr2llw1.pyomo.sol'
# Solver problem files: ('/tmp/tmpjyr2llw1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2020-11-28 12:40:00
#
# Solver log file: '/tmp/tmp2e9_flrd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpytlyde55.pyomo.sol'
# Solver problem files: ('/tmp/tmpytlyde55.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2020-11-28 13:00:00
#
# Solver log file: '/tmp/tmpkg1gpjyb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphjg6qrc1.pyomo.sol'
# Solver problem files: ('/tmp/tmphjg6qrc1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2020-11-28 13:20:00
#
# Solver log file: '/tmp/tmpzjq5p4n6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd1x74g60.pyomo.sol'
# Solver problem files: ('/tmp/tmpd1x74g60.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2020-11-28 13:40:00
#
# Solver log file: '/tmp/tmp3zdl6hd6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwuonlsia.pyomo.sol'
# Solver problem files: ('/tmp/tmpwuonlsia.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2020-11-28 14:00:00
#
# Solver log file: '/tmp/tmphlpx24jb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7cl0efdi.pyomo.sol'
# Solver problem files: ('/tmp/tmp7cl0efdi.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2020-11-28 14:20:00
#
# Solver log file: '/tmp/tmpx_picipa_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpw1nzdj5y.pyomo.sol'
# Solver problem files: ('/tmp/tmpw1nzdj5y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2020-11-28 14:40:00
#
# Solver log file: '/tmp/tmpyif91mlz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpcsw_i477.pyomo.sol'
# Solver problem files: ('/tmp/tmpcsw_i477.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2020-11-28 15:00:00
#
# Solver log file: '/tmp/tmp83v7b00y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxp719121.pyomo.sol'
# Solver problem files: ('/tmp/tmpxp719121.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2020-11-28 15:20:00
#
# Solver log file: '/tmp/tmpwl7n0fux_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpx224g57v.pyomo.sol'
# Solver problem files: ('/tmp/tmpx224g57v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2020-11-28 15:40:00
#
# Solver log file: '/tmp/tmpq993y8wn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpa1pfw_34.pyomo.sol'
# Solver problem files: ('/tmp/tmpa1pfw_34.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2020-11-28 16:00:00
#
# Solver log file: '/tmp/tmp1nvy4mam_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpazv2ysz2.pyomo.sol'
# Solver problem files: ('/tmp/tmpazv2ysz2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2020-11-28 16:20:00
#
# Solver log file: '/tmp/tmpsqbocmz9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdy0ap1oy.pyomo.sol'
# Solver problem files: ('/tmp/tmpdy0ap1oy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2020-11-28 16:40:00
#
# Solver log file: '/tmp/tmpzhfw_2oj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprtn5ckrp.pyomo.sol'
# Solver problem files: ('/tmp/tmprtn5ckrp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2020-11-28 17:00:00
#
# Solver log file: '/tmp/tmpukha62ew_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4ot3yptq.pyomo.sol'
# Solver problem files: ('/tmp/tmp4ot3yptq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2020-11-28 17:20:00
#
# Solver log file: '/tmp/tmpd_t0u_ao_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprq9fwxwp.pyomo.sol'
# Solver problem files: ('/tmp/tmprq9fwxwp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2020-11-28 17:40:00
#
# Solver log file: '/tmp/tmppxaszn0t_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0s2ew517.pyomo.sol'
# Solver problem files: ('/tmp/tmp0s2ew517.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2020-11-28 18:00:00
#
# Solver log file: '/tmp/tmph1_fta3y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfxt5j_qm.pyomo.sol'
# Solver problem files: ('/tmp/tmpfxt5j_qm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2020-11-28 18:20:00
#
# Solver log file: '/tmp/tmpf705xaxx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps9pmbbol.pyomo.sol'
# Solver problem files: ('/tmp/tmps9pmbbol.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2020-11-28 18:40:00
#
# Solver log file: '/tmp/tmp4a51kiev_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp52kflh0b.pyomo.sol'
# Solver problem files: ('/tmp/tmp52kflh0b.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2020-11-28 19:00:00
#
# Solver log file: '/tmp/tmpzy2nk37e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp547svtr0.pyomo.sol'
# Solver problem files: ('/tmp/tmp547svtr0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2020-11-28 19:20:00
#
# Solver log file: '/tmp/tmphh5ppu_e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpsbacpnje.pyomo.sol'
# Solver problem files: ('/tmp/tmpsbacpnje.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2020-11-28 19:40:00
#
# Solver log file: '/tmp/tmpudzpixlg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp55myw_n5.pyomo.sol'
# Solver problem files: ('/tmp/tmp55myw_n5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2020-11-28 20:00:00
#
# Solver log file: '/tmp/tmpxtez1vwr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8iulp6z_.pyomo.sol'
# Solver problem files: ('/tmp/tmp8iulp6z_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2020-11-28 20:20:00
#
# Solver log file: '/tmp/tmpjtugam_1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdiay5obc.pyomo.sol'
# Solver problem files: ('/tmp/tmpdiay5obc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2020-11-28 20:40:00
#
# Solver log file: '/tmp/tmpi2m95061_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5rryb71r.pyomo.sol'
# Solver problem files: ('/tmp/tmp5rryb71r.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2020-11-28 21:00:00
#
# Solver log file: '/tmp/tmpnoefh8lz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqsz_rq4f.pyomo.sol'
# Solver problem files: ('/tmp/tmpqsz_rq4f.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2020-11-28 21:20:00
#
# Solver log file: '/tmp/tmprid5teug_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr2xzglj6.pyomo.sol'
# Solver problem files: ('/tmp/tmpr2xzglj6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2020-11-28 21:40:00
#
# Solver log file: '/tmp/tmpv7xqqu0f_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp14ubwaqq.pyomo.sol'
# Solver problem files: ('/tmp/tmp14ubwaqq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2020-11-28 22:00:00
#
# Solver log file: '/tmp/tmpz68y0gqv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9pzfjkbj.pyomo.sol'
# Solver problem files: ('/tmp/tmp9pzfjkbj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2020-11-28 22:20:00
#
# Solver log file: '/tmp/tmpw2t5woko_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmyb5ncse.pyomo.sol'
# Solver problem files: ('/tmp/tmpmyb5ncse.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2020-11-28 22:40:00
#
# Solver log file: '/tmp/tmp5oce1gox_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1fulrskc.pyomo.sol'
# Solver problem files: ('/tmp/tmp1fulrskc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2020-11-28 23:00:00
#
# Solver log file: '/tmp/tmpwrfm91s__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv78wt8jd.pyomo.sol'
# Solver problem files: ('/tmp/tmpv78wt8jd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2020-11-28 23:20:00
#
# Solver log file: '/tmp/tmpiyqw_edr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpiw3_idod.pyomo.sol'
# Solver problem files: ('/tmp/tmpiw3_idod.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2020-11-28 23:40:00
#
# Solver log file: '/tmp/tmpys5kpicw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf8gl94zk.pyomo.sol'
# Solver problem files: ('/tmp/tmpf8gl94zk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2020-11-29 00:00:00
#
# Solver log file: '/tmp/tmp30l01rxv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfg8jkz85.pyomo.sol'
# Solver problem files: ('/tmp/tmpfg8jkz85.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1                          load   pv  fixed   tou   fit  ch_cost  dis_cost  \
# 2020-11-28 00:00:00  21516.525  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:20:00  20980.725  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 00:40:00  20486.500  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:00:00  20411.700  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-11-28 01:20:00  20345.575  0.0   0.25  0.16  0.11     0.02      0.01
# ...                        ...  ...    ...   ...   ...      ...       ...
# 2020-12-02 22:20:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 22:40:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:00:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:20:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
# 2020-12-02 23:40:00        NaN  0.0   0.25  0.16  0.11     0.02      0.01
#
#                      mode_0  mode_1  mode_2
# 2020-11-28 00:00:00       1       0       0
# 2020-11-28 00:20:00       1       0       0
# 2020-11-28 00:40:00       1       0       0
# 2020-11-28 01:00:00       1       0       0
# 2020-11-28 01:20:00       1       0       0
# ...                     ...     ...     ...
# 2020-12-02 22:20:00       1       0       0
# 2020-12-02 22:40:00       1       0       0
# 2020-12-02 23:00:00       1       0       0
# 2020-12-02 23:20:00       1       0       0
# 2020-12-02 23:40:00       1       0       0
#
# [360 rows x 10 columns]
#
# 0
# 2020-11-28 00:00:00
#
# Solver log file: '/tmp/tmpe9ac9yu7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpl9cu31k8.pyomo.sol'
# Solver problem files: ('/tmp/tmpl9cu31k8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2020-11-28 00:20:00
#
# Solver log file: '/tmp/tmpkyh11xd6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplzby4uk9.pyomo.sol'
# Solver problem files: ('/tmp/tmplzby4uk9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2020-11-28 00:40:00
#
# Solver log file: '/tmp/tmplpuy5ecz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpumc4sj0d.pyomo.sol'
# Solver problem files: ('/tmp/tmpumc4sj0d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2020-11-28 01:00:00
#
# Solver log file: '/tmp/tmpyn8vgcwu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpizctszsl.pyomo.sol'
# Solver problem files: ('/tmp/tmpizctszsl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2020-11-28 01:20:00
#
# Solver log file: '/tmp/tmpzh8eyy4k_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9rg6y5e_.pyomo.sol'
# Solver problem files: ('/tmp/tmp9rg6y5e_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2020-11-28 01:40:00
#
# Solver log file: '/tmp/tmpnqtz9toq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppkctggjh.pyomo.sol'
# Solver problem files: ('/tmp/tmppkctggjh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2020-11-28 02:00:00
#
# Solver log file: '/tmp/tmpprcu1oje_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4w51awc2.pyomo.sol'
# Solver problem files: ('/tmp/tmp4w51awc2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2020-11-28 02:20:00
#
# Solver log file: '/tmp/tmpx9gy62lu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt1pwc8iw.pyomo.sol'
# Solver problem files: ('/tmp/tmpt1pwc8iw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2020-11-28 02:40:00
#
# Solver log file: '/tmp/tmpwyf6_wqw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpoj7r23wh.pyomo.sol'
# Solver problem files: ('/tmp/tmpoj7r23wh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2020-11-28 03:00:00
#
# Solver log file: '/tmp/tmpt9uzusva_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkp4pd9xs.pyomo.sol'
# Solver problem files: ('/tmp/tmpkp4pd9xs.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2020-11-28 03:20:00
#
# Solver log file: '/tmp/tmpd1pgs3fq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpegealb4w.pyomo.sol'
# Solver problem files: ('/tmp/tmpegealb4w.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2020-11-28 03:40:00
#
# Solver log file: '/tmp/tmpnpbhldy7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd2rq7e2m.pyomo.sol'
# Solver problem files: ('/tmp/tmpd2rq7e2m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2020-11-28 04:00:00
#
# Solver log file: '/tmp/tmp3x86fl0e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkkjz7qyr.pyomo.sol'
# Solver problem files: ('/tmp/tmpkkjz7qyr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2020-11-28 04:20:00
#
# Solver log file: '/tmp/tmp569zxovt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdy69jyhm.pyomo.sol'
# Solver problem files: ('/tmp/tmpdy69jyhm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2020-11-28 04:40:00
#
# Solver log file: '/tmp/tmpq03wbl2w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp523l445z.pyomo.sol'
# Solver problem files: ('/tmp/tmp523l445z.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2020-11-28 05:00:00
#
# Solver log file: '/tmp/tmpl_iu84sy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt18qehfp.pyomo.sol'
# Solver problem files: ('/tmp/tmpt18qehfp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2020-11-28 05:20:00
#
# Solver log file: '/tmp/tmpw28abubu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpg5b0ko1y.pyomo.sol'
# Solver problem files: ('/tmp/tmpg5b0ko1y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2020-11-28 05:40:00
#
# Solver log file: '/tmp/tmpqhz0qt3y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_2wjow2l.pyomo.sol'
# Solver problem files: ('/tmp/tmp_2wjow2l.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2020-11-28 06:00:00
#
# Solver log file: '/tmp/tmpqb70oell_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpj39m1c01.pyomo.sol'
# Solver problem files: ('/tmp/tmpj39m1c01.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2020-11-28 06:20:00
#
# Solver log file: '/tmp/tmp4lrzt1v5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvgonmpfc.pyomo.sol'
# Solver problem files: ('/tmp/tmpvgonmpfc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2020-11-28 06:40:00
#
# Solver log file: '/tmp/tmpwhmkiwgz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0kjdsup8.pyomo.sol'
# Solver problem files: ('/tmp/tmp0kjdsup8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2020-11-28 07:00:00
#
# Solver log file: '/tmp/tmp34y63182_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkjuxeg8m.pyomo.sol'
# Solver problem files: ('/tmp/tmpkjuxeg8m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2020-11-28 07:20:00
#
# Solver log file: '/tmp/tmpn82objml_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpofl81b41.pyomo.sol'
# Solver problem files: ('/tmp/tmpofl81b41.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2020-11-28 07:40:00
#
# Solver log file: '/tmp/tmpz4sookfj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3o1fxt08.pyomo.sol'
# Solver problem files: ('/tmp/tmp3o1fxt08.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2020-11-28 08:00:00
#
# Solver log file: '/tmp/tmp7g_6i6qs_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp08llk_d1.pyomo.sol'
# Solver problem files: ('/tmp/tmp08llk_d1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2020-11-28 08:20:00
#
# Solver log file: '/tmp/tmpsehmd9k__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt7hyqg24.pyomo.sol'
# Solver problem files: ('/tmp/tmpt7hyqg24.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2020-11-28 08:40:00
#
# Solver log file: '/tmp/tmph0xcpyqn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5mw1tbt1.pyomo.sol'
# Solver problem files: ('/tmp/tmp5mw1tbt1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2020-11-28 09:00:00
#
# Solver log file: '/tmp/tmpwdgoteq5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp85tzlwky.pyomo.sol'
# Solver problem files: ('/tmp/tmp85tzlwky.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2020-11-28 09:20:00
#
# Solver log file: '/tmp/tmpzzh746us_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprbicnisw.pyomo.sol'
# Solver problem files: ('/tmp/tmprbicnisw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2020-11-28 09:40:00
#
# Solver log file: '/tmp/tmpv551o5vj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4gxorhb7.pyomo.sol'
# Solver problem files: ('/tmp/tmp4gxorhb7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2020-11-28 10:00:00
#
# Solver log file: '/tmp/tmpckt0jh3v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2r8obrob.pyomo.sol'
# Solver problem files: ('/tmp/tmp2r8obrob.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2020-11-28 10:20:00
#
# Solver log file: '/tmp/tmp2q3r8ckz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyngbbnk2.pyomo.sol'
# Solver problem files: ('/tmp/tmpyngbbnk2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2020-11-28 10:40:00
#
# Solver log file: '/tmp/tmp9eb66dg0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpj95ev2m6.pyomo.sol'
# Solver problem files: ('/tmp/tmpj95ev2m6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2020-11-28 11:00:00
#
# Solver log file: '/tmp/tmp9p_5z0_2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1x8w7m84.pyomo.sol'
# Solver problem files: ('/tmp/tmp1x8w7m84.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2020-11-28 11:20:00
#
# Solver log file: '/tmp/tmpwu87n5se_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptng854eg.pyomo.sol'
# Solver problem files: ('/tmp/tmptng854eg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2020-11-28 11:40:00
#
# Solver log file: '/tmp/tmp3zm2ws8a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptst9g_t9.pyomo.sol'
# Solver problem files: ('/tmp/tmptst9g_t9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2020-11-28 12:00:00
#
# Solver log file: '/tmp/tmp7g1ba5ht_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_13a78ap.pyomo.sol'
# Solver problem files: ('/tmp/tmp_13a78ap.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2020-11-28 12:20:00
#
# Solver log file: '/tmp/tmptkpqii_b_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6v57k8tq.pyomo.sol'
# Solver problem files: ('/tmp/tmp6v57k8tq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2020-11-28 12:40:00
#
# Solver log file: '/tmp/tmp7fr7owmw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8hptta1q.pyomo.sol'
# Solver problem files: ('/tmp/tmp8hptta1q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2020-11-28 13:00:00
#
# Solver log file: '/tmp/tmpukeuhvro_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp90qs9g4t.pyomo.sol'
# Solver problem files: ('/tmp/tmp90qs9g4t.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2020-11-28 13:20:00
#
# Solver log file: '/tmp/tmpch8xeza9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_5r8t4kv.pyomo.sol'
# Solver problem files: ('/tmp/tmp_5r8t4kv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2020-11-28 13:40:00
#
# Solver log file: '/tmp/tmpovgewfuy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbzmfbuv6.pyomo.sol'
# Solver problem files: ('/tmp/tmpbzmfbuv6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2020-11-28 14:00:00
#
# Solver log file: '/tmp/tmpoqfiwl6r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfcd7tzxv.pyomo.sol'
# Solver problem files: ('/tmp/tmpfcd7tzxv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2020-11-28 14:20:00
#
# Solver log file: '/tmp/tmpxvu63hs4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpti3phfdb.pyomo.sol'
# Solver problem files: ('/tmp/tmpti3phfdb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2020-11-28 14:40:00
#
# Solver log file: '/tmp/tmpvygngh4r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr42e93z2.pyomo.sol'
# Solver problem files: ('/tmp/tmpr42e93z2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2020-11-28 15:00:00
#
# Solver log file: '/tmp/tmp5bzw_vsp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjvu0azc0.pyomo.sol'
# Solver problem files: ('/tmp/tmpjvu0azc0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2020-11-28 15:20:00
#
# Solver log file: '/tmp/tmpp6uxd143_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4fn4qusu.pyomo.sol'
# Solver problem files: ('/tmp/tmp4fn4qusu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2020-11-28 15:40:00
#
# Solver log file: '/tmp/tmpyeyx1j2t_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2ulw33w7.pyomo.sol'
# Solver problem files: ('/tmp/tmp2ulw33w7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2020-11-28 16:00:00
#
# Solver log file: '/tmp/tmpt15p8eig_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpq4diaykd.pyomo.sol'
# Solver problem files: ('/tmp/tmpq4diaykd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2020-11-28 16:20:00
#
# Solver log file: '/tmp/tmp03zygc0r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_8pgfo3n.pyomo.sol'
# Solver problem files: ('/tmp/tmp_8pgfo3n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2020-11-28 16:40:00
#
# Solver log file: '/tmp/tmpmghbi_vw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpo5ht2644.pyomo.sol'
# Solver problem files: ('/tmp/tmpo5ht2644.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2020-11-28 17:00:00
#
# Solver log file: '/tmp/tmp8e49yajq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpcnpjrtoe.pyomo.sol'
# Solver problem files: ('/tmp/tmpcnpjrtoe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2020-11-28 17:20:00
#
# Solver log file: '/tmp/tmpfq4qpaxp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu0hvn4f8.pyomo.sol'
# Solver problem files: ('/tmp/tmpu0hvn4f8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2020-11-28 17:40:00
#
# Solver log file: '/tmp/tmpc6kvrj6b_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpign72o7v.pyomo.sol'
# Solver problem files: ('/tmp/tmpign72o7v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2020-11-28 18:00:00
#
# Solver log file: '/tmp/tmpjbt2tkhy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqvwjm8nt.pyomo.sol'
# Solver problem files: ('/tmp/tmpqvwjm8nt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2020-11-28 18:20:00
#
# Solver log file: '/tmp/tmpm792hzrr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpptcxcmqw.pyomo.sol'
# Solver problem files: ('/tmp/tmpptcxcmqw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2020-11-28 18:40:00
#
# Solver log file: '/tmp/tmpwh49i22f_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphu8pcxmj.pyomo.sol'
# Solver problem files: ('/tmp/tmphu8pcxmj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2020-11-28 19:00:00
#
# Solver log file: '/tmp/tmpltu_vie2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfr9q115z.pyomo.sol'
# Solver problem files: ('/tmp/tmpfr9q115z.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2020-11-28 19:20:00
#
# Solver log file: '/tmp/tmpph0i006w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdso2dca_.pyomo.sol'
# Solver problem files: ('/tmp/tmpdso2dca_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2020-11-28 19:40:00
#
# Solver log file: '/tmp/tmpc2584r8u_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbsjlwnjf.pyomo.sol'
# Solver problem files: ('/tmp/tmpbsjlwnjf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2020-11-28 20:00:00
#
# Solver log file: '/tmp/tmp76j5votx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptj8ofj7f.pyomo.sol'
# Solver problem files: ('/tmp/tmptj8ofj7f.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2020-11-28 20:20:00
#
# Solver log file: '/tmp/tmpwrhc3drv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9k5qdlib.pyomo.sol'
# Solver problem files: ('/tmp/tmp9k5qdlib.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2020-11-28 20:40:00
#
# Solver log file: '/tmp/tmpsozg4sxc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnp3x3yiy.pyomo.sol'
# Solver problem files: ('/tmp/tmpnp3x3yiy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2020-11-28 21:00:00
#
# Solver log file: '/tmp/tmpxdz5zgni_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc0j5uaok.pyomo.sol'
# Solver problem files: ('/tmp/tmpc0j5uaok.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2020-11-28 21:20:00
#
# Solver log file: '/tmp/tmpcttzvk2e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmi1ckji3.pyomo.sol'
# Solver problem files: ('/tmp/tmpmi1ckji3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2020-11-28 21:40:00
#
# Solver log file: '/tmp/tmpb_e4zkpr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps9ehmr1m.pyomo.sol'
# Solver problem files: ('/tmp/tmps9ehmr1m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2020-11-28 22:00:00
#
# Solver log file: '/tmp/tmph6wa8ayw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpw4z5paw1.pyomo.sol'
# Solver problem files: ('/tmp/tmpw4z5paw1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2020-11-28 22:20:00
#
# Solver log file: '/tmp/tmpm7h34hxu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgyw1g5b5.pyomo.sol'
# Solver problem files: ('/tmp/tmpgyw1g5b5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2020-11-28 22:40:00
#
# Solver log file: '/tmp/tmpbmgxrmyb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphmbh_g8g.pyomo.sol'
# Solver problem files: ('/tmp/tmphmbh_g8g.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2020-11-28 23:00:00
#
# Solver log file: '/tmp/tmpzk2dgoyt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr25q24kr.pyomo.sol'
# Solver problem files: ('/tmp/tmpr25q24kr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2020-11-28 23:20:00
#
# Solver log file: '/tmp/tmprmpu1lfl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfq9irvs2.pyomo.sol'
# Solver problem files: ('/tmp/tmpfq9irvs2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2020-11-28 23:40:00
#
# Solver log file: '/tmp/tmpqfkfaywe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptrnok5z7.pyomo.sol'
# Solver problem files: ('/tmp/tmptrnok5z7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2020-11-29 00:00:00
#
# Solver log file: '/tmp/tmphbppajwh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxj67ons7.pyomo.sol'
# Solver problem files: ('/tmp/tmpxj67ons7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1

# %%
plot_electrical3(mpc_results['2020-11-28'], sim='mbc')

# %%
# plot_thermal_combined2(mpc_results['2020-11-03'])

# %%
(mpc_results['p_im']+mpc_results['p_ex']).plot()
# Out:
# <AxesSubplot:>

# %%
mpc_sim['load'].isna().sum()
# Out:
# 0

# %%
drh.loc[start:end]['P1_Avg[W]'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
