# %% [markdown]
# # Voltage Regulation for DRH IFH and SBRC

# %% [markdown]
# This notebook contains simulations for the DRH and IFH peforming voltage regulation with battery and HVAC along with SBRC performing voltage regulation with just battery per phase

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.dae import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib
import numpy as np
import seaborn as sns
from sqlalchemy import create_engine
import pymysql
import datetime
#from datetime import datetime
import time
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing Data

# %% [markdown]
# **Specify start and end date of MPC simulations**

# %%
start = '2020-11-26'
end = '2020-11-27'
#end = '2020-12-4'
dt = 1/3
sim = 'DRH'
vr_start = '9:00:00'
vr_end = '16:00:00'

t_start = '9am'
t_end = '4pm'

#sb_phase = 'P1'

# %%
sim_start = 0
sim_end = 2200

# %% [markdown]
# **Import fixed time series data**

# %%
ts_data = pd.read_csv('CSV/5min_tariffs.csv', index_col=0)
ts_data.index = pd.to_datetime(ts_data.index, format='%H:%M:%S').time

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

weather = pd.read_sql(f'select * from thermal_comfort where date_ between "{start}" and "{end}"', con=db_connection)
weather.index = weather.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
weather = weather[['t_ext', 'ghi', 't_bed']]

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

power_balance = pd.read_sql(f'select * from power_balance where date_ between "{start}" and "{end}"', con=db_connection)
power_balance.index = power_balance.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
power_balance['pv'] = power_balance['pv_master'] + power_balance['pv_slave']

# %%
drh_1 = pd.read_csv('CSV/DRH SWBD - Hioki PW3360 30sec 20202010 to 20201218.CSV', skiprows=16)
drh_1.index = pd.to_datetime((drh_1['Date']), format='%d/%m/%Y %H:%M')

# %%
drh_2 = pd.read_csv('CSV/DRH SWBD - Hioki PW3360 30sec 20201218 to 20210118.CSV', skiprows=16)
drh_2.index = pd.to_datetime((drh_2['Date']), format='%d/%m/%Y %H:%M')

# %%
drh = pd.concat([drh_1, drh_2])
drh = drh.resample('5min').mean()

# %%
drh['P3_Avg[W]'].loc[start].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# ifh_1 = pd.read_csv('CSV/IFH SWBD - Hioki PW3198 30sec 20201020 to 20201124.CSV')
# ifh_1.index = pd.to_datetime((ifh_1['Date']+' '+ifh_1['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
# ifh_2 = pd.read_csv('CSV/IFH SWBD - Hioki PW3198 30sec 20201218 to 20210116.CSV')
# ifh_2.index = pd.to_datetime((ifh_2['Date']+' '+ifh_2['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
# ifh = pd.concat([ifh_1, ifh_2])

# %%
sbrc_1 = pd.read_csv('CSV/SBRC Incomer - Hioki PW3198 30sec 20201020 to 20201124.CSV')
sbrc_1.index = pd.to_datetime((sbrc_1['Date']+' '+sbrc_1['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
sbrc_2 = pd.read_csv('CSV/SBRC Incomer - Hioki PW3198 30sec 20201218 to 20210116.CSV')
sbrc_2.index = pd.to_datetime((sbrc_2['Date']+' '+sbrc_2['Time']), format='%Y/%m/%d %H:%M:%S')
# Out:
# /home/brendan/jupyter_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,19,20,37,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sbrc = pd.concat([sbrc_1, sbrc_2])
sbrc = sbrc.resample('5min').mean()

# %%
#sbrc.loc['2021-1-10']['AvgUrms1'].resample('5min').mean().plot()

# %%
pv_1 = pd.read_csv('CSV/SBRC Office PV - Hioki PW3360 30sec 20201023 to 20201213.CSV', skiprows=16)
pv_1 = pv_1.drop(pv_1.index[0])
pv_1['Date'] = [idx+':00' if i%2==0 else idx+':30' for i,idx in enumerate(pv_1['Date'])]
pv_1.index = pd.to_datetime((pv_1['Date']), format='%d/%m/%Y %H:%M:%S')

# %%
pv_2 = pd.read_csv('CSV/SBRC Office PV - Hioki PW3360 30sec 20201218 to 20210118.CSV', skiprows=16)
pv_2 = pv_2.drop(pv_2.index[0])
pv_2['Date'] = [idx+':00' if i%2==0 else idx+':30' for i,idx in enumerate(pv_2['Date'])]
pv_2.index = pd.to_datetime((pv_2['Date']), format='%d/%m/%Y %H:%M:%S')

# %%
pv = pd.concat([pv_1, pv_2])
pv = pv.resample('5min').mean()

# %%
if(sim=='DRH'):
    power_balance['pv'] = (power_balance['pv_master'] + power_balance['pv_slave'])
elif(sim=='IFH'):
    power_balance['pv'] = (power_balance['pv_master'] + power_balance['pv_slave'])*0.95

# %%
power_balance = power_balance.resample('5min').mean()

# %%
# power_balance['pv'] = power_balance['pv'].shift(-12, axis=0)
# power_balance.fillna(0, inplace=True)

# %% [markdown]
# **Build dataframe with all relevant data source to use in simulations**

# %%
#Join weather and power data frames
sim_data = weather.join(power_balance['pv'], how='inner')

# %%
#insert fixed time series data into df
for col in ts_data.columns:
    sim_data[col] = [ts_data[col].loc[idx]  for idx in sim_data.index.time]

# %%
sim_data['t_ext'] = sim_data['t_ext'].ewm(span = 24).mean()

# %%
m_cool, b_cool = np.polyfit(x=[20,25,30,35,40,45], y=[-10.24, -9.38, -8.41, -7.44, -5.16, -3.79], deg=1)

# %%
m_cop, b_cop = np.polyfit(x=[20,25,30,35,40,45], y=[3.59, 3.26, 2.85, 2.44, 2.15, 1.88], deg=1)

# %%
sim_data['cop'] = m_cop*(sim_data['t_ext']) + b_cop
sim_data['cool_cap'] = m_cool*sim_data['t_ext'] + b_cool

# %%
states = {'SoC_Av':31.27,
         'T_i': 25.57,
         'T_w': 23.32,
         'phi_h':0,
         'phi_c':0}

# %%
sim_data['load'].loc['2020-11-26 7:00:00']
# Out:
# 3010

# %% [markdown]
# ## DRH MPC Formulation

# %%
class MPC_DRH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 13.8
        self.min_soc = 0
        self.max_ch = 3000
        self.max_dis = 3000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 2.786
        self.C_w = 14.78
        self.C_i = 1.887
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 0.637
        self.A_w = 2.103
        self.COP = 3.69
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        return (self.m.cool_cap[t],0)
    
    
    def hp_min(self, m, t):
        return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
        #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
    def hp_max(self, m, t):
        return m.p_hvac[t] <= self.M*self.m.dhp[t]
        #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        return (21, 27)
        #return (23, 26)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# # IFH MPC Formulation

# %%
class MPC_IFH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 8.8
        self.min_soc = 0
        self.max_ch = 5000
        self.max_dis = 5000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        #return (self.m.cool_cap[t],0)
        return (-7,0)
    
    
#     def hp_min(self, m, t):
#         return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
#         #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
#     def hp_max(self, m, t):
#         return m.p_hvac[t] <= self.M*self.m.dhp[t]
#         #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        #return (23, 26)
        return (21, 27)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)
    
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# ## SBRC MPC Formulation

# %%
class MPC_SBRC():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.95
        self.n_dis = 0.95
        self.max_soc = 13.3
        self.min_soc = 0
        self.max_ch = 7500
        self.max_dis = 7500
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        


    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['fixed'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['fixed'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,100000), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(-100000,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)


    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  



    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        #return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]
    
    def dischargeBalance(self, m,t):
        return self.m.p_dis[t] == self.m.p_dis_l[t] + self.m.p_dis_g[t]

    def pvCharge(self, m,t):
        return -self.m.p_ch_p[t] <= self.m.p_pv[t]
    
    
    def gridDischarge(self, m,t):
        return self.m.p_dis_g[t] >= self.m.p_load[t]
    


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
#         discretizer = TransformationFactory('dae.finite_difference')
#         discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %%
def extract_pyomo_electrical_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    df['p_im'] = list(m.p_im.get_values().values())
    df['p_ex'] = list(m.p_ex.get_values().values())
    df['p_ch'] = list(m.p_ch.get_values().values())
    df['p_ch_p'] = list(m.p_ch_p.get_values().values())
    df['p_ch_g'] = list(m.p_ch_g.get_values().values())
    df['p_dis'] = list(m.p_dis.get_values().values())
    df['soc'] = list(m.soc.get_values().values())
    
    return df

# %%
def extract_pyomo_thermal_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    #df['phi_h_heat'] = list(m.phi_h_heat.get_values().values())
    df['phi_h_cool'] = list(m.phi_h_cool.get_values().values())
    df['p_hvac'] = list(m.p_hvac.get_values().values())
    df['T_i'] = list(m.T_i.get_values().values())
    df['T_w'] = list(m.T_w.get_values().values())
    
    return df

# %%
def plot_electrical3(df_results, sim):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    
    fig = plt.figure(figsize=(12,8))
    
    gs=GridSpec(3,1) # 2 rows, 3 columns

    ax1=fig.add_subplot(gs[0,0]) # First row, first column
    ax2=fig.add_subplot(gs[1:,0]) # First row, second column

    
    load =  ax2.plot(df_results.index, df_results['load'], label='$p_i^l$', lw=1, color='red', ls=(0, (3, 1, 1, 1)))
    pv =  ax2.plot(df_results.index, df_results['pv'], label='$p_i^p$', lw=1, color='blue', ls=(0, (5, 5)))
    im =  ax2.plot(df_results.index, df_results['p_im'], label='$p_i^i$', lw=1, color='grey', ls='-.')
    ex =  ax2.plot(df_results.index, df_results['p_ex'], label='$p_i^e$', lw=1, color='orange', ls=(0, (3, 1, 1, 1, 1, 1)))
    ch =  ax2.plot(df_results.index, df_results['p_ch'], label='$p_i^c$', lw=1.5,color='black', ls='dotted')
    dis =  ax2.plot(df_results.index, df_results['p_dis'], label='$p_i^d$', lw=1, color='green')
    hvac = ax2.plot(df_results.index, df_results['p_hvac'], label='$p_i^h$', lw=1, color='purple', ls=(0, (5, 1)))
    #ax2.set_ylim(-6000,12000)
    ax2.set_ylim(-30000,30000)
     
    soc = ax1.plot(df_results.index, df_results['soc'], label='$SoC$', lw=1, color='blue', ls='--')
    ax1.set_ylim(-10,120)
    
    ax3 = ax1.twinx()
    ax3.set_ylabel('Cost ($/kWh)')
    ax3.set_ylim(0,0.4)
    tou = ax3.plot(df_results.index, df_results['tou'], label='$ToU$', lw=1, color='red',)
    ax3.grid()
    
    ax2.set_xlabel('Date')
    ax1.set_ylabel('SoC (%)')
    ax1.get_shared_x_axes().join(ax1, ax2)
    ax1.set_xticklabels([])
    ax2.set_ylabel('Power (W)')
    
    ax2.legend(loc="upper left", ncol=7)
    ax1.legend(loc="upper left")
    ax3.legend(loc="upper right")
    ax1.autoscale(enable=True, axis='x', tight=True)

# %%
def plot_thermal_combined2(mpc_data):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    fig, ax = plt.subplots(2, sharex=True)
    ax[0].set_ylabel('Indoor Temperature ($^\circ$C)')
    ax[0].set_ylim(15,45)
    ax[0].plot(mpc_data.index, mpc_data['T_i'], color='red', lw=2, ls='--')
    #ax[0].plot(mpc_data.index, rbc_data['T_i'], color='black', lw=2, ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[0].plot(mpc_data.index, mpc_data['t_ext'], color='green', ls='-.')
    #ax[0].plot(mpc_data.index, mpc_data['t_bed'])
    ax[0].plot(mpc_data.index, mpc_data['set_point'], color='grey')
    ax[0].legend(['MPC $T_i^i$', 'RBC $T_i^i$', '$T_a$', 'Set Point'], loc="upper left", ncol=4)
    
    
    
    #Plot Results
    
    ax[1].set_xlabel('Date')
    ax[1].set_ylabel('Cooling (kW) \n Solar Irradiance (kW/m$^2$)')
    ax[1].set_ylim(0,15)
    #ax1.plot(df_results.index, df_results['phi_h_heat'], color='red')
    ax[1].plot(mpc_data.index, -mpc_data['phi_h_cool'], color='red', alpha=0.75, )
    #ax[1].plot(mpc_data.index, -rbc_data['phi_h_cool'], color= 'black', ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[1].plot(mpc_data.index, mpc_data['ghi']/1000, color='blue', ls='--')
    ax[1].legend(['MPC $\Phi_i^c$', 'RPC $\Phi_i^c$', 'GHI'], loc="upper left", ncol=3)



    fig.tight_layout()
    fig.set_figheight(7.5)
    fig.set_figwidth(12)# otherwise the right y-label is slightly clipped
    #ax.grid()
    
    #plt.savefig('thermal_mpc_rbc.pdf')
    ax[0].autoscale(enable=True, axis='x', tight=True)
    ax[1].autoscale(enable=True, axis='x', tight=True)
    plt.show()

# %% [markdown]
# ## Solve MPC

# %%
mpc_data = sim_data.loc[start:end].resample('20min').mean().dropna()

# %%
# if(sim=='DRH'):
#     mpc_data['pv'] = mpc_data['pv'].shift(-3, axis=0)
#     mpc_data['pv'].fillna(0, inplace=True)

# %%
mpc_data['mode_0'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 0
mpc_data['mode_1'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 1

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
Np = 24

# %%
for i, idx in enumerate(mpc_data.index):
    print('\n' + str(i) + '\n' + str(idx) + '\n')
    mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()

    mpc = MPC_DRH(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
    mpc.solve()

    mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
    mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)

    mpc_results_first_step = mpc_sim.iloc[0].copy()
    mpc_results.iloc[i] = mpc_results_first_step
    
    #states = {'SoC_Av':mpc_sim['soc'].iloc[0]}
    
#     states = {'SoC_Av':mpc_sim['soc'].iloc[0],
#               'T_i':mpc_sim['T_i'].iloc[1],
#               'T_w':mpc_sim['T_w'].iloc[1],
#               'phi_h':mpc_sim['phi_h_heat'].iloc[1],
#               'phi_c':mpc_sim['phi_h_cool'].iloc[1]}
    
    states = {'SoC_Av':mpc_sim['soc'].iloc[0],
              'T_i':mpc_sim['T_i'].iloc[1],
              'T_w':mpc_sim['T_w'].iloc[1],
              'phi_c':mpc_sim['phi_h_cool'].iloc[1]}

    
    if(i==72):
        break 
#     if(i==500):
#         break
# Out:
# 0
# 2020-11-26 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpyoiflrim_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxyavphnl.pyomo.sol'
# Solver problem files: ('/tmp/tmpxyavphnl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2020-11-26 00:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmprzc9j9pu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp33q_ssb2.pyomo.sol'
# Solver problem files: ('/tmp/tmp33q_ssb2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2020-11-26 00:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpaaa81c8r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8vdab3ik.pyomo.sol'
# Solver problem files: ('/tmp/tmp8vdab3ik.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2020-11-26 01:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpt5hs3mw2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7why4n_e.pyomo.sol'
# Solver problem files: ('/tmp/tmp7why4n_e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2020-11-26 01:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp8ap8w7ue_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpaw556r0b.pyomo.sol'
# Solver problem files: ('/tmp/tmpaw556r0b.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2020-11-26 01:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpo_nilkhh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpm8j2o4wq.pyomo.sol'
# Solver problem files: ('/tmp/tmpm8j2o4wq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2020-11-26 02:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmprbv43m7o_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8wm72ksc.pyomo.sol'
# Solver problem files: ('/tmp/tmp8wm72ksc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2020-11-26 02:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpweltn316_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyubfij01.pyomo.sol'
# Solver problem files: ('/tmp/tmpyubfij01.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2020-11-26 02:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpokz1y2t5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkuuxo7k5.pyomo.sol'
# Solver problem files: ('/tmp/tmpkuuxo7k5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2020-11-26 03:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpf0dhiz06_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7yx7d0k0.pyomo.sol'
# Solver problem files: ('/tmp/tmp7yx7d0k0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2020-11-26 03:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpfcxa75qg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpuiqm53lk.pyomo.sol'
# Solver problem files: ('/tmp/tmpuiqm53lk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2020-11-26 03:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpw7g5tqe0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpibugymip.pyomo.sol'
# Solver problem files: ('/tmp/tmpibugymip.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2020-11-26 04:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmptwl1g63m_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbg4jz4oy.pyomo.sol'
# Solver problem files: ('/tmp/tmpbg4jz4oy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2020-11-26 04:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmppecmsu2l_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvjgo13g2.pyomo.sol'
# Solver problem files: ('/tmp/tmpvjgo13g2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2020-11-26 04:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpln9onpm2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxoh0gfl2.pyomo.sol'
# Solver problem files: ('/tmp/tmpxoh0gfl2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2020-11-26 05:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpe82y282u_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppqo47keb.pyomo.sol'
# Solver problem files: ('/tmp/tmppqo47keb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2020-11-26 05:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpsc9206uz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps43bbdhf.pyomo.sol'
# Solver problem files: ('/tmp/tmps43bbdhf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2020-11-26 05:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmps6cohmoe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnjv8wh03.pyomo.sol'
# Solver problem files: ('/tmp/tmpnjv8wh03.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2020-11-26 06:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp73zdbuag_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp7da6aom.pyomo.sol'
# Solver problem files: ('/tmp/tmpp7da6aom.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2020-11-26 06:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpfx94cn3g_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpysbt7hmk.pyomo.sol'
# Solver problem files: ('/tmp/tmpysbt7hmk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2020-11-26 06:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp20e89ckm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgkqm2dpz.pyomo.sol'
# Solver problem files: ('/tmp/tmpgkqm2dpz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2020-11-26 07:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp5nvsyppu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpl9drc50y.pyomo.sol'
# Solver problem files: ('/tmp/tmpl9drc50y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2020-11-26 07:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6o_o9_nj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplwqibbf0.pyomo.sol'
# Solver problem files: ('/tmp/tmplwqibbf0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2020-11-26 07:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpwki6dh42_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgzf9l3wr.pyomo.sol'
# Solver problem files: ('/tmp/tmpgzf9l3wr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2020-11-26 08:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpqqqkvr82_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdgi0mp_k.pyomo.sol'
# Solver problem files: ('/tmp/tmpdgi0mp_k.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2020-11-26 08:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphi8iii1b_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu3088vk4.pyomo.sol'
# Solver problem files: ('/tmp/tmpu3088vk4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2020-11-26 08:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpgigd6i6w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5bikk0tw.pyomo.sol'
# Solver problem files: ('/tmp/tmp5bikk0tw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2020-11-26 09:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_0if5h7v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpa8zj23pa.pyomo.sol'
# Solver problem files: ('/tmp/tmpa8zj23pa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2020-11-26 09:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpvqdygc_l_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyo2l4rcy.pyomo.sol'
# Solver problem files: ('/tmp/tmpyo2l4rcy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2020-11-26 09:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp5p216ah__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1c9txrgg.pyomo.sol'
# Solver problem files: ('/tmp/tmp1c9txrgg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2020-11-26 10:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkzs72dj3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdpvux1ue.pyomo.sol'
# Solver problem files: ('/tmp/tmpdpvux1ue.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2020-11-26 10:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp4793e3fw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjxjr3qv0.pyomo.sol'
# Solver problem files: ('/tmp/tmpjxjr3qv0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2020-11-26 10:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpvdlbgh9w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6btcijkw.pyomo.sol'
# Solver problem files: ('/tmp/tmp6btcijkw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2020-11-26 11:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpzgg8egi1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc1dqcocs.pyomo.sol'
# Solver problem files: ('/tmp/tmpc1dqcocs.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2020-11-26 11:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmporn1rfsi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpac2ri1xw.pyomo.sol'
# Solver problem files: ('/tmp/tmpac2ri1xw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2020-11-26 11:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpmzi1djc8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnuol58cz.pyomo.sol'
# Solver problem files: ('/tmp/tmpnuol58cz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2020-11-26 12:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpk4krhyda_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqbh7_cdf.pyomo.sol'
# Solver problem files: ('/tmp/tmpqbh7_cdf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2020-11-26 12:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphzk8hc5u_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphegk201g.pyomo.sol'
# Solver problem files: ('/tmp/tmphegk201g.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2020-11-26 12:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp437k8dl__gurobi_ampl.log'
# Solver solution file: '/tmp/tmppcp5w6bp.pyomo.sol'
# Solver problem files: ('/tmp/tmppcp5w6bp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2020-11-26 13:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp8akfhi2p_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp90i2s6e5.pyomo.sol'
# Solver problem files: ('/tmp/tmp90i2s6e5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2020-11-26 13:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp9g987tk__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv_qq2mym.pyomo.sol'
# Solver problem files: ('/tmp/tmpv_qq2mym.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2020-11-26 13:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmps223evcn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2230img1.pyomo.sol'
# Solver problem files: ('/tmp/tmp2230img1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2020-11-26 14:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjcrl8h8t_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplgugfif7.pyomo.sol'
# Solver problem files: ('/tmp/tmplgugfif7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2020-11-26 14:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbje6wuvq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp35haz3tb.pyomo.sol'
# Solver problem files: ('/tmp/tmp35haz3tb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2020-11-26 14:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpymkpbxr5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjn_kcuw2.pyomo.sol'
# Solver problem files: ('/tmp/tmpjn_kcuw2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2020-11-26 15:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp64z43d_5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpis02u_ed.pyomo.sol'
# Solver problem files: ('/tmp/tmpis02u_ed.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2020-11-26 15:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp8s0aqy2v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5ludj893.pyomo.sol'
# Solver problem files: ('/tmp/tmp5ludj893.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2020-11-26 15:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpf3lys8i5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1wf21be7.pyomo.sol'
# Solver problem files: ('/tmp/tmp1wf21be7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2020-11-26 16:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpgdpaiurw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpw9dsn78a.pyomo.sol'
# Solver problem files: ('/tmp/tmpw9dsn78a.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2020-11-26 16:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphv9lgaod_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkvwdz6xr.pyomo.sol'
# Solver problem files: ('/tmp/tmpkvwdz6xr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2020-11-26 16:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpvtay1jge_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt234lh9j.pyomo.sol'
# Solver problem files: ('/tmp/tmpt234lh9j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2020-11-26 17:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbuescgaz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2azzhkpq.pyomo.sol'
# Solver problem files: ('/tmp/tmp2azzhkpq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2020-11-26 17:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjq9xshfk_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp72x_ec13.pyomo.sol'
# Solver problem files: ('/tmp/tmp72x_ec13.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2020-11-26 17:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp7it0as_d_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp56ehhtz0.pyomo.sol'
# Solver problem files: ('/tmp/tmp56ehhtz0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2020-11-26 18:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6vtk7iue_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgamj1sgz.pyomo.sol'
# Solver problem files: ('/tmp/tmpgamj1sgz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2020-11-26 18:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpe2us7h3z_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpobc52vbk.pyomo.sol'
# Solver problem files: ('/tmp/tmpobc52vbk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2020-11-26 18:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpf2ydvu8y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8othywa0.pyomo.sol'
# Solver problem files: ('/tmp/tmp8othywa0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2020-11-26 19:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpg_cxrgbb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr6v6zivd.pyomo.sol'
# Solver problem files: ('/tmp/tmpr6v6zivd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2020-11-26 19:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp0nkzns_c_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0ccdgsdx.pyomo.sol'
# Solver problem files: ('/tmp/tmp0ccdgsdx.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2020-11-26 19:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp9ytnbg_d_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpscv5_erp.pyomo.sol'
# Solver problem files: ('/tmp/tmpscv5_erp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2020-11-26 20:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpy220fwox_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3l0ptggl.pyomo.sol'
# Solver problem files: ('/tmp/tmp3l0ptggl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2020-11-26 20:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpmue6t57__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6fhgnh1y.pyomo.sol'
# Solver problem files: ('/tmp/tmp6fhgnh1y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2020-11-26 20:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpn9nutqin_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6mtym0pf.pyomo.sol'
# Solver problem files: ('/tmp/tmp6mtym0pf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2020-11-26 21:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkquhioqb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp91jje_u.pyomo.sol'
# Solver problem files: ('/tmp/tmpp91jje_u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2020-11-26 21:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpt9qsmnzb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpin21ki3j.pyomo.sol'
# Solver problem files: ('/tmp/tmpin21ki3j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2020-11-26 21:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpwe_ax6t__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8r25iaqv.pyomo.sol'
# Solver problem files: ('/tmp/tmp8r25iaqv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2020-11-26 22:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpal3oaqlv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpte0cbwyz.pyomo.sol'
# Solver problem files: ('/tmp/tmpte0cbwyz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2020-11-26 22:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmptlzw_h05_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt3ipjkie.pyomo.sol'
# Solver problem files: ('/tmp/tmpt3ipjkie.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2020-11-26 22:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp8uemu0xw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp07s1nchf.pyomo.sol'
# Solver problem files: ('/tmp/tmp07s1nchf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2020-11-26 23:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp9ymnilj2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_8yt36ez.pyomo.sol'
# Solver problem files: ('/tmp/tmp_8yt36ez.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2020-11-26 23:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpdzymh8hq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpti8ngh0g.pyomo.sol'
# Solver problem files: ('/tmp/tmpti8ngh0g.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2020-11-26 23:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbr7ihf5x_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvhnwhyn8.pyomo.sol'
# Solver problem files: ('/tmp/tmpvhnwhyn8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2020-11-27 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpl7i4z1oh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc8scuvf_.pyomo.sol'
# Solver problem files: ('/tmp/tmpc8scuvf_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1

# %%
mpc_results.to_csv(f'Results/VRmode_20min_{sim}_{start}_{t_start}_{t_end}.csv')

# %% [markdown]
# # SBRC Simulations

# %%
def sbrc_mpc_df(sb_phase):
    sbrc_pv = pd.DataFrame()
    
    sbrc_power = pd.DataFrame(index=pv.loc[start:end].index)
    sbrc_power['p'] = list(sbrc.loc['2020-11-04':'2020-11-05'][f'Avg{sb_phase}'])
    
    if(sb_phase == 'P1'):
        sbrc_pv['load'] = (sbrc_power['p'] - pv.loc[start:end][f'{sb_phase}_Avg[W]'] - drh.loc[start:end]['P1_Avg[W]'])
    elif(sb_phase == 'P3'):
        sbrc_pv['load'] = (sbrc_power['p']- pv.loc[start:end][f'{sb_phase}_Avg[W]'] + power_balance['pv'])
    else:
        sbrc_pv['load'] = (sbrc_power['p']- pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = -(pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = [0 if pv_val < 0 else pv_val for pv_val in sbrc_pv['pv']]

    sbrc_pv = sbrc_pv.resample('20min').mean()

    for col in ['fixed', 'tou', 'fit', 'ch_cost', 'dis_cost', 'mode_0', 'mode_1']:
        sbrc_pv[col] = [ts_data[col].loc[idx]  for idx in sbrc_pv.index.time]
        
        
    return sbrc_pv

# %% [markdown]
# ## Simulate MPC Each Pahse SBRC

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
states = {'SoC_Av':20}

# %%
mpc_data
# Out:
#                          t_ext  ghi   t_bed   pv  fixed   tou   fit  ch_cost  \
# 2020-11-26 00:00:00  18.956933  0.0  27.010  0.0   0.25  0.16  0.11     0.02
# 2020-11-26 00:20:00  19.127569  0.0  26.925  0.0   0.25  0.16  0.11     0.02
# 2020-11-26 00:40:00  19.188581  0.0  26.865  0.0   0.25  0.16  0.11     0.02
# 2020-11-26 01:00:00  19.161549  0.0  26.810  0.0   0.25  0.16  0.11     0.02
# 2020-11-26 01:20:00  19.121089  0.0  26.735  0.0   0.25  0.16  0.11     0.02
# ...                        ...  ...     ...  ...    ...   ...   ...      ...
# 2020-11-27 22:20:00  21.165380  0.0  28.720  0.0   0.25  0.16  0.11     0.02
# 2020-11-27 22:40:00  21.362091  0.0  28.685  0.0   0.25  0.16  0.11     0.02
# 2020-11-27 23:00:00  21.590783  0.0  28.645  0.0   0.25  0.16  0.11     0.02
# 2020-11-27 23:20:00  21.584475  0.0  28.615  0.0   0.25  0.16  0.11     0.02
# 2020-11-27 23:40:00  21.609230  0.0  28.590  0.0   0.25  0.16  0.11     0.02
#
#                      dis_cost  mode_0  ...  mode_2  set_point  sp_soft  \
# 2020-11-26 00:00:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-26 00:20:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-26 00:40:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-26 01:00:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-26 01:20:00      0.01     1.0  ...     0.0       25.0     10.0
# ...                       ...     ...  ...     ...        ...      ...
# 2020-11-27 22:20:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-27 22:40:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-27 23:00:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-27 23:20:00      0.01     1.0  ...     0.0       25.0     10.0
# 2020-11-27 23:40:00      0.01     1.0  ...     0.0       25.0     10.0
#
#                      heat_gains  load_sim  load1  heat_gains0    load  \
# 2020-11-26 00:00:00         0.5     300.0  500.0          0.0  330.50
# 2020-11-26 00:20:00         0.5     300.0  500.0          0.0  331.25
# 2020-11-26 00:40:00         0.5     300.0  500.0          0.0  329.75
# 2020-11-26 01:00:00         0.5     300.0  500.0          0.0  333.00
# 2020-11-26 01:20:00         0.5     300.0  500.0          0.0  328.50
# ...                         ...       ...    ...          ...     ...
# 2020-11-27 22:20:00         0.7     300.0  400.0          0.0  630.00
# 2020-11-27 22:40:00         0.7     300.0  400.0          0.0  634.50
# 2020-11-27 23:00:00         0.5     300.0  400.0          0.0  331.25
# 2020-11-27 23:20:00         0.5     300.0  400.0          0.0  321.00
# 2020-11-27 23:40:00         0.5     300.0  400.0          0.0  324.25
#
#                           cop   cool_cap
# 2020-11-26 00:00:00  3.646110 -10.953939
# 2020-11-26 00:20:00  3.634127 -10.909203
# 2020-11-26 00:40:00  3.629842 -10.893207
# 2020-11-26 01:00:00  3.631740 -10.900294
# 2020-11-26 01:20:00  3.634582 -10.910902
# ...                       ...        ...
# 2020-11-27 22:20:00  3.491014 -10.374947
# 2020-11-27 22:40:00  3.477199 -10.323375
# 2020-11-27 23:00:00  3.461139 -10.263418
# 2020-11-27 23:20:00  3.461582 -10.265072
# 2020-11-27 23:40:00  3.459843 -10.258582
#
# [144 rows x 21 columns]

# %%
# for ph in ['P1', 'P2', 'P3']:
    
#     mpc_data = sbrc_mpc_df(ph)
    
#     mpc_data['mode_0'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 0
#     mpc_data['mode_1'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 1
    
#     print(mpc_data)
    
#     ##------VR MODE--------##
# #     mpc_data.loc[end,'mode_0'] = 1
# #     mpc_data.loc[end,'mode_1'] = 0
    
#     ##------ECO MODE--------##
# #     mpc_data['mode_0'] = 1
# #     mpc_data['mode_1'] = 0
  
#     for i, idx in enumerate(mpc_data.index):
#         print('\n' + str(i) + '\n' + str(idx) + '\n')
#         mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()
        
#         mpc = MPC_SBRC(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
#         mpc.solve()

#         mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
# #         #mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)
        
#         #print(mpc_sim)

#         mpc_results_first_step = mpc_sim.iloc[0].copy()
#         mpc_results.iloc[i] = mpc_results_first_step

#         states = {'SoC_Av':mpc_sim['soc'].iloc[0]}


#         if(i==72):
#             break
    
#     mpc_results.to_csv(f'Results/VRmode_20min_SBRC_{ph}_{start}_{t_start}_{t_end}.csv')
#     states = {'SoC_Av':20}

# %%
#sbrc_pv['pv'].plot()

# %%
plot_electrical3(mpc_results['2020-11-26'], sim='mbc')

# %%
# plot_thermal_combined2(mpc_results['2020-11-03'])

# %%
mpc_results['pv'].plot()
# Out:
# <AxesSubplot:>
