# %% [markdown]
# # Voltage Regulation for DRH IFH and SBRC

# %% [markdown]
# This notebook contains simulations for the DRH and IFH peforming voltage regulation with battery and HVAC along with SBRC performing voltage regulation with just battery per phase

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.dae import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib
import numpy as np
import seaborn as sns
from sqlalchemy import create_engine
import pymysql
import datetime
#from datetime import datetime
import time
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing Data

# %% [markdown]
# **Specify start and end date of MPC simulations**

# %%
start = '2021-1-10'
end = '2021-1-11'
#end = '2020-12-4'
dt = 1/3
sim = 'DRH'
vr_start = '9:00:00'
vr_end = '16:00:00'

t_start = '9am'
t_end = '4pm'

#sb_phase = 'P1'

# %%
sim_start = 0
sim_end = 2200

# %% [markdown]
# **Import fixed time series data**

# %%
ts_data = pd.read_csv('CSV/5min_tariffs.csv', index_col=0)
ts_data.index = pd.to_datetime(ts_data.index, format='%H:%M:%S').time

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

weather = pd.read_sql(f'select * from thermal_comfort where date_ between "{start}" and "{end}"', con=db_connection)
weather.index = weather.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
weather = weather[['t_ext', 'ghi', 't_bed']]

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

power_balance = pd.read_sql(f'select * from power_balance where date_ between "{start}" and "{end}"', con=db_connection)
power_balance.index = power_balance.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
power_balance['pv'] = power_balance['pv_master'] + power_balance['pv_slave']

# %%
drh_1 = pd.read_csv('CSV/DRH SWBD - Hioki PW3360 30sec 20202010 to 20201218.CSV', skiprows=16)
drh_1.index = pd.to_datetime((drh_1['Date']), format='%d/%m/%Y %H:%M')

# %%
drh_2 = pd.read_csv('CSV/DRH SWBD - Hioki PW3360 30sec 20201218 to 20210118.CSV', skiprows=16)
drh_2.index = pd.to_datetime((drh_2['Date']), format='%d/%m/%Y %H:%M')

# %%
drh = pd.concat([drh_1, drh_2])

# %%
ifh_1 = pd.read_csv('CSV/IFH SWBD - Hioki PW3198 30sec 20201020 to 20201124.CSV')
ifh_1.index = pd.to_datetime((ifh_1['Date']+' '+ifh_1['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
ifh_2 = pd.read_csv('CSV/IFH SWBD - Hioki PW3198 30sec 20201218 to 20210116.CSV')
ifh_2.index = pd.to_datetime((ifh_2['Date']+' '+ifh_2['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
ifh = pd.concat([ifh_1, ifh_2])

# %%
sbrc_1 = pd.read_csv('CSV/SBRC Incomer - Hioki PW3198 30sec 20201020 to 20201124.CSV')
sbrc_1.index = pd.to_datetime((sbrc_1['Date']+' '+sbrc_1['Time']), format='%Y/%m/%d %H:%M:%S')

# %%
sbrc_2 = pd.read_csv('CSV/SBRC Incomer - Hioki PW3198 30sec 20201218 to 20210116.CSV')
sbrc_2.index = pd.to_datetime((sbrc_2['Date']+' '+sbrc_2['Time']), format='%Y/%m/%d %H:%M:%S')
# Out:
# /home/brendan/jupyter_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,19,20,37,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sbrc = pd.concat([sbrc_1, sbrc_2])

# %%
#sbrc.loc['2021-1-10']['AvgUrms1'].resample('5min').mean().plot()

# %%
pv_1 = pd.read_csv('CSV/SBRC Office PV - Hioki PW3360 30sec 20201023 to 20201213.CSV', skiprows=16)
pv_1 = pv_1.drop(pv_1.index[0])
pv_1['Date'] = [idx+':00' if i%2==0 else idx+':30' for i,idx in enumerate(pv_1['Date'])]
pv_1.index = pd.to_datetime((pv_1['Date']), format='%d/%m/%Y %H:%M:%S')

# %%
pv_2 = pd.read_csv('CSV/SBRC Office PV - Hioki PW3360 30sec 20201218 to 20210118.CSV', skiprows=16)
pv_2 = pv_2.drop(pv_2.index[0])
pv_2['Date'] = [idx+':00' if i%2==0 else idx+':30' for i,idx in enumerate(pv_2['Date'])]
pv_2.index = pd.to_datetime((pv_2['Date']), format='%d/%m/%Y %H:%M:%S')

# %%
pv = pd.concat([pv_1, pv_2])

# %%
if(sim=='DRH'):
    power_balance['pv'] = (power_balance['pv_master'] + power_balance['pv_slave'])
elif(sim=='IFH'):
    power_balance['pv'] = -ifh.loc[start:end]['AvgP2']

# %%
(power_balance['pv_master'] + power_balance['pv_slave']).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Build dataframe with all relevant data source to use in simulations**

# %%
#Join weather and power data frames
sim_data = weather.join(power_balance['pv'], how='inner')

# %%
#insert fixed time series data into df
for col in ts_data.columns:
    sim_data[col] = [ts_data[col].loc[idx]  for idx in sim_data.index.time]

# %%
sim_data['t_ext'] = sim_data['t_ext'].ewm(span = 24).mean()

# %%
m_cool, b_cool = np.polyfit(x=[20,25,30,35,40,45], y=[-10.24, -9.38, -8.41, -7.44, -5.16, -3.79], deg=1)

# %%
m_cop, b_cop = np.polyfit(x=[20,25,30,35,40,45], y=[3.59, 3.26, 2.85, 2.44, 2.15, 1.88], deg=1)

# %%
sim_data['cop'] = m_cop*(sim_data['t_ext']) + b_cop
sim_data['cool_cap'] = m_cool*sim_data['t_ext'] + b_cool

# %%
states = {'SoC_Av':20,
         'T_i': 24,
         'T_w': 23,
         'phi_h':0,
         'phi_c':0}

# %% [markdown]
# ## DRH MPC Formulation

# %%
class MPC_DRH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 13.8
        self.min_soc = 0
        self.max_ch = 3000
        self.max_dis = 3000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 2.786
        self.C_w = 14.78
        self.C_i = 1.887
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 0.637
        self.A_w = 2.103
        self.COP = 3.69
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        return (self.m.cool_cap[t],0)
    
    
    def hp_min(self, m, t):
        return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
        #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
    def hp_max(self, m, t):
        return m.p_hvac[t] <= self.M*self.m.dhp[t]
        #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        return (21, 27)
        #return (23, 26)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# # IFH MPC Formulation

# %%
class MPC_IFH():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 8.8
        self.min_soc = 0
        self.max_ch = 5000
        self.max_dis = 5000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
#         self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
#         self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        #return (self.m.cool_cap[t],0)
        return (-7,0)
    
    
#     def hp_min(self, m, t):
#         return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
#         #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
#     def hp_max(self, m, t):
#         return m.p_hvac[t] <= self.M*self.m.dhp[t]
#         #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        #return (23, 26)
        return (21, 27)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.25*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)
    
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %% [markdown]
# ## SBRC MPC Formulation

# %%
class MPC_SBRC():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.95
        self.n_dis = 0.95
        self.max_soc = 13.3
        self.min_soc = 0
        self.max_ch = 7500
        self.max_dis = 7500
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 6.54
        self.C_w = 6.72
        self.C_i = 3.39
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 1.15
        self.A_w = 2.91
        self.COP = 3.6
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        


    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['fixed'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        
        
        

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['fixed'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            #Thermal
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,100000), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(-100000,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)


    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  



    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(t+1))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        #return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]
    
    def dischargeBalance(self, m,t):
        return self.m.p_dis[t] == self.m.p_dis_l[t] + self.m.p_dis_g[t]

    def pvCharge(self, m,t):
        return -self.m.p_ch_p[t] <= self.m.p_pv[t]
    
    
    def gridDischarge(self, m,t):
        return self.m.p_dis_g[t] >= self.m.p_load[t]
    


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    

    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t]))
                   + self.m.mode_1[t]*((self.m.p_ex[t] - 0)*(self.m.p_ex[t] - 0))
                   for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
#         discretizer = TransformationFactory('dae.finite_difference')
#         discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %%
def extract_pyomo_electrical_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    df['p_im'] = list(m.p_im.get_values().values())
    df['p_ex'] = list(m.p_ex.get_values().values())
    df['p_ch'] = list(m.p_ch.get_values().values())
    df['p_ch_p'] = list(m.p_ch_p.get_values().values())
    df['p_ch_g'] = list(m.p_ch_g.get_values().values())
    df['p_dis'] = list(m.p_dis.get_values().values())
    df['soc'] = list(m.soc.get_values().values())
    
    return df

# %%
def extract_pyomo_thermal_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    #df['phi_h_heat'] = list(m.phi_h_heat.get_values().values())
    df['phi_h_cool'] = list(m.phi_h_cool.get_values().values())
    df['p_hvac'] = list(m.p_hvac.get_values().values())
    df['T_i'] = list(m.T_i.get_values().values())
    df['T_w'] = list(m.T_w.get_values().values())
    
    return df

# %%
def plot_electrical3(df_results, sim):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    
    fig = plt.figure(figsize=(12,8))
    
    gs=GridSpec(3,1) # 2 rows, 3 columns

    ax1=fig.add_subplot(gs[0,0]) # First row, first column
    ax2=fig.add_subplot(gs[1:,0]) # First row, second column

    
    load =  ax2.plot(df_results.index, df_results['load'], label='$p_i^l$', lw=1, color='red', ls=(0, (3, 1, 1, 1)))
    pv =  ax2.plot(df_results.index, df_results['pv'], label='$p_i^p$', lw=1, color='blue', ls=(0, (5, 5)))
    im =  ax2.plot(df_results.index, df_results['p_im'], label='$p_i^i$', lw=1, color='grey', ls='-.')
    ex =  ax2.plot(df_results.index, df_results['p_ex'], label='$p_i^e$', lw=1, color='orange', ls=(0, (3, 1, 1, 1, 1, 1)))
    ch =  ax2.plot(df_results.index, df_results['p_ch'], label='$p_i^c$', lw=1.5,color='black', ls='dotted')
    dis =  ax2.plot(df_results.index, df_results['p_dis'], label='$p_i^d$', lw=1, color='green')
    hvac = ax2.plot(df_results.index, df_results['p_hvac'], label='$p_i^h$', lw=1, color='purple', ls=(0, (5, 1)))
    ax2.set_ylim(-6000,12000)
     
    soc = ax1.plot(df_results.index, df_results['soc'], label='$SoC$', lw=1, color='blue', ls='--')
    ax1.set_ylim(-10,120)
    
    ax3 = ax1.twinx()
    ax3.set_ylabel('Cost ($/kWh)')
    ax3.set_ylim(0,0.4)
    tou = ax3.plot(df_results.index, df_results['tou'], label='$ToU$', lw=1, color='red',)
    ax3.grid()
    
    ax2.set_xlabel('Date')
    ax1.set_ylabel('SoC (%)')
    ax1.get_shared_x_axes().join(ax1, ax2)
    ax1.set_xticklabels([])
    ax2.set_ylabel('Power (W)')
    
    ax2.legend(loc="upper left", ncol=7)
    ax1.legend(loc="upper left")
    ax3.legend(loc="upper right")
    ax1.autoscale(enable=True, axis='x', tight=True)

# %%
def plot_thermal_combined2(mpc_data):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    fig, ax = plt.subplots(2, sharex=True)
    ax[0].set_ylabel('Indoor Temperature ($^\circ$C)')
    ax[0].set_ylim(15,45)
    ax[0].plot(mpc_data.index, mpc_data['T_i'], color='red', lw=2, ls='--')
    #ax[0].plot(mpc_data.index, rbc_data['T_i'], color='black', lw=2, ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[0].plot(mpc_data.index, mpc_data['t_ext'], color='green', ls='-.')
    #ax[0].plot(mpc_data.index, mpc_data['t_bed'])
    ax[0].plot(mpc_data.index, mpc_data['set_point'], color='grey')
    ax[0].legend(['MPC $T_i^i$', 'RBC $T_i^i$', '$T_a$', 'Set Point'], loc="upper left", ncol=4)
    
    
    
    #Plot Results
    
    ax[1].set_xlabel('Date')
    ax[1].set_ylabel('Cooling (kW) \n Solar Irradiance (kW/m$^2$)')
    ax[1].set_ylim(0,15)
    #ax1.plot(df_results.index, df_results['phi_h_heat'], color='red')
    ax[1].plot(mpc_data.index, -mpc_data['phi_h_cool'], color='red', alpha=0.75, )
    #ax[1].plot(mpc_data.index, -rbc_data['phi_h_cool'], color= 'black', ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[1].plot(mpc_data.index, mpc_data['ghi']/1000, color='blue', ls='--')
    ax[1].legend(['MPC $\Phi_i^c$', 'RPC $\Phi_i^c$', 'GHI'], loc="upper left", ncol=3)



    fig.tight_layout()
    fig.set_figheight(7.5)
    fig.set_figwidth(12)# otherwise the right y-label is slightly clipped
    #ax.grid()
    
    #plt.savefig('thermal_mpc_rbc.pdf')
    ax[0].autoscale(enable=True, axis='x', tight=True)
    ax[1].autoscale(enable=True, axis='x', tight=True)
    plt.show()

# %% [markdown]
# ## Solve MPC

# %%
mpc_data = sim_data.loc[start:end].resample('20min').mean().dropna()

# %%
if(sim=='DRH'):
    mpc_data['pv'] = mpc_data['pv'].shift(-3, axis=0)
    mpc_data['pv'].fillna(0, inplace=True)

# %%
mpc_data['mode_0'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 0
mpc_data['mode_1'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 1

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
Np = 24

# %%
for i, idx in enumerate(mpc_data.index):
    print('\n' + str(i) + '\n' + str(idx) + '\n')
    mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()

    mpc = MPC_DRH(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
    mpc.solve()

    mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
    mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)

    mpc_results_first_step = mpc_sim.iloc[0].copy()
    mpc_results.iloc[i] = mpc_results_first_step
    
    #states = {'SoC_Av':mpc_sim['soc'].iloc[0]}
    
#     states = {'SoC_Av':mpc_sim['soc'].iloc[0],
#               'T_i':mpc_sim['T_i'].iloc[1],
#               'T_w':mpc_sim['T_w'].iloc[1],
#               'phi_h':mpc_sim['phi_h_heat'].iloc[1],
#               'phi_c':mpc_sim['phi_h_cool'].iloc[1]}
    
    states = {'SoC_Av':mpc_sim['soc'].iloc[0],
              'T_i':mpc_sim['T_i'].iloc[1],
              'T_w':mpc_sim['T_w'].iloc[1],
              'phi_c':mpc_sim['phi_h_cool'].iloc[1]}

    
    if(i==72):
        break 
#     if(i==500):
#         break
# Out:
# 0
# 2021-01-10 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp79zejxby_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnl1tkbx1.pyomo.sol'
# Solver problem files: ('/tmp/tmpnl1tkbx1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2021-01-10 00:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmph600e431_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp68j_yhnw.pyomo.sol'
# Solver problem files: ('/tmp/tmp68j_yhnw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2021-01-10 00:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp1vvjvk75_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0pxd0swo.pyomo.sol'
# Solver problem files: ('/tmp/tmp0pxd0swo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2021-01-10 01:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpv5_blcuq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzsw9h65l.pyomo.sol'
# Solver problem files: ('/tmp/tmpzsw9h65l.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2021-01-10 01:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6g1x5h1u_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxz6wu_rt.pyomo.sol'
# Solver problem files: ('/tmp/tmpxz6wu_rt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2021-01-10 01:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpdlhirhlo_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc73u7hsn.pyomo.sol'
# Solver problem files: ('/tmp/tmpc73u7hsn.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2021-01-10 02:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp1t04cniw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmgmje_1v.pyomo.sol'
# Solver problem files: ('/tmp/tmpmgmje_1v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2021-01-10 02:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpt7lrjc9j_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpcfv5za0y.pyomo.sol'
# Solver problem files: ('/tmp/tmpcfv5za0y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2021-01-10 02:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpezlb1kdu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpocldwdj_.pyomo.sol'
# Solver problem files: ('/tmp/tmpocldwdj_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2021-01-10 03:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjsd2yku7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk9uoryd_.pyomo.sol'
# Solver problem files: ('/tmp/tmpk9uoryd_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2021-01-10 03:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp98z8w6up_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2yuh1gy2.pyomo.sol'
# Solver problem files: ('/tmp/tmp2yuh1gy2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2021-01-10 03:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbm_dzs2d_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplcn855la.pyomo.sol'
# Solver problem files: ('/tmp/tmplcn855la.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2021-01-10 04:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphh6uyg11_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpeagl0lya.pyomo.sol'
# Solver problem files: ('/tmp/tmpeagl0lya.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2021-01-10 04:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpntertlmo_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpm_uwjach.pyomo.sol'
# Solver problem files: ('/tmp/tmpm_uwjach.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2021-01-10 04:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6zsbub3j_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9gr2_o9e.pyomo.sol'
# Solver problem files: ('/tmp/tmp9gr2_o9e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2021-01-10 05:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpooxbr5k6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdqkf5ow8.pyomo.sol'
# Solver problem files: ('/tmp/tmpdqkf5ow8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2021-01-10 05:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpm7sxruc1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzjuwqdvd.pyomo.sol'
# Solver problem files: ('/tmp/tmpzjuwqdvd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2021-01-10 05:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpa65al95z_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1mrtz6ag.pyomo.sol'
# Solver problem files: ('/tmp/tmp1mrtz6ag.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2021-01-10 06:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp3f9sfdhd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwj8jiju6.pyomo.sol'
# Solver problem files: ('/tmp/tmpwj8jiju6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2021-01-10 06:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmprocexwgq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp104k3yo6.pyomo.sol'
# Solver problem files: ('/tmp/tmp104k3yo6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2021-01-10 06:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp23fipemb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqdyqealq.pyomo.sol'
# Solver problem files: ('/tmp/tmpqdyqealq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2021-01-10 07:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpccziu21v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpq01vpga4.pyomo.sol'
# Solver problem files: ('/tmp/tmpq01vpga4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2021-01-10 07:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpiq7nbrfg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2rw29n9d.pyomo.sol'
# Solver problem files: ('/tmp/tmp2rw29n9d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2021-01-10 07:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp66v1w3t6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyrexdfcz.pyomo.sol'
# Solver problem files: ('/tmp/tmpyrexdfcz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2021-01-10 08:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpgznwk9gg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpifvdj6le.pyomo.sol'
# Solver problem files: ('/tmp/tmpifvdj6le.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2021-01-10 08:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp1bug40xm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprfh9w65j.pyomo.sol'
# Solver problem files: ('/tmp/tmprfh9w65j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2021-01-10 08:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpdgw9mkrh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf8g96u4x.pyomo.sol'
# Solver problem files: ('/tmp/tmpf8g96u4x.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2021-01-10 09:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpzmkmxrmg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpflc5pfzs.pyomo.sol'
# Solver problem files: ('/tmp/tmpflc5pfzs.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2021-01-10 09:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpfrbj96eq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpl4jefqd5.pyomo.sol'
# Solver problem files: ('/tmp/tmpl4jefqd5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2021-01-10 09:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp85kgd1xg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4jwxved_.pyomo.sol'
# Solver problem files: ('/tmp/tmp4jwxved_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2021-01-10 10:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpm8gjezcy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpho8q6ae4.pyomo.sol'
# Solver problem files: ('/tmp/tmpho8q6ae4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2021-01-10 10:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpoazbnxct_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv3818wvd.pyomo.sol'
# Solver problem files: ('/tmp/tmpv3818wvd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2021-01-10 10:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpzsvh9s7x_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9azrb2lz.pyomo.sol'
# Solver problem files: ('/tmp/tmp9azrb2lz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2021-01-10 11:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpksbk0rps_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpujtkk6le.pyomo.sol'
# Solver problem files: ('/tmp/tmpujtkk6le.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2021-01-10 11:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbc9b0wzw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5z5t9dzc.pyomo.sol'
# Solver problem files: ('/tmp/tmp5z5t9dzc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2021-01-10 11:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp2g071887_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5sbif0v1.pyomo.sol'
# Solver problem files: ('/tmp/tmp5sbif0v1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2021-01-10 12:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpghw7bqj7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkh8vn_rj.pyomo.sol'
# Solver problem files: ('/tmp/tmpkh8vn_rj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2021-01-10 12:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp2t1pl82a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvbzwt3c8.pyomo.sol'
# Solver problem files: ('/tmp/tmpvbzwt3c8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2021-01-10 12:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpfd2u3cs6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpui_wdpm2.pyomo.sol'
# Solver problem files: ('/tmp/tmpui_wdpm2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2021-01-10 13:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjlgvfdi4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1qmi_ul7.pyomo.sol'
# Solver problem files: ('/tmp/tmp1qmi_ul7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2021-01-10 13:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpchzer9n0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3f6mw93d.pyomo.sol'
# Solver problem files: ('/tmp/tmp3f6mw93d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2021-01-10 13:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmprtq8js2i_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpinfv4lj2.pyomo.sol'
# Solver problem files: ('/tmp/tmpinfv4lj2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2021-01-10 14:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp7dtdwfky_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb9p31rzg.pyomo.sol'
# Solver problem files: ('/tmp/tmpb9p31rzg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2021-01-10 14:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpye58nhaa_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpisz4p1mi.pyomo.sol'
# Solver problem files: ('/tmp/tmpisz4p1mi.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2021-01-10 14:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_cisnzrg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjx6xa0sw.pyomo.sol'
# Solver problem files: ('/tmp/tmpjx6xa0sw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2021-01-10 15:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpna51s6dr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpikj_0uo_.pyomo.sol'
# Solver problem files: ('/tmp/tmpikj_0uo_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2021-01-10 15:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp2oan0331_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6ai09dos.pyomo.sol'
# Solver problem files: ('/tmp/tmp6ai09dos.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2021-01-10 15:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpz2guic28_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbpt_vy6v.pyomo.sol'
# Solver problem files: ('/tmp/tmpbpt_vy6v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2021-01-10 16:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjoc99fib_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5r93mfee.pyomo.sol'
# Solver problem files: ('/tmp/tmp5r93mfee.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2021-01-10 16:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6yldawzf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpiotmqvvu.pyomo.sol'
# Solver problem files: ('/tmp/tmpiotmqvvu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2021-01-10 16:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpj47gk572_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6j80yfn4.pyomo.sol'
# Solver problem files: ('/tmp/tmp6j80yfn4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2021-01-10 17:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbfkw4a1t_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbxqd8acz.pyomo.sol'
# Solver problem files: ('/tmp/tmpbxqd8acz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2021-01-10 17:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp77qugvim_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8ix7qgde.pyomo.sol'
# Solver problem files: ('/tmp/tmp8ix7qgde.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2021-01-10 17:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpe41oridz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdxiypn9y.pyomo.sol'
# Solver problem files: ('/tmp/tmpdxiypn9y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2021-01-10 18:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpcot_lfjt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8xxle2am.pyomo.sol'
# Solver problem files: ('/tmp/tmp8xxle2am.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2021-01-10 18:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpmv64uxx1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0qtgyu8a.pyomo.sol'
# Solver problem files: ('/tmp/tmp0qtgyu8a.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2021-01-10 18:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp4snb7x53_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprxcfq4o5.pyomo.sol'
# Solver problem files: ('/tmp/tmprxcfq4o5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2021-01-10 19:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp84tqway8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpm76gure9.pyomo.sol'
# Solver problem files: ('/tmp/tmpm76gure9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2021-01-10 19:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphg2m2gho_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvh7qbdua.pyomo.sol'
# Solver problem files: ('/tmp/tmpvh7qbdua.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2021-01-10 19:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp4tgjh38b_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpm7v92omd.pyomo.sol'
# Solver problem files: ('/tmp/tmpm7v92omd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2021-01-10 20:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp8qsoljvy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5exrg8lm.pyomo.sol'
# Solver problem files: ('/tmp/tmp5exrg8lm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2021-01-10 20:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp3kjye2vi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9nf6vh9c.pyomo.sol'
# Solver problem files: ('/tmp/tmp9nf6vh9c.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2021-01-10 20:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpw8k5ge0c_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnqm7__r3.pyomo.sol'
# Solver problem files: ('/tmp/tmpnqm7__r3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2021-01-10 21:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp4v8wko6l_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzir5zxj4.pyomo.sol'
# Solver problem files: ('/tmp/tmpzir5zxj4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2021-01-10 21:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpw_fxjvb__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3l_gyk0j.pyomo.sol'
# Solver problem files: ('/tmp/tmp3l_gyk0j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2021-01-10 21:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpb94i5sh9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6auy67na.pyomo.sol'
# Solver problem files: ('/tmp/tmp6auy67na.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2021-01-10 22:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpomente38_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplcem3thb.pyomo.sol'
# Solver problem files: ('/tmp/tmplcem3thb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2021-01-10 22:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkln8d5iy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgc42dant.pyomo.sol'
# Solver problem files: ('/tmp/tmpgc42dant.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2021-01-10 22:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp5n14esnm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprhb5kky6.pyomo.sol'
# Solver problem files: ('/tmp/tmprhb5kky6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2021-01-10 23:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpay2qagox_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7tpc6qbo.pyomo.sol'
# Solver problem files: ('/tmp/tmp7tpc6qbo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2021-01-10 23:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpo5ca1d0w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr_okuzn4.pyomo.sol'
# Solver problem files: ('/tmp/tmpr_okuzn4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2021-01-10 23:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkszifgnr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpo5pu8coa.pyomo.sol'
# Solver problem files: ('/tmp/tmpo5pu8coa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2021-01-11 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp7me5so86_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_gjh5pnk.pyomo.sol'
# Solver problem files: ('/tmp/tmp_gjh5pnk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1

# %%
mpc_results.to_csv(f'Results/VRmode_20min_{sim}_{start}_{t_start}_{t_end}.csv')

# %% [markdown]
# # SBRC Simulations

# %%
def sbrc_mpc_df(sb_phase):
    sbrc_pv = pd.DataFrame()
    
    if(sb_phase == 'P1'):
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'] - drh.loc[start:end]['P1_Avg[W]'])
    elif(sb_phase == 'P3'):
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'] - ifh.loc[start:end]['AvgP3'])
    else:
        sbrc_pv['load'] = (sbrc.loc[start:end][f'Avg{sb_phase}']- pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = -(pv.loc[start:end][f'{sb_phase}_Avg[W]'])
    
    sbrc_pv['pv'] = [0 if pv_val < 0 else pv_val for pv_val in sbrc_pv['pv']]

    sbrc_pv = sbrc_pv.resample('20min').mean()

    for col in ['fixed', 'tou', 'fit', 'ch_cost', 'dis_cost', 'mode_0', 'mode_1']:
        sbrc_pv[col] = [ts_data[col].loc[idx]  for idx in sbrc_pv.index.time]
        
        
    return sbrc_pv

# %% [markdown]
# ## Simulate MPC Each Pahse SBRC

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_ch_p', 'p_ch_g', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
states = {'SoC_Av':20}

# %%
mpc_data
# Out:
#                          t_ext  ghi      t_bed   pv  fixed   tou   fit  \
# 2021-01-10 00:00:00  17.984475  0.0  27.140000  0.0   0.25  0.16  0.11
# 2021-01-10 00:20:00  17.887711  0.0  27.040000  0.5   0.25  0.16  0.11
# 2021-01-10 00:40:00  17.738755  0.0  26.920000  0.0   0.25  0.16  0.11
# 2021-01-10 01:00:00  17.650798  0.0  26.810000  0.0   0.25  0.16  0.11
# 2021-01-10 01:20:00  17.609016  0.0  26.705000  0.0   0.25  0.16  0.11
# ...                        ...  ...        ...  ...    ...   ...   ...
# 2021-01-11 22:20:00  21.300861  0.0  29.200000  0.0   0.25  0.16  0.11
# 2021-01-11 22:40:00  20.963460  0.0  29.053333  0.0   0.25  0.16  0.11
# 2021-01-11 23:00:00  20.696811  0.0  28.920000  0.0   0.25  0.16  0.11
# 2021-01-11 23:20:00  20.494561  0.0  28.780000  0.0   0.25  0.16  0.11
# 2021-01-11 23:40:00  20.325638  0.0  28.670000  0.0   0.25  0.16  0.11
#
#                      ch_cost  dis_cost  mode_0  ...  mode_2  set_point  \
# 2021-01-10 00:00:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-10 00:20:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-10 00:40:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-10 01:00:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-10 01:20:00     0.02      0.01     1.0  ...     0.0       25.0
# ...                      ...       ...     ...  ...     ...        ...
# 2021-01-11 22:20:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-11 22:40:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-11 23:00:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-11 23:20:00     0.02      0.01     1.0  ...     0.0       25.0
# 2021-01-11 23:40:00     0.02      0.01     1.0  ...     0.0       25.0
#
#                      sp_soft  heat_gains  load_sim  load1  heat_gains0  \
# 2021-01-10 00:00:00     10.0         0.5     300.0  500.0          0.0
# 2021-01-10 00:20:00     10.0         0.5     300.0  500.0          0.0
# 2021-01-10 00:40:00     10.0         0.5     300.0  500.0          0.0
# 2021-01-10 01:00:00     10.0         0.5     300.0  500.0          0.0
# 2021-01-10 01:20:00     10.0         0.5     300.0  500.0          0.0
# ...                      ...         ...       ...    ...          ...
# 2021-01-11 22:20:00     10.0         0.7     300.0  400.0          0.0
# 2021-01-11 22:40:00     10.0         0.7     300.0  400.0          0.0
# 2021-01-11 23:00:00     10.0         0.5     300.0  400.0          0.0
# 2021-01-11 23:20:00     10.0         0.5     300.0  400.0          0.0
# 2021-01-11 23:40:00     10.0         0.5     300.0  400.0          0.0
#
#                        load       cop   cool_cap
# 2021-01-10 00:00:00  330.50  3.714405 -11.208889
# 2021-01-10 00:20:00  331.25  3.721200 -11.234258
# 2021-01-10 00:40:00  329.75  3.731661 -11.273310
# 2021-01-10 01:00:00  333.00  3.737838 -11.296370
# 2021-01-10 01:20:00  328.50  3.740773 -11.307324
# ...                     ...       ...        ...
# 2021-01-11 22:20:00  630.00  3.481500 -10.339428
# 2021-01-11 22:40:00  635.00  3.505195 -10.427885
# 2021-01-11 23:00:00  331.25  3.523921 -10.497792
# 2021-01-11 23:20:00  321.50  3.538125 -10.550816
# 2021-01-11 23:40:00  324.25  3.549988 -10.595103
#
# [144 rows x 21 columns]

# %%
for ph in ['P1', 'P2', 'P3']:
    
    mpc_data = sbrc_mpc_df(ph)
    
    mpc_data['mode_0'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 0
    mpc_data['mode_1'].loc[f'{start} {vr_start}':f'{start} {vr_end}'] = 1
    
    ##------VR MODE--------##
#     mpc_data.loc[end,'mode_0'] = 1
#     mpc_data.loc[end,'mode_1'] = 0
    
    ##------ECO MODE--------##
#     mpc_data['mode_0'] = 1
#     mpc_data['mode_1'] = 0
  
    for i, idx in enumerate(mpc_data.index):
        print('\n' + str(i) + '\n' + str(idx) + '\n')
        mpc_sim = mpc_data.iloc[i:i+int(Np/dt)].copy()
        
        mpc = MPC_SBRC(Np=Np, dt=dt, forecasts=mpc_sim, states=states)
        mpc.solve()

        mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
#         #mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)
        
        #print(mpc_sim)

        mpc_results_first_step = mpc_sim.iloc[0].copy()
        mpc_results.iloc[i] = mpc_results_first_step

        states = {'SoC_Av':mpc_sim['soc'].iloc[0]}


        if(i==72):
            break
    
    mpc_results.to_csv(f'Results/VRmode_20min_SBRC_{ph}_{start}_{t_start}_{t_end}.csv')
    states = {'SoC_Av':20}
# Out:
# 0
# 2021-01-10 00:00:00
#
# Solver log file: '/tmp/tmp1288tmro_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps505m_99.pyomo.sol'
# Solver problem files: ('/tmp/tmps505m_99.pyomo.nl',)
# /home/brendan/jupyter_env/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2021-01-10 00:20:00
#
# Solver log file: '/tmp/tmpcvg3f7dr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpstt7u6k5.pyomo.sol'
# Solver problem files: ('/tmp/tmpstt7u6k5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2021-01-10 00:40:00
#
# Solver log file: '/tmp/tmp9nr2nb0j_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3v4mv5cj.pyomo.sol'
# Solver problem files: ('/tmp/tmp3v4mv5cj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2021-01-10 01:00:00
#
# Solver log file: '/tmp/tmp5l8au05d_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgy0d_93u.pyomo.sol'
# Solver problem files: ('/tmp/tmpgy0d_93u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2021-01-10 01:20:00
#
# Solver log file: '/tmp/tmpsh5w7ggt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwkcwh27f.pyomo.sol'
# Solver problem files: ('/tmp/tmpwkcwh27f.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2021-01-10 01:40:00
#
# Solver log file: '/tmp/tmpn71_0iv__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2z7v6jby.pyomo.sol'
# Solver problem files: ('/tmp/tmp2z7v6jby.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2021-01-10 02:00:00
#
# Solver log file: '/tmp/tmp6ouz0tk1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_gqdrvzs.pyomo.sol'
# Solver problem files: ('/tmp/tmp_gqdrvzs.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2021-01-10 02:20:00
#
# Solver log file: '/tmp/tmp1eci8ikb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_yv9slks.pyomo.sol'
# Solver problem files: ('/tmp/tmp_yv9slks.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2021-01-10 02:40:00
#
# Solver log file: '/tmp/tmpgabvgcn2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjm0izuwz.pyomo.sol'
# Solver problem files: ('/tmp/tmpjm0izuwz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2021-01-10 03:00:00
#
# Solver log file: '/tmp/tmp5w_iumx5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp64bhk5xz.pyomo.sol'
# Solver problem files: ('/tmp/tmp64bhk5xz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2021-01-10 03:20:00
#
# Solver log file: '/tmp/tmpfiq9fopi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1316i30p.pyomo.sol'
# Solver problem files: ('/tmp/tmp1316i30p.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2021-01-10 03:40:00
#
# Solver log file: '/tmp/tmpu5_8yiys_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbf7odr2i.pyomo.sol'
# Solver problem files: ('/tmp/tmpbf7odr2i.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2021-01-10 04:00:00
#
# Solver log file: '/tmp/tmprbx1zj81_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkptneqpk.pyomo.sol'
# Solver problem files: ('/tmp/tmpkptneqpk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2021-01-10 04:20:00
#
# Solver log file: '/tmp/tmp180lhaz3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyc8it_jy.pyomo.sol'
# Solver problem files: ('/tmp/tmpyc8it_jy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2021-01-10 04:40:00
#
# Solver log file: '/tmp/tmp8emuxt3e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp90zz5ixo.pyomo.sol'
# Solver problem files: ('/tmp/tmp90zz5ixo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2021-01-10 05:00:00
#
# Solver log file: '/tmp/tmpre389mqe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv210ofq9.pyomo.sol'
# Solver problem files: ('/tmp/tmpv210ofq9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2021-01-10 05:20:00
#
# Solver log file: '/tmp/tmp9dpzi9or_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5xxj9hmz.pyomo.sol'
# Solver problem files: ('/tmp/tmp5xxj9hmz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2021-01-10 05:40:00
#
# Solver log file: '/tmp/tmpz3r_ik48_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkvqt3gyz.pyomo.sol'
# Solver problem files: ('/tmp/tmpkvqt3gyz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2021-01-10 06:00:00
#
# Solver log file: '/tmp/tmppl9dmapn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppd9ghlqk.pyomo.sol'
# Solver problem files: ('/tmp/tmppd9ghlqk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2021-01-10 06:20:00
#
# Solver log file: '/tmp/tmpti_jm22k_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf2mpf6pd.pyomo.sol'
# Solver problem files: ('/tmp/tmpf2mpf6pd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2021-01-10 06:40:00
#
# Solver log file: '/tmp/tmpmz5u5hhb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppjzyk2k2.pyomo.sol'
# Solver problem files: ('/tmp/tmppjzyk2k2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2021-01-10 07:00:00
#
# Solver log file: '/tmp/tmpoz6ckhyc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv4aznma2.pyomo.sol'
# Solver problem files: ('/tmp/tmpv4aznma2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2021-01-10 07:20:00
#
# Solver log file: '/tmp/tmpmhbh8ea__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmdkjysvk.pyomo.sol'
# Solver problem files: ('/tmp/tmpmdkjysvk.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2021-01-10 07:40:00
#
# Solver log file: '/tmp/tmpoiatm3e6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0c1lrio2.pyomo.sol'
# Solver problem files: ('/tmp/tmp0c1lrio2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2021-01-10 08:00:00
#
# Solver log file: '/tmp/tmpbl6jnp93_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp06j56o16.pyomo.sol'
# Solver problem files: ('/tmp/tmp06j56o16.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2021-01-10 08:20:00
#
# Solver log file: '/tmp/tmpkvty0jpp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0clr3yfr.pyomo.sol'
# Solver problem files: ('/tmp/tmp0clr3yfr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2021-01-10 08:40:00
#
# Solver log file: '/tmp/tmpx999pocd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbwemzmuc.pyomo.sol'
# Solver problem files: ('/tmp/tmpbwemzmuc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2021-01-10 09:00:00
#
# Solver log file: '/tmp/tmp19r81bsg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptwec5ktw.pyomo.sol'
# Solver problem files: ('/tmp/tmptwec5ktw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2021-01-10 09:20:00
#
# Solver log file: '/tmp/tmp74is_zvj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmn7km_il.pyomo.sol'
# Solver problem files: ('/tmp/tmpmn7km_il.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2021-01-10 09:40:00
#
# Solver log file: '/tmp/tmp19ns4saw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8_ag_ktj.pyomo.sol'
# Solver problem files: ('/tmp/tmp8_ag_ktj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2021-01-10 10:00:00
#
# Solver log file: '/tmp/tmpmxpcgx5a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmmgpw74m.pyomo.sol'
# Solver problem files: ('/tmp/tmpmmgpw74m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2021-01-10 10:20:00
#
# Solver log file: '/tmp/tmpiolchhid_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt9p4_6zv.pyomo.sol'
# Solver problem files: ('/tmp/tmpt9p4_6zv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2021-01-10 10:40:00
#
# Solver log file: '/tmp/tmp8cvnd60a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpz8taq99d.pyomo.sol'
# Solver problem files: ('/tmp/tmpz8taq99d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2021-01-10 11:00:00
#
# Solver log file: '/tmp/tmpr968ac32_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzb6sfqd7.pyomo.sol'
# Solver problem files: ('/tmp/tmpzb6sfqd7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2021-01-10 11:20:00
#
# Solver log file: '/tmp/tmprzz6drno_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf00yri_4.pyomo.sol'
# Solver problem files: ('/tmp/tmpf00yri_4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2021-01-10 11:40:00
#
# Solver log file: '/tmp/tmp59i4p27e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8qfpf1sj.pyomo.sol'
# Solver problem files: ('/tmp/tmp8qfpf1sj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2021-01-10 12:00:00
#
# Solver log file: '/tmp/tmpvvu_d_4j_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_ukmprn_.pyomo.sol'
# Solver problem files: ('/tmp/tmp_ukmprn_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2021-01-10 12:20:00
#
# Solver log file: '/tmp/tmpjlnxj771_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc6fem4du.pyomo.sol'
# Solver problem files: ('/tmp/tmpc6fem4du.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2021-01-10 12:40:00
#
# Solver log file: '/tmp/tmp8kruckv7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplc96typt.pyomo.sol'
# Solver problem files: ('/tmp/tmplc96typt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2021-01-10 13:00:00
#
# Solver log file: '/tmp/tmph_wwnrz0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvhz3tmyd.pyomo.sol'
# Solver problem files: ('/tmp/tmpvhz3tmyd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2021-01-10 13:20:00
#
# Solver log file: '/tmp/tmppop5jr7e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkctpj3b0.pyomo.sol'
# Solver problem files: ('/tmp/tmpkctpj3b0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2021-01-10 13:40:00
#
# Solver log file: '/tmp/tmpkxaxqj89_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp3clamgg.pyomo.sol'
# Solver problem files: ('/tmp/tmpp3clamgg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2021-01-10 14:00:00
#
# Solver log file: '/tmp/tmpigfxkuap_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpj852qlfx.pyomo.sol'
# Solver problem files: ('/tmp/tmpj852qlfx.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2021-01-10 14:20:00
#
# Solver log file: '/tmp/tmp81796v3v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpiikegb0u.pyomo.sol'
# Solver problem files: ('/tmp/tmpiikegb0u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2021-01-10 14:40:00
#
# Solver log file: '/tmp/tmpiwbfiuq4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp05rh9slg.pyomo.sol'
# Solver problem files: ('/tmp/tmp05rh9slg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2021-01-10 15:00:00
#
# Solver log file: '/tmp/tmpl6m2s50q_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd9mid2q9.pyomo.sol'
# Solver problem files: ('/tmp/tmpd9mid2q9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2021-01-10 15:20:00
#
# Solver log file: '/tmp/tmpfnse63f4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpv9z0biit.pyomo.sol'
# Solver problem files: ('/tmp/tmpv9z0biit.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2021-01-10 15:40:00
#
# Solver log file: '/tmp/tmpnr08yutg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu3s4izgp.pyomo.sol'
# Solver problem files: ('/tmp/tmpu3s4izgp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2021-01-10 16:00:00
#
# Solver log file: '/tmp/tmprom8037v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_2mzdcfb.pyomo.sol'
# Solver problem files: ('/tmp/tmp_2mzdcfb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2021-01-10 16:20:00
#
# Solver log file: '/tmp/tmpjd5fcbdf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzumaip8t.pyomo.sol'
# Solver problem files: ('/tmp/tmpzumaip8t.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2021-01-10 16:40:00
#
# Solver log file: '/tmp/tmps9e92dbm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkhvejfy3.pyomo.sol'
# Solver problem files: ('/tmp/tmpkhvejfy3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2021-01-10 17:00:00
#
# Solver log file: '/tmp/tmppy1ethzg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpg28_gp5w.pyomo.sol'
# Solver problem files: ('/tmp/tmpg28_gp5w.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2021-01-10 17:20:00
#
# Solver log file: '/tmp/tmpe9wd2pmu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpccmymdw4.pyomo.sol'
# Solver problem files: ('/tmp/tmpccmymdw4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2021-01-10 17:40:00
#
# Solver log file: '/tmp/tmpwbr3x86y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpq5bjstib.pyomo.sol'
# Solver problem files: ('/tmp/tmpq5bjstib.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2021-01-10 18:00:00
#
# Solver log file: '/tmp/tmp5el1c1r__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxw6o6qww.pyomo.sol'
# Solver problem files: ('/tmp/tmpxw6o6qww.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2021-01-10 18:20:00
#
# Solver log file: '/tmp/tmpowlrudy5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprwoqjo7v.pyomo.sol'
# Solver problem files: ('/tmp/tmprwoqjo7v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2021-01-10 18:40:00
#
# Solver log file: '/tmp/tmpmuttharu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxbpkle1q.pyomo.sol'
# Solver problem files: ('/tmp/tmpxbpkle1q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2021-01-10 19:00:00
#
# Solver log file: '/tmp/tmpvbx6xppn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0zar8bk9.pyomo.sol'
# Solver problem files: ('/tmp/tmp0zar8bk9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2021-01-10 19:20:00
#
# Solver log file: '/tmp/tmp24alvnfe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzuc33s2j.pyomo.sol'
# Solver problem files: ('/tmp/tmpzuc33s2j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2021-01-10 19:40:00
#
# Solver log file: '/tmp/tmpnybm6lmj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpr8644x30.pyomo.sol'
# Solver problem files: ('/tmp/tmpr8644x30.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2021-01-10 20:00:00
#
# Solver log file: '/tmp/tmp181fo2yg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqb42f3xa.pyomo.sol'
# Solver problem files: ('/tmp/tmpqb42f3xa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2021-01-10 20:20:00
#
# Solver log file: '/tmp/tmpfs3l2lhj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_gm4qgv3.pyomo.sol'
# Solver problem files: ('/tmp/tmp_gm4qgv3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2021-01-10 20:40:00
#
# Solver log file: '/tmp/tmp4b361xjw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4yuly71x.pyomo.sol'
# Solver problem files: ('/tmp/tmp4yuly71x.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2021-01-10 21:00:00
#
# Solver log file: '/tmp/tmplkc7hn8w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3tlf_foz.pyomo.sol'
# Solver problem files: ('/tmp/tmp3tlf_foz.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2021-01-10 21:20:00
#
# Solver log file: '/tmp/tmps7id160q_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp83uu7t5k.pyomo.sol'
# Solver problem files: ('/tmp/tmp83uu7t5k.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2021-01-10 21:40:00
#
# Solver log file: '/tmp/tmplz7h1g0h_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpyon6tjlq.pyomo.sol'
# Solver problem files: ('/tmp/tmpyon6tjlq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2021-01-10 22:00:00
#
# Solver log file: '/tmp/tmp_le2ry9r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkn2qo3j_.pyomo.sol'
# Solver problem files: ('/tmp/tmpkn2qo3j_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2021-01-10 22:20:00
#
# Solver log file: '/tmp/tmpqvrq8duf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1ij4we7j.pyomo.sol'
# Solver problem files: ('/tmp/tmp1ij4we7j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2021-01-10 22:40:00
#
# Solver log file: '/tmp/tmpa2awuas3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpa98f3h06.pyomo.sol'
# Solver problem files: ('/tmp/tmpa98f3h06.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2021-01-10 23:00:00
# Solver log file: '/tmp/tmpclidm9s2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpaln1lmq6.pyomo.sol'
# Solver problem files: ('/tmp/tmpaln1lmq6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2021-01-10 23:20:00
#
# Solver log file: '/tmp/tmpcsaoimus_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9q1ix8eq.pyomo.sol'
# Solver problem files: ('/tmp/tmp9q1ix8eq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2021-01-10 23:40:00
#
# Solver log file: '/tmp/tmp_fybmcsz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptn6iew7l.pyomo.sol'
# Solver problem files: ('/tmp/tmptn6iew7l.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2021-01-11 00:00:00
#
# Solver log file: '/tmp/tmpkn9n39r4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6olgvhee.pyomo.sol'
# Solver problem files: ('/tmp/tmp6olgvhee.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 0
# 2021-01-10 00:00:00
# /home/brendan/jupyter_env/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Solver log file: '/tmp/tmpmzg8a7jc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwwot5vuc.pyomo.sol'
# Solver problem files: ('/tmp/tmpwwot5vuc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2021-01-10 00:20:00
#
# Solver log file: '/tmp/tmp96oz_ojf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgarg8ik9.pyomo.sol'
# Solver problem files: ('/tmp/tmpgarg8ik9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2021-01-10 00:40:00
#
# Solver log file: '/tmp/tmpwkxd97q6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd6u9gcal.pyomo.sol'
# Solver problem files: ('/tmp/tmpd6u9gcal.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2021-01-10 01:00:00
#
# Solver log file: '/tmp/tmpo44jrp_k_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk3ism7ec.pyomo.sol'
# Solver problem files: ('/tmp/tmpk3ism7ec.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2021-01-10 01:20:00
#
# Solver log file: '/tmp/tmp1a9aujre_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4fy263nq.pyomo.sol'
# Solver problem files: ('/tmp/tmp4fy263nq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2021-01-10 01:40:00
#
# Solver log file: '/tmp/tmp3cb4odrj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxmb6426a.pyomo.sol'
# Solver problem files: ('/tmp/tmpxmb6426a.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2021-01-10 02:00:00
#
# Solver log file: '/tmp/tmplbeufq12_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpokjya4fh.pyomo.sol'
# Solver problem files: ('/tmp/tmpokjya4fh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2021-01-10 02:20:00
#
# Solver log file: '/tmp/tmppo2d3mcv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphxu23s0k.pyomo.sol'
# Solver problem files: ('/tmp/tmphxu23s0k.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2021-01-10 02:40:00
#
# Solver log file: '/tmp/tmpgnxvnncu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxo80j06c.pyomo.sol'
# Solver problem files: ('/tmp/tmpxo80j06c.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2021-01-10 03:00:00
#
# Solver log file: '/tmp/tmpo6si5dm9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpuhsv8uqy.pyomo.sol'
# Solver problem files: ('/tmp/tmpuhsv8uqy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2021-01-10 03:20:00
#
# Solver log file: '/tmp/tmpehfbx2nj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpoq2xbeem.pyomo.sol'
# Solver problem files: ('/tmp/tmpoq2xbeem.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2021-01-10 03:40:00
#
# Solver log file: '/tmp/tmpsild0cl8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpm2t3cgye.pyomo.sol'
# Solver problem files: ('/tmp/tmpm2t3cgye.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2021-01-10 04:00:00
#
# Solver log file: '/tmp/tmpd1ppos98_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvjy9jb59.pyomo.sol'
# Solver problem files: ('/tmp/tmpvjy9jb59.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2021-01-10 04:20:00
#
# Solver log file: '/tmp/tmppucwuoow_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp14ypp637.pyomo.sol'
# Solver problem files: ('/tmp/tmp14ypp637.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2021-01-10 04:40:00
#
# Solver log file: '/tmp/tmpml85p0a8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3z4jg6ug.pyomo.sol'
# Solver problem files: ('/tmp/tmp3z4jg6ug.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2021-01-10 05:00:00
#
# Solver log file: '/tmp/tmpbk4reikc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmk77h2du.pyomo.sol'
# Solver problem files: ('/tmp/tmpmk77h2du.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2021-01-10 05:20:00
#
# Solver log file: '/tmp/tmp0xgisob__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8m1zdsdg.pyomo.sol'
# Solver problem files: ('/tmp/tmp8m1zdsdg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2021-01-10 05:40:00
#
# Solver log file: '/tmp/tmpseizfa6v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpy4kje09p.pyomo.sol'
# Solver problem files: ('/tmp/tmpy4kje09p.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2021-01-10 06:00:00
#
# Solver log file: '/tmp/tmppy61kn0c_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpoh_du2ox.pyomo.sol'
# Solver problem files: ('/tmp/tmpoh_du2ox.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2021-01-10 06:20:00
#
# Solver log file: '/tmp/tmphbe6ehq4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpuebx3m8s.pyomo.sol'
# Solver problem files: ('/tmp/tmpuebx3m8s.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2021-01-10 06:40:00
#
# Solver log file: '/tmp/tmpxddfzby4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkapmdd9a.pyomo.sol'
# Solver problem files: ('/tmp/tmpkapmdd9a.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2021-01-10 07:00:00
#
# Solver log file: '/tmp/tmprits1he2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp3q5suqda.pyomo.sol'
# Solver problem files: ('/tmp/tmp3q5suqda.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2021-01-10 07:20:00
#
# Solver log file: '/tmp/tmpkla_ebyu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjdoj4ihh.pyomo.sol'
# Solver problem files: ('/tmp/tmpjdoj4ihh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2021-01-10 07:40:00
#
# Solver log file: '/tmp/tmpi96kzb9w_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5d5ngi29.pyomo.sol'
# Solver problem files: ('/tmp/tmp5d5ngi29.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2021-01-10 08:00:00
#
# Solver log file: '/tmp/tmp5jrir9ud_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgtmgbep7.pyomo.sol'
# Solver problem files: ('/tmp/tmpgtmgbep7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2021-01-10 08:20:00
#
# Solver log file: '/tmp/tmpp2i82pr__gurobi_ampl.log'
# Solver solution file: '/tmp/tmp57u2f9_q.pyomo.sol'
# Solver problem files: ('/tmp/tmp57u2f9_q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2021-01-10 08:40:00
#
# Solver log file: '/tmp/tmpuoyxnf6i_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplsac9ood.pyomo.sol'
# Solver problem files: ('/tmp/tmplsac9ood.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2021-01-10 09:00:00
#
# Solver log file: '/tmp/tmp88g5sp5x_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppx_z33q9.pyomo.sol'
# Solver problem files: ('/tmp/tmppx_z33q9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2021-01-10 09:20:00
#
# Solver log file: '/tmp/tmpnqkk5er3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt3jq2tmf.pyomo.sol'
# Solver problem files: ('/tmp/tmpt3jq2tmf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2021-01-10 09:40:00
#
# Solver log file: '/tmp/tmpty_hfxiq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1r9vxq88.pyomo.sol'
# Solver problem files: ('/tmp/tmp1r9vxq88.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2021-01-10 10:00:00
#
# Solver log file: '/tmp/tmpvjoko6ko_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprz6fh93e.pyomo.sol'
# Solver problem files: ('/tmp/tmprz6fh93e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2021-01-10 10:20:00
#
# Solver log file: '/tmp/tmpdatig7xh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7esfe66j.pyomo.sol'
# Solver problem files: ('/tmp/tmp7esfe66j.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2021-01-10 10:40:00
#
# Solver log file: '/tmp/tmp03xzsm7f_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9zr7gnn8.pyomo.sol'
# Solver problem files: ('/tmp/tmp9zr7gnn8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2021-01-10 11:00:00
#
# Solver log file: '/tmp/tmpsn9ywm7g_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5xkpqkpd.pyomo.sol'
# Solver problem files: ('/tmp/tmp5xkpqkpd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2021-01-10 11:20:00
#
# Solver log file: '/tmp/tmpe3_57lgr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6vuqf0wt.pyomo.sol'
# Solver problem files: ('/tmp/tmp6vuqf0wt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2021-01-10 11:40:00
#
# Solver log file: '/tmp/tmpmrsmslq4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4c0dufp7.pyomo.sol'
# Solver problem files: ('/tmp/tmp4c0dufp7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2021-01-10 12:00:00
#
# Solver log file: '/tmp/tmpckd2_3mm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvo7thd70.pyomo.sol'
# Solver problem files: ('/tmp/tmpvo7thd70.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2021-01-10 12:20:00
#
# Solver log file: '/tmp/tmpie2h8mfa_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmu9oa5x1.pyomo.sol'
# Solver problem files: ('/tmp/tmpmu9oa5x1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2021-01-10 12:40:00
#
# Solver log file: '/tmp/tmped93uys0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb7ynpuas.pyomo.sol'
# Solver problem files: ('/tmp/tmpb7ynpuas.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2021-01-10 13:00:00
#
# Solver log file: '/tmp/tmpohfe16cp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk_ipkv3o.pyomo.sol'
# Solver problem files: ('/tmp/tmpk_ipkv3o.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2021-01-10 13:20:00
#
# Solver log file: '/tmp/tmpmn9pq33k_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9khlthzq.pyomo.sol'
# Solver problem files: ('/tmp/tmp9khlthzq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2021-01-10 13:40:00
#
# Solver log file: '/tmp/tmp9vu7llto_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppfjhsrpx.pyomo.sol'
# Solver problem files: ('/tmp/tmppfjhsrpx.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2021-01-10 14:00:00
#
# Solver log file: '/tmp/tmpwq8_urkl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpz07d3xjd.pyomo.sol'
# Solver problem files: ('/tmp/tmpz07d3xjd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2021-01-10 14:20:00
#
# Solver log file: '/tmp/tmpdnk5m91i_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfmx99lpu.pyomo.sol'
# Solver problem files: ('/tmp/tmpfmx99lpu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2021-01-10 14:40:00
#
# Solver log file: '/tmp/tmp5heduln4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc_rk8d_y.pyomo.sol'
# Solver problem files: ('/tmp/tmpc_rk8d_y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2021-01-10 15:00:00
#
# Solver log file: '/tmp/tmp7yg2_4cm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4064d38f.pyomo.sol'
# Solver problem files: ('/tmp/tmp4064d38f.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2021-01-10 15:20:00
#
# Solver log file: '/tmp/tmpdedn3_72_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkdojnsnd.pyomo.sol'
# Solver problem files: ('/tmp/tmpkdojnsnd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2021-01-10 15:40:00
#
# Solver log file: '/tmp/tmpxf8kvkwp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8dl2jjv2.pyomo.sol'
# Solver problem files: ('/tmp/tmp8dl2jjv2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2021-01-10 16:00:00
#
# Solver log file: '/tmp/tmpwwc_wgx__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpohpzzi1y.pyomo.sol'
# Solver problem files: ('/tmp/tmpohpzzi1y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2021-01-10 16:20:00
#
# Solver log file: '/tmp/tmp98dil9lt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjlzysdb1.pyomo.sol'
# Solver problem files: ('/tmp/tmpjlzysdb1.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2021-01-10 16:40:00
#
# Solver log file: '/tmp/tmp2sqtmhqd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_ta3x9bt.pyomo.sol'
# Solver problem files: ('/tmp/tmp_ta3x9bt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2021-01-10 17:00:00
#
# Solver log file: '/tmp/tmpx74qe8mi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxxyhjvyu.pyomo.sol'
# Solver problem files: ('/tmp/tmpxxyhjvyu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2021-01-10 17:20:00
#
# Solver log file: '/tmp/tmp1si5pvnd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxpxrpwqf.pyomo.sol'
# Solver problem files: ('/tmp/tmpxpxrpwqf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2021-01-10 17:40:00
#
# Solver log file: '/tmp/tmpacuhmvhr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5glrbz8s.pyomo.sol'
# Solver problem files: ('/tmp/tmp5glrbz8s.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2021-01-10 18:00:00
#
# Solver log file: '/tmp/tmpbk9nbsgh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplo8711et.pyomo.sol'
# Solver problem files: ('/tmp/tmplo8711et.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2021-01-10 18:20:00
#
# Solver log file: '/tmp/tmp3rgojkj__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgcj_08xl.pyomo.sol'
# Solver problem files: ('/tmp/tmpgcj_08xl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2021-01-10 18:40:00
#
# Solver log file: '/tmp/tmpt1jh6rop_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7cc774od.pyomo.sol'
# Solver problem files: ('/tmp/tmp7cc774od.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2021-01-10 19:00:00
#
# Solver log file: '/tmp/tmp0insybb2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4udtgafl.pyomo.sol'
# Solver problem files: ('/tmp/tmp4udtgafl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2021-01-10 19:20:00
#
# Solver log file: '/tmp/tmpfrn6sqea_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn02xk5mp.pyomo.sol'
# Solver problem files: ('/tmp/tmpn02xk5mp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2021-01-10 19:40:00
#
# Solver log file: '/tmp/tmps23lp9yt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf3kx1tw5.pyomo.sol'
# Solver problem files: ('/tmp/tmpf3kx1tw5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2021-01-10 20:00:00
#
# Solver log file: '/tmp/tmp6kra0czz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprxvsk9ne.pyomo.sol'
# Solver problem files: ('/tmp/tmprxvsk9ne.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2021-01-10 20:20:00
#
# Solver log file: '/tmp/tmptn1ctjo7_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp70a5bzzb.pyomo.sol'
# Solver problem files: ('/tmp/tmp70a5bzzb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2021-01-10 20:40:00
#
# Solver log file: '/tmp/tmp05kiqch8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmph8r7be3w.pyomo.sol'
# Solver problem files: ('/tmp/tmph8r7be3w.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2021-01-10 21:00:00
#
# Solver log file: '/tmp/tmpcn1k2yaa_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5yod_9xr.pyomo.sol'
# Solver problem files: ('/tmp/tmp5yod_9xr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2021-01-10 21:20:00
#
# Solver log file: '/tmp/tmpvtv22k38_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppdcneyip.pyomo.sol'
# Solver problem files: ('/tmp/tmppdcneyip.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2021-01-10 21:40:00
#
# Solver log file: '/tmp/tmpo5bwnekf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxv5rjsvp.pyomo.sol'
# Solver problem files: ('/tmp/tmpxv5rjsvp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2021-01-10 22:00:00
#
# Solver log file: '/tmp/tmpajwflzg9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdmlp0emf.pyomo.sol'
# Solver problem files: ('/tmp/tmpdmlp0emf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2021-01-10 22:20:00
#
# Solver log file: '/tmp/tmpg1qqs_d9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzersn_nh.pyomo.sol'
# Solver problem files: ('/tmp/tmpzersn_nh.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2021-01-10 22:40:00
#
# Solver log file: '/tmp/tmpm232cn8r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpx75dnf68.pyomo.sol'
# Solver problem files: ('/tmp/tmpx75dnf68.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2021-01-10 23:00:00
#
# Solver log file: '/tmp/tmpmcziln9r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp72tofi83.pyomo.sol'
# Solver problem files: ('/tmp/tmp72tofi83.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2021-01-10 23:20:00
#
# Solver log file: '/tmp/tmp4h7rpesj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_n8motr9.pyomo.sol'
# Solver problem files: ('/tmp/tmp_n8motr9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2021-01-10 23:40:00
#
# Solver log file: '/tmp/tmplp5qymal_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpku7qi9n0.pyomo.sol'
# Solver problem files: ('/tmp/tmpku7qi9n0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2021-01-11 00:00:00
#
# Solver log file: '/tmp/tmpt5urlupl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpufaqilad.pyomo.sol'
# Solver problem files: ('/tmp/tmpufaqilad.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 0
# 2021-01-10 00:00:00
#
# Solver log file: '/tmp/tmpg6ppcsjr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2w0yyq42.pyomo.sol'
# Solver problem files: ('/tmp/tmp2w0yyq42.pyomo.nl',)
# /home/brendan/jupyter_env/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2021-01-10 00:20:00
#
# Solver log file: '/tmp/tmpi1z5rhdu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp28o7c066.pyomo.sol'
# Solver problem files: ('/tmp/tmp28o7c066.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2021-01-10 00:40:00
#
# Solver log file: '/tmp/tmp4o6of8hu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpps7jjol2.pyomo.sol'
# Solver problem files: ('/tmp/tmpps7jjol2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2021-01-10 01:00:00
#
# Solver log file: '/tmp/tmpw9m8zb3r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpec8e2az4.pyomo.sol'
# Solver problem files: ('/tmp/tmpec8e2az4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2021-01-10 01:20:00
#
# Solver log file: '/tmp/tmpor23d837_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpq_xq6377.pyomo.sol'
# Solver problem files: ('/tmp/tmpq_xq6377.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2021-01-10 01:40:00
#
# Solver log file: '/tmp/tmpa6yw_i_9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgyvwws9n.pyomo.sol'
# Solver problem files: ('/tmp/tmpgyvwws9n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2021-01-10 02:00:00
#
# Solver log file: '/tmp/tmpwoxp4jnm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgb33ndt3.pyomo.sol'
# Solver problem files: ('/tmp/tmpgb33ndt3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2021-01-10 02:20:00
#
# Solver log file: '/tmp/tmpyr2fans3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp90xd1_pd.pyomo.sol'
# Solver problem files: ('/tmp/tmp90xd1_pd.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2021-01-10 02:40:00
#
# Solver log file: '/tmp/tmpl2suiuo8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpij102u7v.pyomo.sol'
# Solver problem files: ('/tmp/tmpij102u7v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2021-01-10 03:00:00
#
# Solver log file: '/tmp/tmp4g9n35x5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphbf9rvbi.pyomo.sol'
# Solver problem files: ('/tmp/tmphbf9rvbi.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2021-01-10 03:20:00
#
# Solver log file: '/tmp/tmpnoe_kz6i_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpx_rmngs0.pyomo.sol'
# Solver problem files: ('/tmp/tmpx_rmngs0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2021-01-10 03:40:00
#
# Solver log file: '/tmp/tmpl26ifyol_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn814nj2o.pyomo.sol'
# Solver problem files: ('/tmp/tmpn814nj2o.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2021-01-10 04:00:00
#
# Solver log file: '/tmp/tmp44wh27wn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptmqbmehe.pyomo.sol'
# Solver problem files: ('/tmp/tmptmqbmehe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2021-01-10 04:20:00
#
# Solver log file: '/tmp/tmp_bpuzst5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnt9pc5vt.pyomo.sol'
# Solver problem files: ('/tmp/tmpnt9pc5vt.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2021-01-10 04:40:00
#
# Solver log file: '/tmp/tmpo5nt0rh1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpga0xenyj.pyomo.sol'
# Solver problem files: ('/tmp/tmpga0xenyj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2021-01-10 05:00:00
#
# Solver log file: '/tmp/tmpjefqtj86_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb33u_7bi.pyomo.sol'
# Solver problem files: ('/tmp/tmpb33u_7bi.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2021-01-10 05:20:00
#
# Solver log file: '/tmp/tmpgnjuttuv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpk4s19nl0.pyomo.sol'
# Solver problem files: ('/tmp/tmpk4s19nl0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2021-01-10 05:40:00
#
# Solver log file: '/tmp/tmpes2jg0hl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn8ctoac6.pyomo.sol'
# Solver problem files: ('/tmp/tmpn8ctoac6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2021-01-10 06:00:00
#
# Solver log file: '/tmp/tmpaj1yoyy4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpop5wgs1k.pyomo.sol'
# Solver problem files: ('/tmp/tmpop5wgs1k.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2021-01-10 06:20:00
#
# Solver log file: '/tmp/tmptzdrqqm9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5zr3tj4s.pyomo.sol'
# Solver problem files: ('/tmp/tmp5zr3tj4s.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2021-01-10 06:40:00
#
# Solver log file: '/tmp/tmp0eu7yae3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpy5uoxml3.pyomo.sol'
# Solver problem files: ('/tmp/tmpy5uoxml3.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2021-01-10 07:00:00
#
# Solver log file: '/tmp/tmpk2c3ygtg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpw__3uine.pyomo.sol'
# Solver problem files: ('/tmp/tmpw__3uine.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2021-01-10 07:20:00
#
# Solver log file: '/tmp/tmp3c8gzkhv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmplc65yyc9.pyomo.sol'
# Solver problem files: ('/tmp/tmplc65yyc9.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2021-01-10 07:40:00
#
# Solver log file: '/tmp/tmpkmwbk_rh_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn0okag_0.pyomo.sol'
# Solver problem files: ('/tmp/tmpn0okag_0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2021-01-10 08:00:00
#
# Solver log file: '/tmp/tmpvzhku797_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp48uq29y_.pyomo.sol'
# Solver problem files: ('/tmp/tmp48uq29y_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2021-01-10 08:20:00
#
# Solver log file: '/tmp/tmp95pxailr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp99l_vl_d.pyomo.sol'
# Solver problem files: ('/tmp/tmp99l_vl_d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2021-01-10 08:40:00
#
# Solver log file: '/tmp/tmpi6fx053a_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwn3iwtfn.pyomo.sol'
# Solver problem files: ('/tmp/tmpwn3iwtfn.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2021-01-10 09:00:00
#
# Solver log file: '/tmp/tmpz8szi2ua_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptkyh9_u2.pyomo.sol'
# Solver problem files: ('/tmp/tmptkyh9_u2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2021-01-10 09:20:00
#
# Solver log file: '/tmp/tmp44sqkyey_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpajpce6tb.pyomo.sol'
# Solver problem files: ('/tmp/tmpajpce6tb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2021-01-10 09:40:00
#
# Solver log file: '/tmp/tmp9r9ohhau_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpz270vpcw.pyomo.sol'
# Solver problem files: ('/tmp/tmpz270vpcw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2021-01-10 10:00:00
#
# Solver log file: '/tmp/tmpfi829puy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp6x1hvfxe.pyomo.sol'
# Solver problem files: ('/tmp/tmp6x1hvfxe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2021-01-10 10:20:00
#
# Solver log file: '/tmp/tmp17mbbeyo_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpkvr2p5li.pyomo.sol'
# Solver problem files: ('/tmp/tmpkvr2p5li.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2021-01-10 10:40:00
#
# Solver log file: '/tmp/tmp5ulwazyd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp72c7kw3m.pyomo.sol'
# Solver problem files: ('/tmp/tmp72c7kw3m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2021-01-10 11:00:00
#
# Solver log file: '/tmp/tmpy3_epz_2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb4286k3r.pyomo.sol'
# Solver problem files: ('/tmp/tmpb4286k3r.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2021-01-10 11:20:00
#
# Solver log file: '/tmp/tmpgl05t9wv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpfiwhdb6k.pyomo.sol'
# Solver problem files: ('/tmp/tmpfiwhdb6k.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2021-01-10 11:40:00
#
# Solver log file: '/tmp/tmpl8j80isi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp798qqoiy.pyomo.sol'
# Solver problem files: ('/tmp/tmp798qqoiy.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2021-01-10 12:00:00
#
# Solver log file: '/tmp/tmpy2109sx1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf_8_ueql.pyomo.sol'
# Solver problem files: ('/tmp/tmpf_8_ueql.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2021-01-10 12:20:00
#
# Solver log file: '/tmp/tmpfwnsd7ay_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_1wmq3uo.pyomo.sol'
# Solver problem files: ('/tmp/tmp_1wmq3uo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2021-01-10 12:40:00
#
# Solver log file: '/tmp/tmp8fcbt6z5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmx0gzexo.pyomo.sol'
# Solver problem files: ('/tmp/tmpmx0gzexo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2021-01-10 13:00:00
#
# Solver log file: '/tmp/tmpe_o9p76t_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4yt6tp3w.pyomo.sol'
# Solver problem files: ('/tmp/tmp4yt6tp3w.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2021-01-10 13:20:00
#
# Solver log file: '/tmp/tmpzn8c89f4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp52gsaeml.pyomo.sol'
# Solver problem files: ('/tmp/tmp52gsaeml.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2021-01-10 13:40:00
#
# Solver log file: '/tmp/tmpsb56sp4d_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2e_fx7mo.pyomo.sol'
# Solver problem files: ('/tmp/tmp2e_fx7mo.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2021-01-10 14:00:00
#
# Solver log file: '/tmp/tmp4f8_jzmt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmppms9y_tv.pyomo.sol'
# Solver problem files: ('/tmp/tmppms9y_tv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2021-01-10 14:20:00
#
# Solver log file: '/tmp/tmp6hfn2qn8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbghweckx.pyomo.sol'
# Solver problem files: ('/tmp/tmpbghweckx.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2021-01-10 14:40:00
#
# Solver log file: '/tmp/tmpxhb861da_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4p3__9i8.pyomo.sol'
# Solver problem files: ('/tmp/tmp4p3__9i8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2021-01-10 15:00:00
#
# Solver log file: '/tmp/tmphy1279o5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqryij4at.pyomo.sol'
# Solver problem files: ('/tmp/tmpqryij4at.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2021-01-10 15:20:00
#
# Solver log file: '/tmp/tmpbys5bkjd_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxl9hpuz7.pyomo.sol'
# Solver problem files: ('/tmp/tmpxl9hpuz7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2021-01-10 15:40:00
#
# Solver log file: '/tmp/tmpq_q9ae82_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0lcbmp8y.pyomo.sol'
# Solver problem files: ('/tmp/tmp0lcbmp8y.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2021-01-10 16:00:00
#
# Solver log file: '/tmp/tmprd37z46q_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpiwfxskwn.pyomo.sol'
# Solver problem files: ('/tmp/tmpiwfxskwn.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2021-01-10 16:20:00
#
# Solver log file: '/tmp/tmpy6r0lh34_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbrrgm2go.pyomo.sol'
# Solver problem files: ('/tmp/tmpbrrgm2go.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2021-01-10 16:40:00
#
# Solver log file: '/tmp/tmpfa7h47v1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp428vs8z0.pyomo.sol'
# Solver problem files: ('/tmp/tmp428vs8z0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2021-01-10 17:00:00
#
# Solver log file: '/tmp/tmpjcy24nte_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9vwqkyv0.pyomo.sol'
# Solver problem files: ('/tmp/tmp9vwqkyv0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2021-01-10 17:20:00
#
# Solver log file: '/tmp/tmp1raty2s2_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb3xqotqm.pyomo.sol'
# Solver problem files: ('/tmp/tmpb3xqotqm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2021-01-10 17:40:00
#
# Solver log file: '/tmp/tmp6zwvxxru_gurobi_ampl.log'
# Solver solution file: '/tmp/tmph3h1tohe.pyomo.sol'
# Solver problem files: ('/tmp/tmph3h1tohe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2021-01-10 18:00:00
#
# Solver log file: '/tmp/tmp8_ew6ahc_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpquui97h4.pyomo.sol'
# Solver problem files: ('/tmp/tmpquui97h4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2021-01-10 18:20:00
#
# Solver log file: '/tmp/tmp7uzon1qu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_4r987wl.pyomo.sol'
# Solver problem files: ('/tmp/tmp_4r987wl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2021-01-10 18:40:00
#
# Solver log file: '/tmp/tmpqh6gbykb_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpe2t3vlmq.pyomo.sol'
# Solver problem files: ('/tmp/tmpe2t3vlmq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2021-01-10 19:00:00
#
# Solver log file: '/tmp/tmpm3_npqe4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf78_9rzq.pyomo.sol'
# Solver problem files: ('/tmp/tmpf78_9rzq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2021-01-10 19:20:00
#
# Solver log file: '/tmp/tmpe2ujzo8y_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpftx0o1pe.pyomo.sol'
# Solver problem files: ('/tmp/tmpftx0o1pe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2021-01-10 19:40:00
#
# Solver log file: '/tmp/tmphan47nrp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp59ys4ava.pyomo.sol'
# Solver problem files: ('/tmp/tmp59ys4ava.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2021-01-10 20:00:00
#
# Solver log file: '/tmp/tmpelk0rq33_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn9dz6d8l.pyomo.sol'
# Solver problem files: ('/tmp/tmpn9dz6d8l.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2021-01-10 20:20:00
#
# Solver log file: '/tmp/tmphj25uoja_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvkq3_pav.pyomo.sol'
# Solver problem files: ('/tmp/tmpvkq3_pav.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2021-01-10 20:40:00
#
# Solver log file: '/tmp/tmpsuwaw1fn_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpf4ocmyma.pyomo.sol'
# Solver problem files: ('/tmp/tmpf4ocmyma.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2021-01-10 21:00:00
#
# Solver log file: '/tmp/tmpwuhe0f_c_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt851d9ak.pyomo.sol'
# Solver problem files: ('/tmp/tmpt851d9ak.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2021-01-10 21:20:00
#
# Solver log file: '/tmp/tmp_zd1yjhu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpuysjuv03.pyomo.sol'
# Solver problem files: ('/tmp/tmpuysjuv03.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2021-01-10 21:40:00
#
# Solver log file: '/tmp/tmpkqhf5igt_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbjp_4fam.pyomo.sol'
# Solver problem files: ('/tmp/tmpbjp_4fam.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2021-01-10 22:00:00
#
# Solver log file: '/tmp/tmp5lrrltb8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprsui_0q0.pyomo.sol'
# Solver problem files: ('/tmp/tmprsui_0q0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2021-01-10 22:20:00
#
# Solver log file: '/tmp/tmp_4huqg8g_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7okcivau.pyomo.sol'
# Solver problem files: ('/tmp/tmp7okcivau.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2021-01-10 22:40:00
#
# Solver log file: '/tmp/tmpgtso28lp_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps844_blr.pyomo.sol'
# Solver problem files: ('/tmp/tmps844_blr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2021-01-10 23:00:00
#
# Solver log file: '/tmp/tmp8_zr292e_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpnvdyen3g.pyomo.sol'
# Solver problem files: ('/tmp/tmpnvdyen3g.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2021-01-10 23:20:00
#
# Solver log file: '/tmp/tmpzeeq5ltg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpipsi2c0d.pyomo.sol'
# Solver problem files: ('/tmp/tmpipsi2c0d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2021-01-10 23:40:00
#
# Solver log file: '/tmp/tmp_arijzi9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpu6u_jtki.pyomo.sol'
# Solver problem files: ('/tmp/tmpu6u_jtki.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2021-01-11 00:00:00
#
# Solver log file: '/tmp/tmpd3xchue8_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpjsi3md_0.pyomo.sol'
# Solver problem files: ('/tmp/tmpjsi3md_0.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1

# %%
#sbrc_pv['pv'].plot()

# %%
plot_electrical3(mpc_results['2021-1-10'], sim='mbc')

# %%
# plot_thermal_combined2(mpc_results['2020-11-03'])

# %%
mpc_results['pv'].plot()
# Out:
# <AxesSubplot:>
