# %% [markdown]
# # Peak Shaving DRH Simulations

# %% [markdown]
# This notebook contains simulations for the DRH MPC suystem that will be used throughout thesis

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.dae import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib
import numpy as np
import seaborn as sns
from sqlalchemy import create_engine
import pymysql
import datetime
#from datetime import datetime
import time
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing Data

# %% [markdown]
# **Specify start and end date of MPC simulations**

# %%
start = '2020-11-28'
end = '2020-11-29'
#end = '2020-12-4'
dt = 1/3

# %%
sim_start = 0
sim_end = 2200

# %% [markdown]
# **Import fixed time series data**

# %%
ts_data = pd.read_csv('5min_tariffs_peak.csv', index_col=0)
#ts_data = pd.read_csv('5min_tariffs.csv', index_col=0)
ts_data.index = pd.to_datetime(ts_data.index, format='%H:%M:%S').time

# %% [markdown]
# **Import historical DRH weather data from MySQL DB**

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

weather = pd.read_sql(f'select * from thermal_comfort where date_ between "{start}" and "{end}"', con=db_connection)
weather.index = weather.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
weather = weather[['t_ext', 'ghi', 't_bed']]

# %% [markdown]
# **Import historical PV data from MySQL DB**

# %%
db_connection_str = 'mysql+pymysql://bjb997:password@130.130.221.71/Desert_Rose_House'
db_connection = create_engine(db_connection_str)

power_balance = pd.read_sql(f'select * from power_balance where date_ between "{start}" and "{end}"', con=db_connection)
power_balance.index = power_balance.apply(lambda x : datetime.datetime.combine(x['date_'], datetime.time.min) + x['time_'], axis=1)
power_balance['pv'] = power_balance['pv_master'] + power_balance['pv_slave']

# %% [markdown]
# **Build dataframe with all relevant data source to use in simulations**

# %%
#Join weather and power data frames
sim_data = weather.join(power_balance['pv'], how='inner')

# %%
#insert fixed time series data into df
for col in ts_data.columns:
    sim_data[col] = [ts_data[col].loc[idx]  for idx in sim_data.index.time]

# %%
sim_data['t_ext'] = sim_data['t_ext'].ewm(span = 24).mean()

# %%
m_cool, b_cool = np.polyfit(x=[20,25,30,35,40,45], y=[-10.24, -9.38, -8.41, -7.44, -5.16, -3.79], deg=1)

# %%
m_cop, b_cop = np.polyfit(x=[20,25,30,35,40,45], y=[3.59, 3.26, 2.85, 2.44, 2.15, 1.88], deg=1)

# %%
sim_data['cop'] = m_cop*(sim_data['t_ext']) + b_cop
sim_data['cool_cap'] = m_cool*sim_data['t_ext'] + b_cool

# %%
states = {'SoC_Av':38.20,
         'T_i': 25.74,
         'T_w': 24.24,
         'phi_h':0,
         'phi_c':0}

# %% [markdown]
# ## MPC Formulation

# %%
class MPC():
    def __init__(self, **kwargs):
        self.Np = kwargs.get('Np', None)
        self.dt = kwargs.get('dt', None)
        self.forecasts = kwargs.get('forecasts', None)
        self.states = kwargs.get('states', None)
        self.n_ch = 0.96
        self.n_dis = 0.98
        self.max_soc = 13.8
        self.min_soc = 0
        self.max_ch = 3000
        self.max_dis = 3000
        self.batt_cost = 0.01
        self.M = 1000000
        self.R_w = 2.786
        self.C_w = 14.78
        self.C_i = 1.887
#         self.C_w = 1.78
#         self.C_i = 30.887
        self.A_g = 0.637
        self.A_w = 2.103
        self.COP = 3.69
        self.n_hvac = 0.6
        self.T_in_min = 16
        self.T_in_max = 50
        self.heat_cap = 7.4
        #self.cool_cap = 6.2
        self.min_cool = 1.8
        self.hp_rated_p = 8000
        self.hp_min_p = 1000
        self.weighted_batt = (np.arange(len(self.forecasts.index))/1000000) + self.batt_cost
        self.m = ConcreteModel()
        self.solver = SolverFactory('gurobi_ampl')
        self.control_modes = {}

    def initaliseSets(self):
        #time = list(range(int(self.Np/self.dt)))
        time = np.arange(len(self.forecasts.index))
        time_str = [str(x) for x in time]
        self.m.t = ContinuousSet(initialize=time)

    def initaliseScalars(self):
        #Initialise Electrical scalars
        #self.m.soc0 = Param(initialize=((self.states['SoC_Av']/100.0)*self.max_soc))
        self.m.soc0 = Param(initialize=self.states['SoC_Av'])
        self.m.dt = Param(initialize=self.dt)
        self.m.n_ch = Param(initialize=self.n_ch)
        self.m.n_dis = Param(initialize=self.n_dis)
        
        
        #Initialise thermal
        self.m.R_w = Param(initialize=self.R_w)
        self.m.C_w = Param(initialize=self.C_w)
        self.m.C_i = Param(initialize=self.C_i)
        self.m.A_g = Param(initialize=self.A_g)
        self.m.A_w = Param(initialize=self.A_w)
        self.m.COP = Param(initialize=self.COP)
        self.m.n_hvac = Param(initialize=self.n_hvac)

    def initialiseParameters(self):
        #Initialise Electrical Parameters
        self.m.p_load = Param(self.m.t, initialize=self.forecasts['load'].iloc[0], mutable=True)
        self.m.p_pv = Param(self.m.t, initialize=self.forecasts['pv'].iloc[0], mutable=True)
        self.m.tou = Param(self.m.t, initialize=self.forecasts['tou'].iloc[0], mutable=True)
        self.m.fit = Param(self.m.t, initialize=self.forecasts['fit'].iloc[0], mutable=True)
        self.m.batt_cost = Param(self.m.t, initialize=self.weighted_batt[0], mutable=True)
        self.m.ch_cost = Param(self.m.t, initialize=self.forecasts['ch_cost'].iloc[0], mutable=True)
        self.m.dis_cost = Param(self.m.t, initialize=self.forecasts['dis_cost'].iloc[0], mutable=True)
        self.m.mode_0 = Param(self.m.t, initialize=self.forecasts['mode_0'].iloc[0], mutable=True)
        self.m.mode_1 = Param(self.m.t, initialize=self.forecasts['mode_1'].iloc[0], mutable=True)
        self.m.mode_2 = Param(self.m.t, initialize=self.forecasts['mode_2'].iloc[0], mutable=True)
        
        
        
        #Initialise Paramerters
        self.m.ghi = Param(self.m.t, initialize=self.forecasts['ghi'].iloc[0]/1000, mutable=True)
        self.m.T_a = Param(self.m.t, initialize=self.forecasts['t_ext'].iloc[0], mutable=True)
        self.m.phi_g = Param(self.m.t, initialize=self.forecasts['heat_gains'].iloc[0], mutable=True)
        self.m.T_set = Param(self.m.t, initialize=self.forecasts['set_point'].iloc[0], mutable=True)
        self.m.T_set_cost = Param(self.m.t, initialize=self.forecasts['sp_soft'].iloc[0], mutable=True)
        self.m.cop = Param(self.m.t, initialize=self.forecasts['cop'].iloc[0], mutable=True)
        self.m.cool_cap = Param(self.m.t, initialize=self.forecasts['cool_cap'].iloc[0], mutable=True)

        #Insert predicted data into model
        weight = 0

        for n, time in enumerate(self.forecasts.index):
            #Electrical
            self.m.p_load[n] = self.forecasts['load'].loc[time]
            self.m.p_pv[n] = self.forecasts['pv'].loc[time]
            self.m.tou[n]= self.forecasts['tou'].loc[time]
            self.m.fit[n] = self.forecasts['fit'].loc[time]
            self.m.batt_cost[n]= self.weighted_batt[n]
            #self.m.batt_cost[n]= 0.01+weight
            self.m.ch_cost[n] = self.forecasts['ch_cost'].loc[time]
            self.m.dis_cost[n] = self.forecasts['dis_cost'].loc[time]
            self.m.mode_0[n] = self.forecasts['mode_0'].loc[time]
            self.m.mode_1[n] = self.forecasts['mode_1'].loc[time]
            self.m.mode_2[n] = self.forecasts['mode_2'].loc[time]
            #Thermal
            self.m.T_a[n].value = self.forecasts['t_ext'].loc[time]
            self.m.ghi[n].value = self.forecasts['ghi'].loc[time]/1000
            self.m.phi_g[n].value = self.forecasts['heat_gains'].loc[time]
            self.m.T_set[n].value = self.forecasts['set_point'].loc[time]
            self.m.T_set_cost[n].value = self.forecasts['sp_soft'].loc[time]
            self.m.cop[n].value = self.forecasts['cop'].loc[time]
            self.m.cool_cap[n].value = self.forecasts['cool_cap'].loc[time]
            
            weight = (weight + n/100000)

    def initaliseVariables(self):
        #initialise electrical variables
        self.m.p_im = Var(self.m.t, bounds=(0.0,None), doc='Power imported from grid')
        self.m.p_ex = Var(self.m.t, bounds=(None,0.0), doc='Power exported to grid')
        self.m.p_ch = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_p = Var(self.m.t, bounds=(-self.max_ch,0.0), doc='batt charge power')
        self.m.p_ch_g = Var(self.m.t, bounds=(-500,0.0), doc='batt charge power')
        self.m.p_dis = Var(self.m.t, bounds=(0.0,self.max_dis), doc='batt dis power')
        self.m.soc = Var(self.m.t, bounds=(0,100), doc='batt soc')
        #self.m.p_hvac = Var(self.m.t, bounds=(0.0,self.hp_rated_p), doc='hvac power')
        self.m.p_hvac = Var(self.m.t, bounds=(0, self.hp_rated_p), doc='hvac power')
        
        #Initialise Thermal Variables
        #self.m.T_i = Var(self.m.t, bounds=(self.T_in_min,self.T_in_max))
        self.m.T_i = Var(self.m.t, bounds=self.set_point_bounds)
        self.m.T_w = Var(self.m.t,bounds=(-10,60.0))
        #self.m.phi_h_heat = Var(self.m.t, bounds=(0.0,self.heat_cap))
        self.m.phi_h_cool = Var(self.m.t, bounds=self.cool_cap_bounds)
        #self.m.phi_h_cool = Var(self.m.t, bounds=(-10,0))
        
        self.m.hp_switch = Var(self.m.t, bounds=(self.hp_min_p,self.hp_rated_p))
        self.m.dhp = Var(self.m.t, within=Binary)

        #Initialise Binary Variables
        self.m.dbatt = Var(self.m.t, within=Binary)
        self.m.dhvac = Var(self.m.t, within=Binary)
        self.m.dgrid = Var(self.m.t, within=Binary)
        
        #Initialise derivatives
        self.m.dT_i = DerivativeVar(self.m.T_i, wrt=self.m.t)
        self.m.dT_w = DerivativeVar(self.m.T_w, wrt=self.m.t)

    def initialseConstraints(self):
        
        self.m.state = Constraint(self.m.t, rule=self.state_of_charge)
        self.m.powBal = Constraint(self.m.t, rule=self.powerBalance, doc='Power balance equation')

        self.m.charge_balance = Constraint(self.m.t, rule=self.chargeBalance)
        self.m.pv_charge = Constraint(self.m.t, rule=self.pvCharge)

        self.m.binary_discharge = Constraint(self.m.t, rule=self.binaryDischarge)
        self.m.binary_charge = Constraint(self.m.t, rule=self.binaryCharge)
        
        self.m.binary_import = Constraint(self.m.t, rule=self.binaryImport)
        self.m.binary_export = Constraint(self.m.t, rule=self.binaryExport)
        
        self.m.de1 = Constraint(self.m.t, rule=self.T_i_dot)
        self.m.de2 = Constraint(self.m.t, rule=self.T_w_dot)
        
        self.m.heatpump = Constraint(self.m.t, rule=self.heatpump_rule)
        self.m.heat_min = Constraint(self.m.t, rule=self.hp_min)
        self.m.heat_max = Constraint(self.m.t, rule=self.hp_max)
        
#         self.m.binary_heat = Constraint(self.m.t, rule=self.binaryHeat)
#         self.m.binary_cool = Constraint(self.m.t, rule=self.binaryCool)
        
        self.m.init_conditions = ConstraintList(rule=self._init)

        self.m.obj = Objective(rule=self.objFunc, sense=minimize)
        
      #------------------------Thermal----------------------#  

    #COOLING and HEATING CONTRAINTS
    def T_i_dot(self, m, t):
        #return m.dT_i[t] == (1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i)
        #return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_heat[t]+m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
        return m.dT_i[t] == ((1/(m.R_w*m.C_i))*(m.T_w[t] - m.T_i[t]) + (m.phi_g[t]/m.C_i) + ((m.phi_h_cool[t])/m.C_i) + ((m.A_g*m.ghi[t])/m.C_i))*self.dt
    
    #First order DE 2
    def T_w_dot(self, m, t):
        #return m.dT_w[t] == (1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w)
        return m.dT_w[t] == ((1/(m.R_w*m.C_w))*(m.T_i[t] - m.T_w[t]) + (1/(m.R_w*m.C_w))*(m.T_a[t] - m.T_w[t]) + ((m.A_w*m.ghi[t])/m.C_w))*self.dt
        
    
    #HVAc heat pump model
    def heatpump_rule(self, m,t):
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
        return (m.p_hvac[t]/1000)*m.n_hvac*m.cop[t] == -(m.phi_h_cool[t])
        #return (m.p_hvac[t]/1000)*m.n_hvac*m.COP == ((m.phi_h_heat[t]) - (m.phi_h_cool[t]))
    
    
    def binaryHeat(self, m,t):
        return -m.phi_h_cool[t] <= self.M*self.m.dhvac[t]
    
    def binaryCool(self, m,t):
        return m.phi_h_heat[t] <= self.M*(1-self.m.dhvac[t])
    
    def cool_cap_bounds(self, m, t):
        return (self.m.cool_cap[t],0)
    
    
    def hp_min(self, m, t):
        return m.p_hvac[t] >= self.hp_min_p*self.m.dhp[t]
        #return -m.phi_h_cool[t] >= self.min_cool*self.m.dhp[t]
    
    def hp_max(self, m, t):
        return m.p_hvac[t] <= self.M*self.m.dhp[t]
        #return -m.phi_h_cool[t] <= -self.m.cool_cap[t]*self.m.dhp[t]

    
    def set_point_bounds(self, m, t):
        #return (self.m.T_set[t]-0.5, self.m.T_set[t]+0.5)
        return (21, 27)
    
    
    #------------------------Electrical----------------------#
    
    def state_of_charge(self, m,t):
        j = list(range(int(t+1)))
        return self.m.soc0 + sum(-((((self.m.p_ch[i]*self.m.n_ch)+(self.m.p_dis[i]/self.m.n_dis))*(self.m.dt/1000))/self.max_soc)*100 for i in j) == self.m.soc[t]


    def powerBalance(self, m,t):
        return (self.m.p_load[t] + self.m.p_hvac[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0
        #return (self.m.p_load[t])-self.m.p_pv[t]-(self.m.p_ch[t])-self.m.p_im[t]-self.m.p_ex[t]-(self.m.p_dis[t])  == 0.0

        
    def chargeBalance(self, m,t):
        return self.m.p_ch[t] == self.m.p_ch_p[t] + self.m.p_ch_g[t]

    def pvCharge(self, m,t):
        return self.m.p_ch_p[t] >= -self.m.p_pv[t]


    def binaryDischarge(self, m,t):
        return self.m.p_dis[t] <= self.M*self.m.dbatt[t]

    def binaryCharge(self, m,t):
        return -self.m.p_ch[t] <= self.M*(1-self.m.dbatt[t])
    
    
    def binaryImport(self, m,t):
        return self.m.p_im[t] <= self.M*self.m.dgrid[t]

    def binaryExport(self, m,t):
        return -self.m.p_ex[t] <= self.M*(1-self.m.dgrid[t])
    

    
    #State measurements
    def _init(self, m):
        yield m.T_i[0] == self.states['T_i']
        yield m.T_w[m.t.first()] == self.states['T_w']
        #yield m.phi_h_heat[m.t.first()] == self.states['phi_h']
        yield m.phi_h_cool[m.t.first()] == self.states['phi_c']


    #Combined Objective function - linear p_ch_g
    
#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
#                    + 0.25*(self.m.p_hvac[t]*(self.m.dt))
#                    for t in self.m.t)
    
    
    def objFunc(self, m):  
        
        return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
                   + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
                   + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t]))
                   + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
                   + (self.m.T_set_cost[t]*((self.m.T_i[t] - self.m.T_set[t])*(self.m.T_i[t] - self.m.T_set[t])))
                   + 0.1*(self.m.p_hvac[t]*(self.m.dt)))
                   + self.m.mode_2[t]*0.25*(((self.m.p_im[t] + self.m.p_ex[t]) + 5000)*((self.m.p_im[t] + self.m.p_ex[t]) + 5000))
                   for t in self.m.t)
    

    
        
    

#     def objFunc(self, m):  
        
#         return sum(self.m.mode_0[t]*((self.m.p_im[t]*(self.m.dt)*self.m.tou[t])
#                    + (self.m.p_ex[t]*(self.m.dt)*self.m.fit[t])
#                    + (-self.m.p_ch_p[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (self.m.p_dis[t]*(self.m.dt)*self.m.batt_cost[t])
#                    + (-(self.m.p_ch_g[t])*(self.m.dt)*(self.m.ch_cost[t])))
#                    for t in self.m.t)
    


    
    def solve(self):
        
        self.initaliseSets()
        self.initaliseScalars()
        self.initialiseParameters()
        self.initaliseVariables()
        self.initialseConstraints()
        
        #Discretise the model
        discretizer = TransformationFactory('dae.finite_difference')
        discretizer.apply_to(self.m, nfe=48, wrt=self.m.t, scheme='BACKWARD')
        
        solver = SolverFactory('gurobi_ampl')
        results = solver.solve(self.m, keepfiles=True, tee=True)
        
        return results

# %%
def extract_pyomo_electrical_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    df['p_im'] = list(m.p_im.get_values().values())
    df['p_ex'] = list(m.p_ex.get_values().values())
    df['p_ch'] = list(m.p_ch.get_values().values())
    df['p_dis'] = list(m.p_dis.get_values().values())
    df['soc'] = list(m.soc.get_values().values())
    
    return df

# %%
def extract_pyomo_thermal_data(idx, m, df):
    
    #df_results = pd.DataFrame(index=idx)
    
    #df['phi_h_heat'] = list(m.phi_h_heat.get_values().values())
    df['phi_h_cool'] = list(m.phi_h_cool.get_values().values())
    df['p_hvac'] = list(m.p_hvac.get_values().values())
    df['T_i'] = list(m.T_i.get_values().values())
    df['T_w'] = list(m.T_w.get_values().values())
    
    return df

# %%
def plot_electrical3(df_results, sim):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    
    fig = plt.figure(figsize=(12,8))
    
    gs=GridSpec(3,1) # 2 rows, 3 columns

    ax1=fig.add_subplot(gs[0,0]) # First row, first column
    ax2=fig.add_subplot(gs[1:,0]) # First row, second column

    
    load =  ax2.plot(df_results.index, df_results['load'], label='$p_i^l$', lw=1, color='red', ls=(0, (3, 1, 1, 1)))
    pv =  ax2.plot(df_results.index, df_results['pv'], label='$p_i^p$', lw=1, color='blue', ls=(0, (5, 5)))
    im =  ax2.plot(df_results.index, df_results['p_im'], label='$p_i^i$', lw=1, color='grey', ls='-.')
    ex =  ax2.plot(df_results.index, df_results['p_ex'], label='$p_i^e$', lw=1, color='orange', ls=(0, (3, 1, 1, 1, 1, 1)))
    ch =  ax2.plot(df_results.index, df_results['p_ch'], label='$p_i^c$', lw=1.5,color='black', ls='dotted')
    dis =  ax2.plot(df_results.index, df_results['p_dis'], label='$p_i^d$', lw=1, color='green')
    hvac = ax2.plot(df_results.index, df_results['p_hvac'], label='$p_i^h$', lw=1, color='purple', ls=(0, (5, 1)))
    ax2.set_ylim(-6000,12000)
     
    soc = ax1.plot(df_results.index, df_results['soc'], label='$SoC$', lw=1, color='blue', ls='--')
    ax1.set_ylim(-10,120)
    
    ax3 = ax1.twinx()
    ax3.set_ylabel('Cost ($/kWh)')
    ax3.set_ylim(0,0.4)
    tou = ax3.plot(df_results.index, df_results['tou'], label='$ToU$', lw=1, color='red',)
    ax3.grid()
    
    ax2.set_xlabel('Date')
    ax1.set_ylabel('SoC (%)')
    ax1.get_shared_x_axes().join(ax1, ax2)
    ax1.set_xticklabels([])
    ax2.set_ylabel('Power (W)')
    
    ax2.legend(loc="upper left", ncol=7)
    ax1.legend(loc="upper left")
    ax3.legend(loc="upper right")
    ax1.autoscale(enable=True, axis='x', tight=True)

# %%
def plot_thermal_combined2(mpc_data):
    
    sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    matplotlib.rcParams['font.family'] = 'Abyssinica SIL'
    
    fig, ax = plt.subplots(2, sharex=True)
    ax[0].set_ylabel('Indoor Temperature ($^\circ$C)')
    ax[0].set_ylim(15,45)
    ax[0].plot(mpc_data.index, mpc_data['T_i'], color='red', lw=2, ls='--')
    #ax[0].plot(mpc_data.index, rbc_data['T_i'], color='black', lw=2, ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[0].plot(mpc_data.index, mpc_data['t_ext'], color='green', ls='-.')
    #ax[0].plot(mpc_data.index, mpc_data['t_bed'])
    ax[0].plot(mpc_data.index, mpc_data['set_point'], color='grey')
    ax[0].legend(['MPC $T_i^i$', 'RBC $T_i^i$', '$T_a$', 'Set Point'], loc="upper left", ncol=4)
    
    
    
    #Plot Results
    
    ax[1].set_xlabel('Date')
    ax[1].set_ylabel('Cooling (kW) \n Solar Irradiance (kW/m$^2$)')
    ax[1].set_ylim(0,15)
    #ax1.plot(df_results.index, df_results['phi_h_heat'], color='red')
    ax[1].plot(mpc_data.index, -mpc_data['phi_h_cool'], color='red', alpha=0.75, )
    #ax[1].plot(mpc_data.index, -rbc_data['phi_h_cool'], color= 'black', ls=(0, (3, 1, 1, 1, 1, 1)))
    ax[1].plot(mpc_data.index, mpc_data['ghi']/1000, color='blue', ls='--')
    ax[1].legend(['MPC $\Phi_i^c$', 'RPC $\Phi_i^c$', 'GHI'], loc="upper left", ncol=3)



    fig.tight_layout()
    fig.set_figheight(7.5)
    fig.set_figwidth(12)# otherwise the right y-label is slightly clipped
    #ax.grid()
    
    #plt.savefig('thermal_mpc_rbc.pdf')
    ax[0].autoscale(enable=True, axis='x', tight=True)
    ax[1].autoscale(enable=True, axis='x', tight=True)
    plt.show()

# %% [markdown]
# ## Solve MPC

# %%
mpc_data = sim_data.loc[start:end].resample('20min').mean().dropna()

# %%
mpc_data.loc['2020-11-29','mode_0'] = 1
mpc_data.loc['2020-11-29','mode_2'] = 0

# mpc_data['mode_0'] = 1
# mpc_data['mode_1'] = 0

# %%
mpc_data['mode_1'].plot()
# Out:
# <AxesSubplot:>

# %%
# mpc = MPC(Np=24, dt=(1/3), forecasts=mpc_data, states=states)
# start = time.time()
# results = mpc.solve()
# end = time.time()
# print(f'\nSolved in {str(round(end-start,2))}s')

# %%
# mpc_data = extract_pyomo_electrical_data(mpc_data.index, mpc.m, mpc_data)
# mpc_data = extract_pyomo_thermal_data(mpc_data.index, mpc.m, mpc_data)

# %%
# plot_electrical3(mpc_data, sim='mbc')

# %%
# plot_thermal_combined2(mpc_data)

# %%
# (mpc_data['p_im'] + mpc_data['p_ex']).plot()

# %%
mpc_results = pd.DataFrame(index = mpc_data.index, columns=['t_ext', 'ghi', 't_bed', 'pv', 'fixed', 'tou', 'fit', 'ch_cost',
       'dis_cost', 'mode_0', 'mode_1', 'mode_2', 'set_point', 'sp_soft',
       'heat_gains', 'load_sim', 'load1', 'heat_gains0', 'load', 'cop',
       'cool_cap', 'p_im', 'p_ex', 'p_ch', 'p_dis', 'soc', 'phi_h_heat',
       'phi_h_cool', 'p_hvac', 'T_i', 'T_w'])

# %%
# mpc_results = mpc_data.copy()

# %%
start = time.time()

for i, idx in enumerate(mpc_data.index):
    print('\n' + str(i) + '\n' + str(idx) + '\n')
    mpc_sim = mpc_data.iloc[i:i+int(24/dt)].copy()

    mpc = MPC(Np=24, dt=dt, forecasts=mpc_sim, states=states)
    mpc.solve()

    mpc_sim = extract_pyomo_electrical_data(mpc_sim.index, mpc.m, mpc_sim)
    mpc_sim = extract_pyomo_thermal_data(mpc_sim.index, mpc.m, mpc_sim)

    mpc_results_first_step = mpc_sim.iloc[0].copy()
    mpc_results.iloc[i] = mpc_results_first_step
    
    #states = {'SoC_Av':mpc_sim['soc'].iloc[0]}
    
#     states = {'SoC_Av':mpc_sim['soc'].iloc[0],
#               'T_i':mpc_sim['T_i'].iloc[1],
#               'T_w':mpc_sim['T_w'].iloc[1],
#               'phi_h':mpc_sim['phi_h_heat'].iloc[1],
#               'phi_c':mpc_sim['phi_h_cool'].iloc[1]}
    
    states = {'SoC_Av':mpc_sim['soc'].iloc[0],
              'T_i':mpc_sim['T_i'].iloc[1],
              'T_w':mpc_sim['T_w'].iloc[1],
              'phi_c':mpc_sim['phi_h_cool'].iloc[1]}

    
    #print(mpc_results_first_step)
    
    if(i==72):
        break 
#     if(i==500):
#         break
        
end = time.time()
print(f'\nSolved in {str(round(end-start,2))}s')
# Out:
# 0
# 2020-11-28 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_ckq350q_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp3hr9owp.pyomo.sol'
# Solver problem files: ('/tmp/tmpp3hr9owp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 1
# 2020-11-28 00:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp90_oset0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp82ny9ruj.pyomo.sol'
# Solver problem files: ('/tmp/tmp82ny9ruj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 2
# 2020-11-28 00:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpml9_t02m_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp74b8q1rg.pyomo.sol'
# Solver problem files: ('/tmp/tmp74b8q1rg.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 3
# 2020-11-28 01:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjf7lq1qg_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9wwqdjzp.pyomo.sol'
# Solver problem files: ('/tmp/tmp9wwqdjzp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 4
# 2020-11-28 01:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpnn5qauoy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5pt2s5s7.pyomo.sol'
# Solver problem files: ('/tmp/tmp5pt2s5s7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 5
# 2020-11-28 01:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpy457jcw3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp2vpni12e.pyomo.sol'
# Solver problem files: ('/tmp/tmp2vpni12e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 6
# 2020-11-28 02:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpf9j_q_ij_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpc4lgd3cc.pyomo.sol'
# Solver problem files: ('/tmp/tmpc4lgd3cc.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 7
# 2020-11-28 02:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmprl4_57yq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprbx9rekl.pyomo.sol'
# Solver problem files: ('/tmp/tmprbx9rekl.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 8
# 2020-11-28 02:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp1odky32z_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7mn027r8.pyomo.sol'
# Solver problem files: ('/tmp/tmp7mn027r8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 9
# 2020-11-28 03:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpb5ggh36z_gurobi_ampl.log'
# Solver solution file: '/tmp/tmponbft8qm.pyomo.sol'
# Solver problem files: ('/tmp/tmponbft8qm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 10
# 2020-11-28 03:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp7lr_qqh__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpeezsub0z.pyomo.sol'
# Solver problem files: ('/tmp/tmpeezsub0z.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 11
# 2020-11-28 03:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpnqrwrs1h_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbaphy44v.pyomo.sol'
# Solver problem files: ('/tmp/tmpbaphy44v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 12
# 2020-11-28 04:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpliihehqq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9fw1e3nb.pyomo.sol'
# Solver problem files: ('/tmp/tmp9fw1e3nb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 13
# 2020-11-28 04:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpaoh9cnnm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4hp336kq.pyomo.sol'
# Solver problem files: ('/tmp/tmp4hp336kq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 14
# 2020-11-28 04:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkb9zu1jq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvhoc0m_o.pyomo.sol'
# Solver problem files: ('/tmp/tmpvhoc0m_o.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 15
# 2020-11-28 05:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpxa5oolwr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpq5ob2mfp.pyomo.sol'
# Solver problem files: ('/tmp/tmpq5ob2mfp.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 16
# 2020-11-28 05:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpi7yk1mxy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpo0fv7i6q.pyomo.sol'
# Solver problem files: ('/tmp/tmpo0fv7i6q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 17
# 2020-11-28 05:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpda5xj3d5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8clc5xqa.pyomo.sol'
# Solver problem files: ('/tmp/tmp8clc5xqa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 18
# 2020-11-28 06:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpv2qzrybe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwuewb7o6.pyomo.sol'
# Solver problem files: ('/tmp/tmpwuewb7o6.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 19
# 2020-11-28 06:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpiwe5kws0_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpko4njsmu.pyomo.sol'
# Solver problem files: ('/tmp/tmpko4njsmu.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 20
# 2020-11-28 06:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp5eu0_wpx_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7vivah_p.pyomo.sol'
# Solver problem files: ('/tmp/tmp7vivah_p.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 21
# 2020-11-28 07:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp7qsaq_72_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4kqo17tm.pyomo.sol'
# Solver problem files: ('/tmp/tmp4kqo17tm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 22
# 2020-11-28 07:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmphmushq1u_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpcnstw02e.pyomo.sol'
# Solver problem files: ('/tmp/tmpcnstw02e.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 23
# 2020-11-28 07:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmph4bmngel_gurobi_ampl.log'
# Solver solution file: '/tmp/tmphmurg7o7.pyomo.sol'
# Solver problem files: ('/tmp/tmphmurg7o7.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 24
# 2020-11-28 08:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp39cu6fmu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp9vzfs1xv.pyomo.sol'
# Solver problem files: ('/tmp/tmp9vzfs1xv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 25
# 2020-11-28 08:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp476w7r3s_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp4isgu6uf.pyomo.sol'
# Solver problem files: ('/tmp/tmp4isgu6uf.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 26
# 2020-11-28 08:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmptwheh8fi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpvhhkyj70.pyomo.sol'
# Solver problem files: ('/tmp/tmpvhhkyj70.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 27
# 2020-11-28 09:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_ht0jkqq_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpawt37icb.pyomo.sol'
# Solver problem files: ('/tmp/tmpawt37icb.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 28
# 2020-11-28 09:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp1n5593tw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpqn6xfi6m.pyomo.sol'
# Solver problem files: ('/tmp/tmpqn6xfi6m.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 29
# 2020-11-28 09:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_510_zyv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpsnyn520i.pyomo.sol'
# Solver problem files: ('/tmp/tmpsnyn520i.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 30
# 2020-11-28 10:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpbrvc_ynm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp5m6mzy0q.pyomo.sol'
# Solver problem files: ('/tmp/tmp5m6mzy0q.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 31
# 2020-11-28 10:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp10wu7hsy_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp1fh95hrj.pyomo.sol'
# Solver problem files: ('/tmp/tmp1fh95hrj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 32
# 2020-11-28 10:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpadhzubpf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbuh55v2x.pyomo.sol'
# Solver problem files: ('/tmp/tmpbuh55v2x.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 33
# 2020-11-28 11:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpdras4us5_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpb3ridcne.pyomo.sol'
# Solver problem files: ('/tmp/tmpb3ridcne.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 34
# 2020-11-28 11:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpoloprcdu_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpml76bdqa.pyomo.sol'
# Solver problem files: ('/tmp/tmpml76bdqa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 35
# 2020-11-28 11:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp701s1scz_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpoucn8tz4.pyomo.sol'
# Solver problem files: ('/tmp/tmpoucn8tz4.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 36
# 2020-11-28 12:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpt1h217pe_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp_355gajw.pyomo.sol'
# Solver problem files: ('/tmp/tmp_355gajw.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 37
# 2020-11-28 12:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpfdx6l8vw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgh7_z0k5.pyomo.sol'
# Solver problem files: ('/tmp/tmpgh7_z0k5.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 38
# 2020-11-28 12:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmplyvooovm_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpt8l0c9n2.pyomo.sol'
# Solver problem files: ('/tmp/tmpt8l0c9n2.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 39
# 2020-11-28 13:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpp9kahi0s_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpgvkwt8gq.pyomo.sol'
# Solver problem files: ('/tmp/tmpgvkwt8gq.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 40
# 2020-11-28 13:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpd9e38qux_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprkcpj6ca.pyomo.sol'
# Solver problem files: ('/tmp/tmprkcpj6ca.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 41
# 2020-11-28 13:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpnmcbn_e3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpxryctl2i.pyomo.sol'
# Solver problem files: ('/tmp/tmpxryctl2i.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 42
# 2020-11-28 14:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpu76vyd2r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpglck18ip.pyomo.sol'
# Solver problem files: ('/tmp/tmpglck18ip.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 43
# 2020-11-28 14:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpjausvw6r_gurobi_ampl.log'
# Solver solution file: '/tmp/tmptf7xkkao.pyomo.sol'
# Solver problem files: ('/tmp/tmptf7xkkao.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 44
# 2020-11-28 14:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpre911apl_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpphxgwt8_.pyomo.sol'
# Solver problem files: ('/tmp/tmpphxgwt8_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 45
# 2020-11-28 15:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpb7jv1124_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp616ivg6o.pyomo.sol'
# Solver problem files: ('/tmp/tmp616ivg6o.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 46
# 2020-11-28 15:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpwzx6f_sj_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpypxdns9u.pyomo.sol'
# Solver problem files: ('/tmp/tmpypxdns9u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 47
# 2020-11-28 15:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpa98d1jb1_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp0bh_ie0v.pyomo.sol'
# Solver problem files: ('/tmp/tmp0bh_ie0v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 48
# 2020-11-28 16:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp_047w1ij_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpaa8dxvl8.pyomo.sol'
# Solver problem files: ('/tmp/tmpaa8dxvl8.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 49
# 2020-11-28 16:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6uq0mdh9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp40z3d4zm.pyomo.sol'
# Solver problem files: ('/tmp/tmp40z3d4zm.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 50
# 2020-11-28 16:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmptrnvggop_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzmeseqrv.pyomo.sol'
# Solver problem files: ('/tmp/tmpzmeseqrv.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 51
# 2020-11-28 17:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpunuh8qca_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpwvma64nj.pyomo.sol'
# Solver problem files: ('/tmp/tmpwvma64nj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 52
# 2020-11-28 17:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpiub4et28_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps7to5_fe.pyomo.sol'
# Solver problem files: ('/tmp/tmps7to5_fe.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 53
# 2020-11-28 17:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpx8fvyb7h_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpdu7wiiee.pyomo.sol'
# Solver problem files: ('/tmp/tmpdu7wiiee.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 54
# 2020-11-28 18:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpgr0b84x6_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpe9hlwc8d.pyomo.sol'
# Solver problem files: ('/tmp/tmpe9hlwc8d.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 55
# 2020-11-28 18:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp621op4ml_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp7smvvhcr.pyomo.sol'
# Solver problem files: ('/tmp/tmp7smvvhcr.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 56
# 2020-11-28 18:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp2qq6zlgr_gurobi_ampl.log'
# Solver solution file: '/tmp/tmprxs2in5_.pyomo.sol'
# Solver problem files: ('/tmp/tmprxs2in5_.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 57
# 2020-11-28 19:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp2b83vaar_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpa_6km8oj.pyomo.sol'
# Solver problem files: ('/tmp/tmpa_6km8oj.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 58
# 2020-11-28 19:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpqhm62m7n_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpn9izoi3v.pyomo.sol'
# Solver problem files: ('/tmp/tmpn9izoi3v.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 59
# 2020-11-28 19:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpn6tlw8k3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp8zb6i32g.pyomo.sol'
# Solver problem files: ('/tmp/tmp8zb6i32g.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 60
# 2020-11-28 20:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpr30vfcb9_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp01102u8n.pyomo.sol'
# Solver problem files: ('/tmp/tmp01102u8n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 61
# 2020-11-28 20:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpanf1zmzi_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpd1puf4du.pyomo.sol'
# Solver problem files: ('/tmp/tmpd1puf4du.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 62
# 2020-11-28 20:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpl6hcmtev_gurobi_ampl.log'
# Solver solution file: '/tmp/tmps_i0t4ka.pyomo.sol'
# Solver problem files: ('/tmp/tmps_i0t4ka.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 63
# 2020-11-28 21:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpq4qg3ct__gurobi_ampl.log'
# Solver solution file: '/tmp/tmpg73iq10n.pyomo.sol'
# Solver problem files: ('/tmp/tmpg73iq10n.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 64
# 2020-11-28 21:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpblscski3_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp516aex41.pyomo.sol'
# Solver problem files: ('/tmp/tmp516aex41.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 65
# 2020-11-28 21:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpn5tuew5v_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpp49umswa.pyomo.sol'
# Solver problem files: ('/tmp/tmpp49umswa.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 66
# 2020-11-28 22:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpea334diw_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpaei5p5ql.pyomo.sol'
# Solver problem files: ('/tmp/tmpaei5p5ql.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 67
# 2020-11-28 22:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpvecrfztf_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpbow0ffij.pyomo.sol'
# Solver problem files: ('/tmp/tmpbow0ffij.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 68
# 2020-11-28 22:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp29oekipv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp75q90j6t.pyomo.sol'
# Solver problem files: ('/tmp/tmp75q90j6t.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 69
# 2020-11-28 23:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpkai6n7om_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpmqaep2_b.pyomo.sol'
# Solver problem files: ('/tmp/tmpmqaep2_b.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 70
# 2020-11-28 23:20:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmp6jd1r1a4_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpni0uej9u.pyomo.sol'
# Solver problem files: ('/tmp/tmpni0uej9u.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 71
# 2020-11-28 23:40:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpcebkfk9s_gurobi_ampl.log'
# Solver solution file: '/tmp/tmp84crejba.pyomo.sol'
# Solver problem files: ('/tmp/tmp84crejba.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# 72
# 2020-11-29 00:00:00
#
# WARNING: More finite elements were found in ContinuousSet 't' than the number
#     of finite elements specified in apply. The larger number of finite
#     elements will be used.
# Solver log file: '/tmp/tmpzlzb2udv_gurobi_ampl.log'
# Solver solution file: '/tmp/tmpzesgv9ui.pyomo.sol'
# Solver problem files: ('/tmp/tmpzesgv9ui.pyomo.nl',)
# Academic license - for non-commercial use only
# Gurobi 9.0.1
# Solved in 32.63s

# %%
mpc_results['cost'] = mpc_results['tou']*(mpc_results['p_im']/1000*dt)

# %%
mpc_results['payment'] = mpc_results['fit']*(mpc_results['p_ex']/1000*dt)

# %%
mpc_results['p_load'] = mpc_results['load']+mpc_results['p_hvac']

# %%
mpc_energy = mpc_results['2020-11-23':'2020-11-29'][['p_load', 'pv', 'p_hvac', 'p_im', 'p_ex', 'p_ch', 'p_dis', 
                      'cost', 'payment']].resample('d').sum()

# %%
mpc_energy[['p_load', 'pv', 'p_im', 'p_ex', 'p_ch', 'p_dis','p_hvac']] = (mpc_energy[['p_load', 'pv', 'p_im', 'p_ex', 'p_ch', 'p_dis','p_hvac']])/(1000)*dt

# %%
mpc_energy.loc['Total'] = mpc_energy.sum()
mpc_energy
# Out:
#                         p_load         pv     p_hvac       p_im       p_ex  \
# 2020-11-28 00:00:00  43.482872  49.210333  21.403455  18.060182 -26.469347
# 2020-11-29 00:00:00   0.110167   0.000000   0.000000   0.276833   0.000000
# Total                43.593039  49.210333  21.403455  18.337015 -26.469347
#
#                           p_ch      p_dis      cost   payment
# 2020-11-28 00:00:00 -15.897858  18.579561  4.016430 -2.911628
# 2020-11-29 00:00:00  -0.166667   0.000000  0.044293  0.000000
# Total               -16.064525  18.579561  4.060724 -2.911628

# %%
mpc_thermal = mpc_results['2020-11-23':'2020-11-29'][['p_hvac', 'phi_h_cool']].resample('d').sum()

# %%
mpc_thermal[['p_hvac']] = (mpc_thermal[['p_hvac']]/(1000))*dt
mpc_thermal[['phi_h_cool']] = -(mpc_thermal[['phi_h_cool']])*dt

# %%
mpc_thermal['COP'] = (mpc_thermal['phi_h_cool']/mpc_thermal['p_hvac'])/0.6

# %%
#mpc_thermal['RMSE'] = [np.sqrt(mean_squared_error(mpc_results.loc[date.strftime("%Y-%m-%d")]['T_i'], mpc_results.loc[date.strftime("%Y-%m-%d")]['set_point'])) for date in mpc_thermal.index]

# %%
mpc_thermal.loc['Total'] = mpc_thermal.sum()

# %%
mpc_results['T_i'].plot()
# Out:
# <AxesSubplot:>

# %%
mpc_results['p_hvac'].plot()
# Out:
# <AxesSubplot:>

# %%
mpc_thermal
# Out:
#                         p_hvac  phi_h_cool       COP
# 2020-11-28 00:00:00  21.403455   34.356724  2.675325
# 2020-11-29 00:00:00   0.000000   -0.000000       NaN
# Total                21.403455   34.356724  2.675325

# %%
plot_electrical3(mpc_results['2020-11-28'], sim='mbc')

# %%
plot_thermal_combined2(mpc_results['2020-11-28'])

# %%
mpc_results.to_csv('Peak_shave_20min_26-22-2020_3pm_7pm.csv')

# %%
(mpc_results.loc['2020-11-28']['p_im']+mpc_results.loc['2020-11-28']['p_ex']).plot()
# Out:
# <AxesSubplot:>
