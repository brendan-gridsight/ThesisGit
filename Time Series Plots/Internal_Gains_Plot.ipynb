# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib

# %%
ts_data = pd.read_csv('5min_tariffs.csv', index_col=0)
# ts_data.index = pd.to_datetime(ts_data.index, format='%H:%M:%S')
ts_data
# Out:
#           fixed   tou   fit  ch_cost  dis_cost  mode_0  mode_1  mode_2  \
# TIME
# 00:00:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 00:05:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 00:10:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 00:15:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 00:20:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# ...         ...   ...   ...      ...       ...     ...     ...     ...
# 23:35:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 23:40:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 23:45:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 23:50:00   0.25  0.16  0.11     0.02      0.01       1       0       0
# 23:55:00   0.25  0.16  0.11     0.02      0.01       1       0       0
#
#           set_point  sp_soft  heat_gains  load  load1  heat_gains0
# TIME
# 00:00:00         25      1.0         0.5   300    500            0
# 00:05:00         25      1.0         0.5   300    500            0
# 00:10:00         25      1.0         0.5   300    500            0
# 00:15:00         25      1.0         0.5   300    500            0
# 00:20:00         25      1.0         0.5   300    500            0
# ...             ...      ...         ...   ...    ...          ...
# 23:35:00         25      1.0         0.5   300    400            0
# 23:40:00         25      1.0         0.5   300    400            0
# 23:45:00         25      1.0         0.5   300    400            0
# 23:50:00         25      1.0         0.5   300    400            0
# 23:55:00         25      1.0         0.5   300    400            0
#
# [288 rows x 14 columns]

# %%
sns.set(font_scale=1.35, rc={'figure.figsize':(12,5)})
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
matplotlib.rcParams['font.family'] = 'Abyssinica SIL'


#Plot Results
fig, ax1 = plt.subplots()
ax1.set_xlabel('Time')
ax1.set_ylabel('Thermal Power Input (kW)')
ax1.set_xlim(0,288)
ax1.plot(ts_data.index, ts_data['heat_gains'], lw=2)
ax1.legend(['Internal Heat Gains'], loc="upper left")



fig.tight_layout()
fig.set_figheight(5)
fig.set_figwidth(12)# otherwise the right y-label is slightly clipped

plt.xticks(np.arange(0, 288, step=36))


plt.savefig('internal_gains.pdf', bbox_inches='tight')
plt.show()
